# %%
import requests # from urllib.request import urlopen
from bs4 import BeautifulSoup # HTTP Response -> HTML 

import pandas as pd

from datetime import datetime


from selenium import webdriver
import time 
import re #정규 표현식 활용

# %%
#망고플레이트에서 음식을 키워드로 맛집 리스트 가져오는 function
def get_rest_list(keyword):
    
    #페이지, 맛집리스트 초기화
    pagenum = 1
    restaurant_list = []
    
    #page별로 while 루프 돌려서 상호명 뽑아오기
    while pagenum <= 2: 
        try:
            url = 'https://www.mangoplate.com/search/?keyword='+keyword+'&page='+str(pagenum)#keyword를 input으로 망고플레이트 url 생성

            session = requests.Session()
            headers = {
            "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit 537.36 (KHTML, like Gecko) Chrome",
            "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8"
            }
            html = session.get(url, headers=headers).content 
            source = BeautifulSoup(html, 'html.parser')

            restaurants = source.find_all('h2', {'class' : 'title'}) #h2태그의 class 'title' => 상호명

            for restaurant in restaurants:#텍스트 깔끔하게 처리 및 리스트에 상호명 추가 루프

                n_restaurant = re.sub('\s', '', restaurant.get_text()) #텍스트 중간에 빈칸 없애기
                restaurant_list.append(n_restaurant)#리스트에 상호명 추가
        except:
            print(pagenum,'페이지 까지의 결과입니다.')
        
        pagenum += 1
        
    return restaurant_list #keyword 관련 맛집 리스트 생성

# %%
cnoodlelist = get_rest_list('냉면') #냉면 맛집 리스트 생성

# %%
cnoodlelist
# Out:
# ['허브족발(본점)',
#  '윤밀원',
#  '김진목삼',
#  '진미평양냉면',
#  '을지면옥',
#  '서관면옥',
#  '광릉한옥집',
#  '광화문국밥',
#  '춘향미엔',
#  '우래옥(을지로점)',
#  '설눈',
#  '봉밀가',
#  '봉피양(방이점)',
#  '미엔아이',
#  '윤선희의평양냉면양각도',
#  '청기와타운',
#  '서평면옥',
#  '몽탄',
#  '능라도(강남점)',
#  '정인면옥',
#  '옥돌현옥',
#  '오장동흥남집(본점)',
#  '거대갈비',
#  '평안도상원냉면',
#  '명지원이동갈비',
#  '벽제갈비(신촌점)',
#  '공단떡볶이',
#  '고명집',
#  '우밀면옥',
#  '단천식당',
#  '명인등심(압구정점)',
#  '평남면옥',
#  '송월냉면',
#  '서정가야밀면',
#  '더진미평냉',
#  '명인등심(삼성직영점)',
#  '영동냉면',
#  '을밀대(본점)',
#  '능라도(분당점)',
#  '강서면옥']

# %%
currylist = get_rest_list('카레')

# %%
currylist
# Out:
# ['마루심',
#  '우미노미',
#  '카레',
#  '공기식당',
#  '요시즈카우나기야/吉塚うなぎ屋',
#  '마루심(마포점)',
#  '멘야하나비(신사점)',
#  '예티',
#  '고옥',
#  '홋카이도부타동스미레',
#  '데카망(휴업중)',
#  '요우란',
#  '온정',
#  '타이가텐푸라',
#  '오사카카레콘유',
#  '텐동요츠야',
#  '멘야하나비',
#  '깔리',
#  '우마텐',
#  '부타이',
#  '에베레스트(동대문점)',
#  '가츠오',
#  '교양식사',
#  '도요스6가',
#  '텐동한',
#  '현우동',
#  '라하노카레',
#  '포탈라(종로점)',
#  '후라토식당(아브뉴프랑판교점)',
#  '운멜로랩',
#  '이치젠(망원본점)',
#  'BARN110',
#  '후라토식당',
#  '오복수산(도산점)',
#  '멘야코노하카레',
#  '사쿠텐',
#  '이코이',
#  '스아게/すあげ',
#  '주간소바식당산',
#  '하이쿠']

# %%
 url = 'https://www.mangoplate.com/search/?keyword='+'마루심' #상호명으로 망고플레이트 검색 url

session = requests.Session()
headers = {
"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit 537.36 (KHTML, like Gecko) Chrome",
"Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8"
}
html = session.get(url, headers=headers).content 
source = BeautifulSoup(html, 'html.parser')

rest_code = source.find('div',{'class':'list-restaurant-item'}).find('a')['href']
rest_code
# Out:
# '/restaurants/KU-4QO6Yvt'

# %%
def get_mango_info(restaurant):#상호명을 input으로 관련 정보 받아오는 function

    mango_info = {} #빈 dict 생성

    url = 'https://www.mangoplate.com/search/'+restaurant #상호명으로 망고플레이트 검색 url

    session = requests.Session()
    headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit 537.36 (KHTML, like Gecko) Chrome",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8"
    }
    html = session.get(url, headers=headers).content 
    source = BeautifulSoup(html, 'html.parser')
    
    try:
        rest_code = source.find('div',{'class':'list-restaurant-item'}).find('a')['href']#검색결과에서 첫번째 결과의 고유 코드 따오기 
        newurl = 'https://www.mangoplate.com'+rest_code #고유 코드 활용한 url 주소 생성
        newhtml = session.get(newurl, headers=headers).content 
        newsource = BeautifulSoup(newhtml, 'html.parser')

        rate = float(re.sub('\s','',newsource.find('strong',{'class':'rate-point'}).get_text()))#평점이 속한 태그에서 텍스트 가져와 float로 바꾸기 (나중에 계산 용이)

        rest_table = newsource.find('table',{'class':'info'})#관련 정보가 있는 테이블 경로

        address = rest_table.find_all('td')[0].find_all('span')[1].get_text()#주소
        phone = rest_table.find_all('td')[1].get_text()#전화번호
        kind = re.sub('\s','',rest_table.find_all('td')[2].get_text())#음식 종류(정규표현식 활용하여 깔끔하게 정리)
        price = rest_table.find_all('td')[3].get_text()#가격대

        #각각의 정보를 만든 dict의 key값의 value로 추가
        mango_info['name'] = restaurant
        mango_info['rate'] = rate
        mango_info['address'] = address
        mango_info['phone'] = phone
        mango_info['kind'] = kind
        mango_info['price'] = price
        
    except:
        mango_info['name'] = restaurant
        mango_info['rate'] = 'N/A'
        mango_info['address'] = 'N/A'
        mango_info['phone'] = 'N/A'
        mango_info['kind'] = 'N/A'
        mango_info['price'] = 'N/A'
    
    return mango_info #하나의 dict를 최종 값으로 return

# %%
for rest in currylist:
    get_mango_info(rest)
    print(rest,'의 정보 획득!')
# Out:
# 마루심 의 정보 획득!
# 우미노미 의 정보 획득!
# 카레 의 정보 획득!
# 공기식당 의 정보 획득!
# 요시즈카우나기야/吉塚うなぎ屋 의 정보 획득!
# 마루심(마포점) 의 정보 획득!
# 멘야하나비(신사점) 의 정보 획득!
# 예티 의 정보 획득!
# 고옥 의 정보 획득!
# 홋카이도부타동스미레 의 정보 획득!
# 데카망(휴업중) 의 정보 획득!
# 요우란 의 정보 획득!
# 온정 의 정보 획득!
# 타이가텐푸라 의 정보 획득!
# 오사카카레콘유 의 정보 획득!
# 텐동요츠야 의 정보 획득!
# 멘야하나비 의 정보 획득!
# 깔리 의 정보 획득!
# 우마텐 의 정보 획득!
# 부타이 의 정보 획득!
# 에베레스트(동대문점) 의 정보 획득!
# 가츠오 의 정보 획득!
# 교양식사 의 정보 획득!
# 도요스6가 의 정보 획득!
# 텐동한 의 정보 획득!
# 현우동 의 정보 획득!
# 라하노카레 의 정보 획득!
# 포탈라(종로점) 의 정보 획득!
# 후라토식당(아브뉴프랑판교점) 의 정보 획득!
# 운멜로랩 의 정보 획득!
# 이치젠(망원본점) 의 정보 획득!
# BARN110 의 정보 획득!
# 후라토식당 의 정보 획득!
# 오복수산(도산점) 의 정보 획득!
# 멘야코노하카레 의 정보 획득!
# 사쿠텐 의 정보 획득!
# 이코이 의 정보 획득!
# 스아게/すあげ 의 정보 획득!
# 주간소바식당산 의 정보 획득!
# 하이쿠 의 정보 획득!

# %%
print(get_mango_info('윤밀원'))
# Out:
# {'name': '윤밀원', 'rate': 4.6, 'address': '경기도 성남시 분당구 정자동 223-9', 'phone': '031-714-8388', 'kind': '국수/면요리', 'price': '만원 미만'}

# %%
def get_naver_info(restaurant): #네이버 평점 및 리뷰 가져오기
    
    naver_info = {}
    
    #정규표현식 활용해 상호명에 있는 괄호 및 특수문자 제거
    regex = "\(.*\)|\s-\s.*" 
    query = re.sub(regex, '', restaurant)
    
    url = "https://search.naver.com/search.naver?where=nexearch&sm=tab_jum&query=" + query
    web = requests.get(url).content
    source = BeautifulSoup(web, 'html.parser')
    
    try:
        reviewcount = int(source.find_all('span', {'class': 'count'})[1].get_text())
        rate = float(source.find_all('div', {'class': 'star_area'})[0].find('em').get_text())
    except:
        reviewcount = 'N/A'
        rate = 'N/A'
    
    naver_info['reviewcount'] = reviewcount
    naver_info['rate'] = rate
    
    return naver_info

# %%
print(get_naver_info('윤밀원'))
# Out:
# {'reviewcount': 'N/A', 'rate': 'N/A'}

# %%
def get_dining_info(restaurant): #다이닝코드 평점/별점/리뷰 가져오기
    
    dining_info = {}
    review_list = []
    
    #정규표현식 활용해 상호명에 있는 괄호 및 특수문자 제거
    regex = "\(.*\)|\s-\s.*"
    query = re.sub(regex, '', restaurant)
    
    url = 'https://www.diningcode.com/isearch.php?query=' + query
    web = requests.get(url).content
    source = BeautifulSoup(web, 'html.parser')
    
    #다이닝코드에 해당 식당이 없는 경우를 예상하여 try/except로 error 발생 시 'N/A'로 데이터 대체
    try:
        ul_tag = source.find('div', {'id':'div_rn'})
        li_tag = ul_tag.find('li')
        a_tag = li_tag.find('a')
        target_url = 'https://www.diningcode.com' + a_tag.attrs['href']
        target_url

        web_review = requests.get(target_url).content
        source_review = BeautifulSoup(web_review, 'html.parser')

        #평균 평점 꺼내기
        p_tag = source_review.find('p', {'class':'grade'})
        # p_tag
        review_point = int(p_tag.find('strong').get_text().replace('점',''))

        #평균 별점 꺼내기
        star_point = source_review.find('p', {'id':'lbl_star_point'}).get_text()
        star_point = star_point.replace("\n", "")
        star_point = float(star_point.replace('점',''))# 교체하다

        reviews = source_review.find_all('p',{'class':'review_contents btxt'})

        for review in reviews:
            review_list.append(re.sub('\n','',review.get_text()))

        dining_info['review_point'] = review_point
        dining_info['star_point'] = star_point
        dining_info['review'] = review_list
                               
    except:
        dining_info['review_point'] = 'N/A'
        dining_info['star_point'] = 'N/A'
        dining_info['review'] = 'N/A'
        
    return dining_info

# %%
print(get_dining_info('윤밀원'))
# Out:
# {'review_point': 67, 'star_point': 4.7, 'review': ['한글날 딸들을 데리고 분당 정자동 윤밀원으로  평양냉면 양곰탕 양지국수를 주문 평양냉면 면발 매밀함량 굿 식감 굿 육수는 동치미맛이 짙음 양지국수 먹어보지 못했던 특색있는 깊고 칼칼한 맛 굿 양 곰탕은 고기냄새는잘 잡았으나 국물은 그다지 깨끗하게 개운하지 못했음 다음엔 족발을 꼭 먹어봐야겠다 주택가에 위치해 가로수들이 단풍이들어 가을 정취를 도심에서 느낄수있어 더더욱 좋았던 가족나들이였습니다', '족발은 요즘 유행하는 스타일이고 제공되는 고수와 소스등으로 깔끔함. 평양냉면 역시 입문자가 먹어도 무난한 맛. 칼국수는 개인적으로 별로였습니다. 대기가 길지만 일단 입장하면 음식도 빨리 나오고 서비스도 좋아서 기분 좋게 식사 가능합니다. 주차는 근처 공영 주차장 추천합니다.', '첫번째 사진 : 양지칼국수두번째 사진 : 막국수세번째 사진 : 냉면칼국수 종류(양지칼국수, 칼국수)는 흰국물과 빨간국물 두가지 종류가 있다고 한다. 양지칼국수 흰국물로 시켰는데 순하고 담백한 맛이었다.막국수는 막국수보단 비빔냉면 같은 느낌이었다. 자극적이지 않으며 얘 또한 순하고 단백한 맛이었다.냉면은 평양냉면 스타일같고, 순한 맛이었다.총평 : 멀리갈게 아니라면 아주 괜찮은 선택지가 될거같다. 재방문의사 있음.양이 상당히 많다. 대식가가 아니라면 인원수보다 적게 시키는데 좋을거같으며, 족발을 시키는 경우에는 더 적게 시켜도 될거 같다. 전체적으로 고급지고 단백하고 순한 맛으로 어른들이 좋아할것 같고, 아이들도 칼국수와 막국수는 좋아할것 같다. 메뉴가 전체적으로 순한맛이라 막국수도 자극적이지 않아서 어린 아이들이 먹기 좋을거같다. 재방문의사 있음.', '근처에 공영 주차장이 있어서 거기에 차 대시면 됩니다. 막국수가 진짜 부드럽게 녹아요. 맛있어요. 족발도 잡내 없고 정말 맛있네요.', '나이와 상관없이 맛난 음식을 즐길수있는 행복한 장소']}

# %%
#음식을 키워드로 해당 음식 맛집리스트를 뽑아오는 function
def get_restaurant_data(menu):
    
    #만들어놓은 get_rest_list function으로 상호명 리스트 생성
    restaurant_list = get_rest_list(menu)
    print(len(restaurant_list),'개의 식당 검색 완료.')
    
    #DataFrame을 위한 빈 리스트 생성

    mango_name = []
    mango_rate = []
    mango_address = []
    mango_phone = []
    mango_kind = []
    mango_price = []
    naver_reviewcount = []
    naver_rate = []
    dining_review_point = []
    dining_star_point = []
    dining_review = []
    count = 1

    #상호명 리스트를 활용하여 각각의 점포의 정보를 망고플레이트, 네이버, 다이닝코드로 부터 받아오는 for loop
    for restaurant in restaurant_list:

        mango_info = get_mango_info(restaurant)
        naver_info = get_naver_info(restaurant)
        dining_info = get_dining_info(restaurant)
        #위에서 정의한 망고플레이트 음식점 정보를 하나의 dict로 가져옴

        #각각의 리스트에 고유 정보 추가
        mango_name.append(mango_info['name'])
        mango_rate.append(mango_info['rate'])
        mango_address.append(mango_info['address'])
        mango_phone.append(mango_info['phone'])
        mango_kind.append(mango_info['kind'])
        mango_price.append(mango_info['price'])
        naver_reviewcount.append(naver_info['reviewcount'])
        naver_rate.append(naver_info['rate'])
        dining_review_point.append(dining_info['review_point'])
        dining_star_point.append(dining_info['star_point'])
        dining_review.append(dining_info['review'])
        
        print(count,'번째 식당 정보 수집중...')
        count += 1
    
    #생성된 리스트로 pandas dataframe 생성
    restaurant_df = pd.DataFrame({'음식점':mango_name,
                         '망고평점': mango_rate,
                         '네이버평점': naver_rate,
                         '네이버리뷰수': naver_reviewcount,
                         '다이닝코드평점': dining_review_point,
                         '다이닝코드별점': dining_star_point,
                         '다이닝코드리뷰': dining_review,     
                         '주소': mango_address,
                         '전화': mango_phone,
                         '종류': mango_kind,
                         '가격': mango_price})
    
    #완성된 DataFrame으로 excel파일 생성
    restaurant_df.to_excel('{}맛집리스트_{}.xlsx'.format(menu,datetime.now().strftime('%y%m%d_%H%M')), index=False, encoding='utf-8')
    print(menu,'맛집리스트가 완성되었습니다.')
    print(restaurant_df.head())
    
    #완성된 Dataframe을 return
    return restaurant_df

# %%
get_restaurant_data('돈까스')
# Out:
# 40 개의 식당 검색 완료.
# 1 번째 식당 정보 수집중...
# 2 번째 식당 정보 수집중...
# 3 번째 식당 정보 수집중...
# 4 번째 식당 정보 수집중...
# 5 번째 식당 정보 수집중...
# 6 번째 식당 정보 수집중...
# 7 번째 식당 정보 수집중...
# 8 번째 식당 정보 수집중...
# 9 번째 식당 정보 수집중...
# 10 번째 식당 정보 수집중...
# 11 번째 식당 정보 수집중...
# 12 번째 식당 정보 수집중...
# 13 번째 식당 정보 수집중...
# 14 번째 식당 정보 수집중...
# 15 번째 식당 정보 수집중...
# 16 번째 식당 정보 수집중...
# 17 번째 식당 정보 수집중...
# 18 번째 식당 정보 수집중...
# 19 번째 식당 정보 수집중...
# 20 번째 식당 정보 수집중...
# 21 번째 식당 정보 수집중...
# 22 번째 식당 정보 수집중...
# 23 번째 식당 정보 수집중...
# 24 번째 식당 정보 수집중...
# 25 번째 식당 정보 수집중...
# 26 번째 식당 정보 수집중...
# 27 번째 식당 정보 수집중...
# 28 번째 식당 정보 수집중...
# 29 번째 식당 정보 수집중...
# 30 번째 식당 정보 수집중...
# 31 번째 식당 정보 수집중...
# 32 번째 식당 정보 수집중...
# 33 번째 식당 정보 수집중...
# 34 번째 식당 정보 수집중...
# 35 번째 식당 정보 수집중...
# 36 번째 식당 정보 수집중...
# 37 번째 식당 정보 수집중...
# 38 번째 식당 정보 수집중...
# 39 번째 식당 정보 수집중...
# 40 번째 식당 정보 수집중...
# 돈까스 맛집리스트가 완성되었습니다.
# 22                            대전시 서구 갈마동 876    042-485-5025         까스요리
# 23                       서울시 성동구 금호동1가 132-6   010-9780-2352    정통일식/일반일식
# 24                    서울시 서초구 방배동 766-4 103호   070-8777-3679         까스요리
# 25                       서울시 서대문구 대현동 142-25     02-362-4295         기타한식
# 26                         대전시 서구 탄방동 691 1F    042-477-3700         기타한식
# 27                         서울시 서초구 잠원동 25-12     02-515-7057         기타한식
# 28                경기도 안양시 만안구 안양동 873-174 1F   010-3432-5143         까스요리
# 29  경기도 용인시 기흥구 구갈동 227-34 지웰푸르지오 상가동 110-1호    031-287-7851         까스요리
# 30                         서울시 종로구 통인동 154-8    02-3210-0113     라멘/소바/우동
# 31           경기도 고양시 일산동구 장항동 868 2F 제비-255호    031-901-9463         까스요리
# 32                              서울시 중구 다동 92     02-772-9023         까스요리
# 33                       경기도 가평군 설악면 가일리 183    031-585-3386       닭/오리요리
# 34                        서울시 중구 무학동 11-2 1F    02-2235-7501         기타한식
# 35                            대전시 서구 갈마동 711    042-485-3777         기타한식
# 36                   서울시 성동구 성수동1가 16-8 102호     02-499-0323         까스요리
# 37                         서울시 강동구 성내동 12-38     02-472-1418         기타한식
# 38                         서울시 광진구 자양동 232-4     02-452-3574      탕/찌개/전골
# 39                         서울시 동작구 사당동 88-18     02-532-6670       국수/면요리
#
#          가격
# 0    만원-2만원
# 1    만원-2만원
# 2     만원 미만
# 3    만원-2만원
# 4     만원 미만
# 5    만원-2만원
# 6    만원-2만원
# 7     만원 미만
# 8     만원 미만
# 9     만원 미만
# 10   만원-2만원
# 11   만원-2만원
# 12   4만원 이상
# 13    만원 미만
# 14  2만원-3만원
# 15   만원-2만원
# 16    만원 미만
# 17   만원-2만원
# 18   만원-2만원
# 19   만원-2만원
# 20    만원 미만
# 21    만원 미만
# 22   만원-2만원
# 23   만원-2만원
# 24   만원-2만원
# 25    만원 미만
# 26    만원 미만
# 27   만원-2만원
# 28   만원-2만원
# 29    만원 미만
# 30    만원 미만
# 31   만원-2만원
# 32   만원-2만원
# 33  2만원-3만원
# 34    만원 미만
# 35    만원 미만
# 36   만원-2만원
# 37    만원 미만
# 38   만원-2만원
# 39    만원 미만

# %%
get_restaurant_data('카레')
# Out:
# 40 개의 식당 검색 완료.
# 1 번째 식당 정보 수집중...
# 2 번째 식당 정보 수집중...
# 3 번째 식당 정보 수집중...
# 4 번째 식당 정보 수집중...
# 5 번째 식당 정보 수집중...
# 6 번째 식당 정보 수집중...
# 7 번째 식당 정보 수집중...
# 8 번째 식당 정보 수집중...
# 9 번째 식당 정보 수집중...
# 10 번째 식당 정보 수집중...
# 11 번째 식당 정보 수집중...
# 12 번째 식당 정보 수집중...
# 13 번째 식당 정보 수집중...
# 14 번째 식당 정보 수집중...
# 15 번째 식당 정보 수집중...
# 16 번째 식당 정보 수집중...
# 17 번째 식당 정보 수집중...
# 18 번째 식당 정보 수집중...
# 19 번째 식당 정보 수집중...
# 20 번째 식당 정보 수집중...
# 21 번째 식당 정보 수집중...
# 22 번째 식당 정보 수집중...
# 23 번째 식당 정보 수집중...
# 24 번째 식당 정보 수집중...
# 25 번째 식당 정보 수집중...
# 26 번째 식당 정보 수집중...
# 27 번째 식당 정보 수집중...
# 28 번째 식당 정보 수집중...
# 29 번째 식당 정보 수집중...
# 30 번째 식당 정보 수집중...
# 31 번째 식당 정보 수집중...
# 32 번째 식당 정보 수집중...
# 33 번째 식당 정보 수집중...
# 34 번째 식당 정보 수집중...
# 35 번째 식당 정보 수집중...
# 36 번째 식당 정보 수집중...
# 37 번째 식당 정보 수집중...
# 38 번째 식당 정보 수집중...
# 39 번째 식당 정보 수집중...
# 40 번째 식당 정보 수집중...
# 카레 맛집리스트가 완성되었습니다.
#                음식점 망고평점 네이버평점 네이버리뷰수 다이닝코드평점 다이닝코드별점  \
# 0              마루심  4.7   4.4    777      73     4.1
# 1             우미노미  4.7   N/A    N/A      52     4.6
# 2               카레  4.7   N/A    N/A      34     4.3
# 3             공기식당  4.5   N/A    N/A      60     3.6
# 4  요시즈카우나기야/吉塚うなぎ屋  N/A   N/A    N/A      25       5
#
#                                              다이닝코드리뷰  \
# 0  [장어덮밥이 정말 맛있습니다. 정갈한 나고야식 덮밥입니다. 배부르게 점심을 먹고 싶...
# 1  [고된 일하고 나서 내가 내자신에게 정말 성대한 식사를 제공하고 싶을때 방문하는 집...
# 2  [12시 오픈인데 들어가려면 일단 11시 반 즈음부터 줄을 서야 맛볼 수가 있는 곳...
# 3  [서촌에 위치한 카레 전문점 공기식당입니다. 대표 메뉴인 새우버터카레와 새우키마커리...
# 4  [장어덮밥 먹으러 가는 곳! 히쯔마부시보다 우나쥬가 장어양이 더 많긴 하지만 오차즈...
#
#                             주소             전화           종류       가격
# 0       서울시 서초구 반포동 54-10 청구빌딩    02-592-8998  돈부리/일본카레/벤토  3만원-4만원
# 1  서울시 영등포구 당산동4가 31-2 신우빌딩 1F  070-4367-7116  돈부리/일본카레/벤토   만원-2만원
# 2       서울시 서초구 반포동 54-10 청구빌딩    02-592-8998  돈부리/일본카레/벤토  3만원-4만원
# 3          서울시 종로구 통인동 46-5 1F  010-4750-0930  돈부리/일본카레/벤토    만원 미만
# 4                          N/A            N/A          N/A      N/A
#                 음식점 망고평점 네이버평점 네이버리뷰수 다이닝코드평점 다이닝코드별점  \
# 0               마루심  4.7   4.4    777      73     4.1
# 1              우미노미  4.7   N/A    N/A      52     4.6
# 2                카레  4.7   N/A    N/A      34     4.3
# 3              공기식당  4.5   N/A    N/A      60     3.6
# 4   요시즈카우나기야/吉塚うなぎ屋  N/A   N/A    N/A      25       5
# 5          마루심(마포점)  4.5   4.4    777      73     4.1
# 6        멘야하나비(신사점)  4.4  4.51    286      78     4.1
# 7                예티  4.4   N/A    N/A      41     4.2
# 8                고옥  4.4   N/A    N/A      75     4.4
# 9        홋카이도부타동스미레  4.4   N/A    N/A      38       5
# 10         데카망(휴업중)  N/A   N/A    N/A      35     4.4
# 11              요우란  4.4   N/A    N/A     N/A     N/A
# 12               온정  4.4   N/A    N/A      22       5
# 13           타이가텐푸라  4.4   N/A    N/A      39     4.4
# 14          오사카카레콘유  4.4   N/A    N/A      45     4.3
# 15            텐동요츠야  4.3  4.34    937      81     4.3
# 16            멘야하나비  4.4  4.51    286      78     4.1
# 17               깔리  4.3   N/A    N/A      77     4.2
# 18              우마텐  4.3   N/A    N/A      58     4.2
# 19              부타이  4.4   N/A    N/A      57     3.8
# 20      에베레스트(동대문점)  4.3   N/A    N/A      78     4.4
# 21              가츠오  4.3   N/A    N/A      54     4.2
# 22             교양식사  4.3   N/A    N/A      51       4
# 23            도요스6가  4.3  4.59    236      51     4.1
# 24              텐동한  4.3   N/A    N/A      43     4.5
# 25              현우동  4.3  4.41    386      50     4.3
# 26            라하노카레  4.3   N/A    N/A      25     3.5
# 27         포탈라(종로점)  4.3   N/A    N/A      24       0
# 28  후라토식당(아브뉴프랑판교점)  N/A   N/A    N/A      59     4.7
# 29             운멜로랩  4.3  4.41    467      32     4.3
# 30        이치젠(망원본점)  4.2   N/A    N/A      76     4.4
# 31          BARN110  4.2  4.48    366     N/A     N/A
# 32            후라토식당  4.3   N/A    N/A      59     4.7
# 33        오복수산(도산점)  4.2  4.44    515      63     4.4
# 34          멘야코노하카레  4.2   N/A    N/A      33     4.3
# 35              사쿠텐  4.2   N/A    N/A     N/A     N/A
# 36              이코이  4.2   N/A    N/A      26       5
# 37          스아게/すあげ  N/A   N/A    N/A      50     4.1
# 38          주간소바식당산  4.2  4.48    234      43     4.2
# 39              하이쿠  4.2   N/A    N/A      35     4.1
#
#                                               다이닝코드리뷰  \
# 0   [장어덮밥이 정말 맛있습니다. 정갈한 나고야식 덮밥입니다. 배부르게 점심을 먹고 싶...
# 1   [고된 일하고 나서 내가 내자신에게 정말 성대한 식사를 제공하고 싶을때 방문하는 집...
# 2   [12시 오픈인데 들어가려면 일단 11시 반 즈음부터 줄을 서야 맛볼 수가 있는 곳...
# 3   [서촌에 위치한 카레 전문점 공기식당입니다. 대표 메뉴인 새우버터카레와 새우키마커리...
# 4   [장어덮밥 먹으러 가는 곳! 히쯔마부시보다 우나쥬가 장어양이 더 많긴 하지만 오차즈...
# 5   [장어덮밥이 정말 맛있습니다. 정갈한 나고야식 덮밥입니다. 배부르게 점심을 먹고 싶...
# 6   [진짜 지금까지 먹었던 맛집 중에 최고였음 (별 5개가 부족할 정도) 소바 처음 먹...
# 7   [회식으로 방문해봤다커리를 다양하게 먹어보고싶었는데 인도분이 말을 잘못이해하셔서 양...
# 8   [깔끔한 히츠마부시 장어덮밥집입니다 큰게 양이 많고 좋고 브레이크타임 있습니다. 인...
# 9   [먹고 감동받은 부타동집입니다. 신촌에 위치한 작은 가게이고 ㄷ자 테이블로 되어있어...
# 10  [- 친구 추천으로 방문한 식당 - 저녁 6시 넘어서 방문. 주문 후에 튀기기 시작...
# 11                                                N/A
# 12  [맛있습니다 가성비 좋고요 마라마파두부를 먹었는데 마라러버로써 대만족 재방문의사 있어요]
# 13  [텐동으로 유명한 타이가에 다녀왔습니다. 가게 입구 좌측에 키오스크 있는데 거기서 ...
#
#          가격
# 0   3만원-4만원
# 1    만원-2만원
# 2   3만원-4만원
# 3     만원 미만
# 4       N/A
# 5   3만원-4만원
# 6    만원-2만원
# 7    만원-2만원
# 8   2만원-3만원
# 9   주차공간없음
# 10      N/A
# 11  주차공간없음
# 12   만원-2만원
# 13   만원-2만원
# 14   만원-2만원
# 15    만원 미만
# 16   만원-2만원
# 17   만원-2만원
# 18   만원-2만원
# 19    만원 미만
# 20   만원-2만원
# 21   만원-2만원
# 22  2만원-3만원
# 23   만원-2만원
# 24    만원 미만
# 25   만원-2만원
# 26    만원 미만
# 27   만원-2만원
# 28      N/A
# 29   만원-2만원
# 30   만원-2만원
# 31   만원-2만원
# 32   만원-2만원
# 33   만원-2만원
# 34    만원 미만
# 35   만원-2만원
# 36   만원-2만원
# 37      N/A
# 38    만원 미만
# 39   만원-2만원

# %%
get_restaurant_data('삼겹살')
# Out:
# 40 개의 식당 검색 완료.
# 1 번째 식당 정보 수집중...
# 2 번째 식당 정보 수집중...
# 3 번째 식당 정보 수집중...
# 4 번째 식당 정보 수집중...
# 5 번째 식당 정보 수집중...
# 6 번째 식당 정보 수집중...
# 7 번째 식당 정보 수집중...
# 8 번째 식당 정보 수집중...
# 9 번째 식당 정보 수집중...
# 10 번째 식당 정보 수집중...
# 11 번째 식당 정보 수집중...
# 12 번째 식당 정보 수집중...
# 13 번째 식당 정보 수집중...
# 14 번째 식당 정보 수집중...
# 15 번째 식당 정보 수집중...
# 16 번째 식당 정보 수집중...
# 17 번째 식당 정보 수집중...
# 18 번째 식당 정보 수집중...
# 19 번째 식당 정보 수집중...
# 20 번째 식당 정보 수집중...
# 21 번째 식당 정보 수집중...
# 22 번째 식당 정보 수집중...
# 23 번째 식당 정보 수집중...
# 24 번째 식당 정보 수집중...
# 25 번째 식당 정보 수집중...
# 26 번째 식당 정보 수집중...
# 27 번째 식당 정보 수집중...
# 28 번째 식당 정보 수집중...
# 29 번째 식당 정보 수집중...
# 30 번째 식당 정보 수집중...
# 31 번째 식당 정보 수집중...
# 32 번째 식당 정보 수집중...
# 33 번째 식당 정보 수집중...
# 34 번째 식당 정보 수집중...
# 35 번째 식당 정보 수집중...
# 36 번째 식당 정보 수집중...
# 37 번째 식당 정보 수집중...
# 38 번째 식당 정보 수집중...
# 39 번째 식당 정보 수집중...
# 40 번째 식당 정보 수집중...
# 삼겹살 맛집리스트가 완성되었습니다.
#          음식점  망고평점 네이버평점 네이버리뷰수 다이닝코드평점 다이닝코드별점  \
# 0         길목   4.6   N/A    N/A      62       4
# 1       김진목삼   4.6  4.69    248      55     4.9
# 2  육전식당(4호점)   4.5   4.4    738      76     4.2
# 3       한림돈가   4.4   N/A    N/A      64     4.1
# 4  육전식당(1호점)   4.4   4.4    738      76     4.2
#
#                                              다이닝코드리뷰  \
# 0  [예쁘장한 삼겹살집이라고 정의하고 싶네요. 실내가 아기자기합니다. 여성분들만의 모임...
# 1  [주차할 수 없는 서촌 골목에 위치. 1호점과 2호점이 아주 가깝게 붙어있는데 두 ...
# 2  [이 정도 돼지고기면 옷에 냄새 다 배겨도 인정이다. 청계천 나들이 필수 코스라고 ...
# 3  [칼집 넣고 초벌한 삼겹살이 달달하니 맛나요. 메뉴 중 삼겹살 특히 추천. 고사리와...
# 4  [이 정도 돼지고기면 옷에 냄새 다 배겨도 인정이다. 청계천 나들이 필수 코스라고 ...
#
#                            주소            전화    종류       가격
# 0            서울시 강남구 삼성동 58-6   02-518-9710  고기요리   만원-2만원
# 1             서울시 종로구 필운동 154   02-929-2929  고기요리   만원-2만원
# 2  서울시 강남구 역삼동 823-10 신도빌딩 1F  02-3452-6373  고기요리  2만원-3만원
# 3      서울시 서대문구 창천동 52-124 1F   02-338-6604  고기요리   만원-2만원
# 4          서울시 동대문구 신설동 104-3  02-2253-6373  고기요리   만원-2만원
#             음식점  망고평점 네이버평점 네이버리뷰수 다이닝코드평점 다이닝코드별점  \
# 0            길목   4.6   N/A    N/A      62       4
# 1          김진목삼   4.6  4.69    248      55     4.9
# 2     육전식당(4호점)   4.5   4.4    738      76     4.2
# 3          한림돈가   4.4   N/A    N/A      64     4.1
# 4     육전식당(1호점)   4.4   4.4    738      76     4.2
# 5            꿉당   4.4   4.5    321      41       4
# 6           남영돈   4.4   N/A    N/A      61     4.5
# 7    홋카이도부타동스미레   4.4   N/A    N/A      38       5
# 8           숙성도   4.8   N/A    N/A      60     4.4
# 9         일품생고기   4.4   N/A    N/A     N/A     N/A
# 10         분당그릴   4.4   N/A    N/A      24       5
# 11        금돼지식당   4.3   N/A    N/A      77     4.2
# 12           몽탄   4.3   N/A    N/A      63     4.3
# 13    명봉샤브샤브양꼬치   4.3   N/A    N/A      29     3.1
# 14  하이디라오(서초지점)   4.3   N/A    N/A      67     4.1
# 15       땅코참숯구이   4.3   N/A    N/A      78     4.5
# 16     나정순할매쭈꾸미   4.3   N/A    N/A      65     4.1
# 17      양지말화로구이   4.3  4.24    533      72     4.3
# 18    한림돈가(서교점)   4.3   N/A    N/A      64     4.1
# 19        광화문뚝감   4.3   N/A    N/A      61     4.3
# 20         양인환대   4.3  4.59    182      58     4.4
# 21       투뿔등심고담   4.3  4.18    161      50       4
# 22           해몽   4.3   N/A    N/A      56     4.6
# 23         서울갈비   4.3   N/A    N/A      49       4
# 24       노원목고기집   4.3   N/A    N/A      37     3.9
# 25         고깃집열   4.3   4.4    124      29     4.6
# 26       효자동목고기   4.3   N/A    N/A      36       4
# 27          고명집   4.3  4.13     60      52     3.9
# 28           돈멜   4.3  4.66    318      29       5
# 29         신흥식당   4.3   N/A    N/A      23       5
# 30         운산식당   4.3   N/A    N/A      20     3.1
# 31         을지육점   4.3   N/A    N/A      45     4.4
# 32         큰손식당   4.3   N/A    N/A      50       5
# 33     삼육가(야탑점)   4.3   N/A    N/A      53     4.2
# 34   제주도그릴(연희점)   4.3   N/A    N/A      28     4.2
# 35   숙달돼지(문래본점)   4.2   N/A    N/A      51     4.4
# 36          853   4.2   N/A    N/A      41       4
# 37       땅코참숯구이   4.3   N/A    N/A      78     4.5
# 38  교대이층집(광화문점)   4.2   N/A    N/A      61       4
# 17           강원도 홍천군 홍천읍 하오안리 1014          033-435-7533        고기요리   만원-2만원
# 18               서울시 마포구 서교동 465-7           02-336-6604        고기요리   만원-2만원
# 19              서울시 종로구 당주동 128-14           02-722-5894     탕/찌개/전골   만원-2만원
# 20              서울시 강남구 도곡동 954-16           02-577-1014    스테이크/바베큐  2만원-3만원
# 21      서울시 강남구 삼성동 154-10 융전빌딩 B1           02-568-7710        고기요리  3만원-4만원
# 22              서울시 강남구 논현동 107-11           02-515-6080        고기요리   만원-2만원
# 23             서울시 관악구 신림동 1410-17           02-885-7610        고기요리   만원-2만원
# 24              서울시 노원구 상계동 349-24           02-932-6599        고기요리   만원-2만원
# 25          서울시 서초구 서초동 1330-14 2F           02-586-7710        고기요리   만원-2만원
# 26                  서울시 종로구 관철동 26           02-737-7989        고기요리   만원-2만원
# 27            서울시 관악구 봉천동 858-1 2F           02-883-5988      닭/오리요리   만원-2만원
# 28           경기도 성남시 분당구 정자동 66-10          031-718-0092        고기요리   만원-2만원
# 29               서울시 강남구 대치동 908-2           02-555-8157        고기요리  2만원-3만원
# 30              제주 제주시 삼도이동 1113-1          064-758-0330        고기요리  2만원-3만원
# 31              서울시 중구 을지로3가 321-2          02-2269-3398        고기요리   만원-2만원
# 32          경기도 용인시 기흥구 공세동 390-15          031-287-3383        고기요리   만원-2만원
# 33  경기도 성남시 분당구 야탑동 361-2 우송프라자 1F          031-706-3637        고기요리   만원-2만원
# 34              서울시 서대문구 연희동 188-5           02-324-3724        고기요리   만원-2만원
# 35         서울시 영등포구 양평동1가 13-18 1F         070-4205-8433        고기요리   만원-2만원
# 36               서울시 종로구 관훈동 84-23         070-8832-0853        고기요리   만원-2만원
# 37                 서울시 강남구 역삼동 835           02-562-2009        고기요리   만원-2만원
# 38                 서울시 종로구 견지동 110           02-723-6692        고기요리   만원-2만원
# 39              서울시 강서구 화곡동 782-12         070-7641-2008        고기요리   만원-2만원

# %%
donkatsu_df = get_restaurant_data('돈까스')
# Out:
# 40 개의 식당 검색 완료.
# 1 번째 식당 정보 수집중...
# 2 번째 식당 정보 수집중...
# 3 번째 식당 정보 수집중...
# 4 번째 식당 정보 수집중...
# 5 번째 식당 정보 수집중...
# 6 번째 식당 정보 수집중...
# 7 번째 식당 정보 수집중...
# 8 번째 식당 정보 수집중...
# 9 번째 식당 정보 수집중...
# 10 번째 식당 정보 수집중...
# 11 번째 식당 정보 수집중...
# 12 번째 식당 정보 수집중...
# 13 번째 식당 정보 수집중...
# 14 번째 식당 정보 수집중...
# 15 번째 식당 정보 수집중...
# 16 번째 식당 정보 수집중...
# 17 번째 식당 정보 수집중...
# 18 번째 식당 정보 수집중...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-15466cad0ca2> in <module>
# ----> 1 donkatsu_df = get_restaurant_data('돈까스')
#
# <ipython-input-19-e857e4634090> in get_restaurant_data(menu)
#      25
#      26         mango_info = get_mango_info(restaurant)
# ---> 27         naver_info = get_naver_info(restaurant)
#      28         dining_info = get_dining_info(restaurant)
#      29         #위에서 정의한 망고플레이트 음식점 정보를 하나의 dict로 가져옴
#
# <ipython-input-15-e4fbea1b6757> in get_naver_info(restaurant)
#       8
#       9     url = "https://search.naver.com/search.naver?where=nexearch&sm=tab_jum&query=" + query
# ---> 10     web = requests.get(url).content
#      11     source = BeautifulSoup(web, 'html.parser')
#      12
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     626
#     627         if not stream:
# --> 628             r.content
#     629
#     630         return r
#
# ~\Anaconda3\lib\site-packages\requests\models.py in content(self)
#     753                     self._content = None
#     754                 else:
# --> 755                     self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     756
#     757             except AttributeError:
#
# ~\Anaconda3\lib\site-packages\requests\models.py in generate()
#     674             if hasattr(self.raw, 'stream'):
#     675                 try:
# --> 676                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     677                         yield chunk
#     678                 except ProtocolError as e:
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in stream(self, amt, decode_content)
#     351         """
#     352         if self.chunked:
# --> 353             for line in self.read_chunked(amt, decode_content=decode_content):
#     354                 yield line
#     355         else:
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     503                 if self.chunk_left == 0:
#     504                     break
# --> 505                 chunk = self._handle_chunk(amt)
#     506                 decoded = self._decode(chunk, decode_content=decode_content,
#     507                                        flush_decoder=False)
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in _handle_chunk(self, amt)
#     472             returned_chunk = value
#     473         else:  # amt > self.chunk_left
# --> 474             returned_chunk = self._fp._safe_read(self.chunk_left)
#     475             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     476             self.chunk_left = None
#
# ~\Anaconda3\lib\http\client.py in _safe_read(self, amt)
#     608         s = []
#     609         while amt > 0:
# --> 610             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     611             if not chunk:
#     612                 raise IncompleteRead(b''.join(s), amt)
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# 임시
import requests # from urllib.request import urlopen
from bs4 import BeautifulSoup # HTTP Response -> HTML 

import pandas as pd

from datetime import datetime


from selenium import webdriver
import time 
import re #정규 표현식 활용

# %%
import numpy as np
# import pandas as pd

# %%
df = pd.read_excel('카레.xlsx', encoding='utf-8')
df.head()
# Out:
#                음식점  망고평점  네이버평점  네이버리뷰수  다이닝코드평점  다이닝코드별점  \
# 0              마루심   4.7    4.4   776.0     73.0      4.1
# 1             우미노미   4.7    NaN     NaN     52.0      4.6
# 2               카레   4.7    NaN     NaN     34.0      4.3
# 3             공기식당   4.5    NaN     NaN     60.0      3.6
# 4  요시즈카우나기야/吉塚うなぎ屋   NaN    NaN     NaN     25.0      5.0
#
#                                              다이닝코드리뷰  \
# 0  ['장어덮밥이 정말 맛있습니다. 정갈한 나고야식 덮밥입니다. 배부르게 점심을 먹고 ...
# 1  ['고된 일하고 나서 내가 내자신에게 정말 성대한 식사를 제공하고 싶을때 방문하는 ...
# 2  ['12시 오픈인데 들어가려면 일단 11시 반 즈음부터 줄을 서야 맛볼 수가 있는 ...
# 3  ["서촌에 위치한 카레 전문점 공기식당입니다. 대표 메뉴인 새우버터카레와 새우키마커...
# 4  ['장어덮밥 먹으러 가는 곳! 히쯔마부시보다 우나쥬가 장어양이 더 많긴 하지만 오차...
#
#                             주소             전화           종류       가격
# 0       서울시 서초구 반포동 54-10 청구빌딩    02-592-8998  돈부리/일본카레/벤토  3만원-4만원
# 1  서울시 영등포구 당산동4가 31-2 신우빌딩 1F  070-4367-7116  돈부리/일본카레/벤토   만원-2만원
# 2       서울시 서초구 반포동 54-10 청구빌딩    02-592-8998  돈부리/일본카레/벤토  3만원-4만원
# 3          서울시 종로구 통인동 46-5 1F  010-4750-0930  돈부리/일본카레/벤토    만원 미만
# 4                          NaN            NaN          NaN      NaN

# %%
# series를 list로 
# 돈까스 다이닝코드 리뷰

donkatsu_dining_review = df['다이닝코드리뷰'].dropna()

donkatsu_dining_review = list(donkatsu_dining_review)
donkatsu_dining_review
# Out:
# ["['장어덮밥이 정말 맛있습니다. 정갈한 나고야식 덮밥입니다. 배부르게 점심을 먹고 싶은날 가면 좋더라구요', '깔끔한 장어정식. 특별한날 몸보신용으로 먹기에 적당하다. 기분좋은 배부름이었음. 블로그 후기들이 평이 엄청 좋아서 기대를 많이했는데 이게 그렇게 특별한건가 싶기는 함..', '•반포에 위치한 히쯔마부시 맛집 국내산 민물장어에 일본식 나고야 요리법을 접목하여 만든 요리입니다.사이즈는 미니, 상 (장어 1마리), 특 (장어 1마리반) 대개 여성분들은 상, 장어 좋아하시는 남성분들은 특 드시더라구요.맛은 숯불향 가득한 장어와 간이 잘 베인 밥이 정말 잘 어울려요. 메뉴판에 명시된것처럼 먹는법을 다 해보니색다른 맛으로 다 맛있어요! 저는 특히 마지막에 육수를 넣어 먹는 오차즈께가 가장 맛있더라구요. 사이드메뉴도 정갈하게 함께 나와서 배부르게 드실 수있어요. 저는 같이 나온 계란찜도 맛있더라구요! 발렛 가능해요.', '어버이
 특히 당신이 텐동을 사랑한다면 이집은 망리단에 있어 당신의 뇌리에 랜드마크를 세우게 될 것이다.', '망원동 다이닝코드 추천 TOP3 식당줄서기 성공으로 첫번째 그룹으로 입성해서 텐동과 바질토마토를 주문했습니다. 텐동은 정성의 맛이라고 표현하겠습니다. 차가운 튀김옷을 입히기위해 얼음물위에 볼을 올린뒤 기름으로 퐁당, 바질토마토의 에피타이저와 마무리로 딱입니다.', '망원동 상권의 유명한 텐동집으로 웨이팅이 상당히 길기 때문에 식사 시간에는 일찍 서둘러야 한다웨이팅 리스트에 이름을 올려놓고 매장 앞에서 대기하지 않으면 두세번 호명한 후 삭제하니 주의(자리를 지킬 것)내부에는 14~15석 정도의 바 테이블 형태의 자리 뿐이지만 메뉴가 텐동과 사이드메뉴 위주로 간단해서 회전은 제법 되는 것 같다기본 메뉴인 이체젠텐동(9.0천원/새우2,오징어,연근,가지,꽈리고추,온천계란,김)과 아나고텐동(13.0천원/장어,새우2,연근,가지,꽈리고추,온천계란,김), 인기 사이드메뉴인 바질토마토(1.0천원)을 주문했는데즉석에서 바로 튀겨 내는 튀김은 바삭하고 맛있었고바닥에 깔린 간장양념이 과하지 않아 좋았다밥의 양 자체가 다른 곳보다 적은 편이라 성인 남자 기준 양은 조금 모자랄 수 있다사이드로 인기 메뉴인 바질토마토를 곁들여 먹는걸 추천한다', '유명해서 줄서서 들어감 가격이 좀 비싸다고 느낀다 맛은 있다', '평일도 웨이팅 하는 맛집입니다대기자명단 작성해야합니다퀄리티 대박이고요살짝 양이 모자라긴 한데 정성에 비하면 가성비가 매우 좋습니다테이블식이고 새우가 진짜 맛있었어요ㅠ심지어 유자 향나는 단무지도 맛있어요']",
#  "['깔끔하고 차분한 분위기예요. 가성비가 좋고 맛도 괜찮았어요. 돈까스는 구우면서 먹을 수 있는데 괜찮았고, 새우튀김카레랑 오므라이스도 다 맛있었어요. 간만에 찾은 괜찮은 집.', 'ㅇ 최근 먹은 규카츠 중에 제일 괜찮았던 곳ㅇ 구성은 심플하지만 고기 상태가 굉장히 좋았다ㅇ 밥이랑 양배추는 양이 약간 적은 느낌ㅇ 주문했던 규카츠랑 스테끼 정식 둘 다 맛있었고 이 정도면 다른 메뉴들도 잘 나올 것 같다ㅇ 재방문 의사 있음', '일식을 좋아하는 친구랑 같이 갔습니다.원래는 규카츠만 먹으려고 했는데바람이 꽤 차가워서 규카츠 더블에 우동까지 주문했고여기에는 술이 빠질 수 없다며 하이볼까지 주문해 버렸습니다.ㅋㅋ일단 일요일 저녁 6시에 도착했음에도 10분 정도 대기해야 했었으니평일 점심에는 대기가 엄청 길 수도 있겠다는 생각이 들었습니다.근처에 회사가 많다 보니 평일이 주말보다 더 붐빌 듯해요.식당은 그리 넓지 않습니다.테이블 간격도 좁은 편이었고조명은 약간 어두운 듯한 간접 조명이어서분위기는 괜찮았던 것 같습니다.그리고 마치 그냥 고깃집처럼 고기 굽는 냄새가 생각보다는 많이 났습니다.^^;주문하고 10분 이내에 메뉴는 준비되어 나왔던 것 같습니다.규카츠
#  "['친절하고 맛있습니다. 밥의 소스가 많이 짜지도 않아서 묘하게 참치랑 먹으면 1그릇이 순삭']",
#  "['원래는 상수에있는 스프카레진을 자주갔었는데 영업안하신다고 하더라구요 ㅠㅠ 우연히 스아게를 알게되어 방문했습니다삿포로에 실제로 가게가 있다고 하네요본점인갚..매장 깨끗하고 자리도 널널해요 다만 서버하시는분이 한명이라 정신없어보였습니다 카레는 약간 묽은 느낌이였는데 맛은있었어요야채가 좀더 다양하지 않은게 아쉽네요', '추울 때 먹기 딱 좋은 국물 자작한 카레. 재료가 다양하고 실하게 들어있어서 굳이 추가 토핑 안해도 배부르게 먹을 수 있어요', '삿포로에서 먹던 맛 그래도 느낄수 있습니다. 추운날 먹기 딱 좋은 음식. 토핑 식감이 살아 있어서 좋아요!!반찬이 없는게 아쉽긴 하지만 메인메뉴만으로 충분해요', '삿포로식이라는데 정말 맛있게 먹었다. 야채 카레에 스페셜 스프, 고기까지 추가해 먹었더니 16000원. 독특하다.', '토핑이 삿포로에서 먹었던것보다는 약간 덜 실한것 같긴 했지만 스프는 맛이 괜찮았습니다. 가장 매운맛으로 주문했으나 제입맛엔 그렇게 맵지는 않았고 칼칼한 정도였습니다. 추운날 가기 좋을것 같아 재방문의사 있습니다.']",
#  "['검색해서 간곳은 아니고 식당가 있는곳에 조용한 분위기라 방문했는데 맛은 무난했고 가격도 비싸지 않고 괜찮았다.특별히 여기만을 위해서 시간내서 올 정도는 아니지만 경복궁역 근처에 방문했을때 무난하게 먹을 수 있을 만한 곳이다.', '식당 내부는 깔끔했고 조용했다. 혼자 앉을 수 있는 자리도 마련되어 있어 혼밥하기 좋을 것 같다. 돈카츠는 맛있지만 계속 먹다보면 비계부분이 특히 물렸다. 비계는 돈카츠의 3분의 1정도 있었고 소바는 깔끔했고 맛있었다.', '길거리에서 봤을 땐 눈에 띄지않을 수 있는 차분한 외관. 그리고 인테리어 역시 일본 분위기의 정갈한 느낌임. 소바나 돈까스 모두 평균 이상이었음. 좌석은 많지 않은 편.', '소바 맛집이라 해서갔는데 맛있어요!! 미니 돈가스도 먹었는데 돈가스도 진짜맛있네용 또갈게용', '샐러드소바 깔끔하게 맛있었음! 정식이라 돈까스도 같이 맛볼수잇어서 조음! 고급스럽진 않디만 간단히 식사하기 괜찮음 양이 많딘 않음']"]

# %%
donkatsu_dining_review = ' '.join(donkatsu_dining_review)
donkatsu_dining_review[:1000]
# Out:
# "['장어덮밥이 정말 맛있습니다. 정갈한 나고야식 덮밥입니다. 배부르게 점심을 먹고 싶은날 가면 좋더라구요', '깔끔한 장어정식. 특별한날 몸보신용으로 먹기에 적당하다. 기분좋은 배부름이었음. 블로그 후기들이 평이 엄청 좋아서 기대를 많이했는데 이게 그렇게 특별한건가 싶기는 함..', '•반포에 위치한 히쯔마부시 맛집 국내산 민물장어에 일본식 나고야 요리법을 접목하여 만든 요리입니다.사이즈는 미니, 상 (장어 1마리), 특 (장어 1마리반) 대개 여성분들은 상, 장어 좋아하시는 남성분들은 특 드시더라구요.맛은 숯불향 가득한 장어와 간이 잘 베인 밥이 정말 잘 어울려요. 메뉴판에 명시된것처럼 먹는법을 다 해보니색다른 맛으로 다 맛있어요! 저는 특히 마지막에 육수를 넣어 먹는 오차즈께가 가장 맛있더라구요. 사이드메뉴도 정갈하게 함께 나와서 배부르게 드실 수있어요. 저는 같이 나온 계란찜도 맛있더라구요! 발렛 가능해요.', '어버이날 이라서 아이들이 선물을 해서 점심으로 마루심에 예약하고 갔더니 룸으로 해줘서 조용하게 밥을 먹을수 있었다언제가도 한결같이 맛있다그냥 먹어도 맛있고 물에 말아서 먹어도 비벼서 먹어도 다 맛있다예전에는 그냥 와도 됐는데 요즘은 손님들이 많아서 예약을 하고 가야 기다리지 않고 식사할수 있는거같다', '일본에서 장어덮밥을 맛있게 먹어서 가봤는데소스맛은 있지만 너무 타서 맛이 반감돼요밥은 진짜 맛있습니다.'] ['고된 일하고 나서 내가 내자신에게 정말 성대한 식사를 제공하고 싶을때 방문하는 집.1.5만원에 카이센동나 스끼야끼를 깔끔히 대접받을 수 있어요바자리가 잘 되어있어서 혼밥하기에도 적절한 아주 좋은 집입니다카이센동은 밥에 조리가 매우 잘되어있어 어느 곳은 퍼먹어도 맛나요단새우,참치,연어,관자,오징어,시소잎,계란말이,연어알,날치알이 올려져있습니다자왕무시와 김과 절임메뉴,된장국 제공됩니다평일 점심에도 줄을 서서 먹는 이유가 납득되는 메뉴가 나옵니다비린맛이 없이 해산물이 모두 신선하고 단맛이 납니다계절에따라 올려지는 메뉴는 달라진다고 합니다', "

# %%
len(donkatsu_dining_review)
# Out:
# 28090

# %%
# 이모티콘 없애기

# import re

TEXT = 'donkatsu_dining_review'

EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
TEXT_refine = EMOJI.sub(r'', TEXT)

# %%
donkatsu_dining_review1 = donkatsu_dining_review[:5000]
donkatsu_dining_review2 = donkatsu_dining_review[5000:10000]
donkatsu_dining_review3 = donkatsu_dining_review[10000:15000]
donkatsu_dining_review4 = donkatsu_dining_review[15000:20000]
donkatsu_dining_review5 = donkatsu_dining_review[20000:25000]
donkatsu_dining_review6 = donkatsu_dining_review[25000:]


# donkatsu_dining_review1 = donkatsu_dining_review[:6000]
# donkatsu_dining_review2 = donkatsu_dining_review[6000:12000]
# donkatsu_dining_review3 = donkatsu_dining_review[12000:18000]
# donkatsu_dining_review4 = donkatsu_dining_review[18000:]

# %%
from konlpy.tag import Twitter

twitter = Twitter()
raw_pos_tagged1 = twitter.pos(donkatsu_dining_review1, norm=True, stem=True) # POS Tagging
raw_pos_tagged2 = twitter.pos(donkatsu_dining_review2, norm=True, stem=True) # POS Tagging
raw_pos_tagged3 = twitter.pos(donkatsu_dining_review3, norm=True, stem=True) # POS Tagging
raw_pos_tagged4 = twitter.pos(donkatsu_dining_review4, norm=True, stem=True) # POS Tagging
raw_pos_tagged5 = twitter.pos(donkatsu_dining_review5, norm=True, stem=True) # POS Tagging
raw_pos_tagged6 = twitter.pos(donkatsu_dining_review6, norm=True, stem=True) # POS Tagging

# %%
raw_pos_tagged = []

for raw_reviews in [donkatsu_dining_review1, donkatsu_dining_review2, donkatsu_dining_review3, donkatsu_dining_review4]:
    raw_pos_tagged += twitter.pos(raw_reviews, norm=True, stem=True)

# %%
del_list = ['하다', '있다', '되다', '이다', '돼다', '않다', '그렇다', '아니다', '이렇다', '그렇다', '어떻다'] 

word_cleaned = []
for word in raw_pos_tagged: #  ('서울', 'Noun'),
    if not word[1] in ["Josa", "Eomi", "Punctuation", "Foreign"]: # Foreign == ”, “ 와 같이 제외되어야할 항목들
        if (len(word[0]) != 1) & (word[0] not in del_list): # 한 글자로 이뤄진 단어들을 제외 & 원치 않는 단어들을 제외
            word_cleaned.append(word[0])
        
word_cleaned
# Out:
# ['장어',
#  '덮다',
#  '정말',
#  '맛있다',
#  '정갈하다',
#  '나고야',
#  '덮다',
#  '배부르다',
#  '점심',
#  '먹다',
#  '싶다',
#  '가면',
#  '좋다',
#  '깔끔하다',
#  '장어',
#  '정식',
#  '특별하다',
#  '몸보',
#  '신용',
#  '먹기',
#  '적당하다',
#  '기분',
#  '좋다',
#  '배부르다',
#  '블로그',
#  '후기',
#  '평이',
#  '엄청',
#  '좋다',
#  '기대',
#  '많이',
#  '그렇게',
#  '특별하다',
#  '건가',
#  '싶다',
#  '반포',
#  '위치',
#  '히쯔',
#  '부시',
#  '맛집',
#  '국내',
#  '민물장어',
#  '일본',
#  '나고야',
#  '요리법',
#  '접목',
#  '만들다',
#  '요리',
#  '사이즈',
#  '미니',
#  '장어',
#  '마리',
#  '장어',
#  '마리',
#  '대개',
#  '여성',
#  '분들',
#  '장어',
#  '좋아하다',
#  '남성',
#  '분들',
#  '들다',
#  '숯불',
#  '가득하다',
#  '장어',
#  '간이',
#  '자다',
#  '베인',
#  '정말',
#  '자다',
#  '어울리다',
#  '메뉴판',
#  '명시',
#  '먹다',
#  '해보다',
#  '색다르다',
#  '맛있다',
#  '특히',
#  '마지막',
#  '육수',
#  '넣다',
#  '먹다',
#  '오차',
#  '가장',
#  '맛있다',
#  '사이드',
#  '메뉴',
#  '정갈하다',
#  '함께',
#  '나오다',
#  '배부르다',
#  '들다',
#  '같이',
#  '나오다',
#  '계란찜',
#  '맛있다',
#  '발렛',
#  '가능하다',
#  '어버이날',
#  '아이',
#  '선물',
#  '점심',
#  '마루',
#  '예약',
#  '가다',
#  '해주다',
#  '조용하다',
#  '먹다',
#  '언제',
#  '가도',
#  '한결같이',
#  '맛있다',
#  '그냥',
#  '먹다',
#  '맛있다',
#  '말다',
#  '먹다',
#  '비비다',
#  '먹다',
#  '맛있다',
#  '예전',
#  '그냥',
#  '요즘',
#  '손님',
#  '많다',
#  '예약',
#  '가야',
#  '기다리다',
#  '식사',
#  '같다',
#  '일본',
#  '장어',
#  '덮다',
#  '맛있다',
#  '먹다',
#  '가보다',
#  '소스',
#  '너무',
#  '타다',
#  '반감',
#  '진짜',
#  '맛있다',
#  '나서다',
#  '자신',
#  '정말',
#  '성대',
#  '식사',
#  '제공',
#  '싶다',
#  '방문',
#  '1.5만원',
#  '카이센동',
#  '스끼야끼',
#  '깔끔하다',
#  '대접받다',
#  '자리',
#  '자다',
#  '되어다',
#  '혼밥',
#  '적절하다',
#  '아주',
#  '좋다',
#  '카이센동',
#  '조리',
#  '매우',
#  '되어다',
#  '어느',
#  '퍼먹어',
#  '새우',
#  '참치',
#  '연어',
#  '관자',
#  '오징어',
#  '계란말이',
#  '연어',
#  '날치',
#  '올리다',
#  '무시',
#  '절임',
#  '메뉴',
#  '된장국',
#  '제공',
#  '평일',
#  '점심',
#  '서서',
#  '먹다',
#  '이유',
#  '납득',
#  '메뉴',
#  '나오다',
#  '비리다',
#  '없이',
#  '해산물',
#  '모두',
#  '신선하다',
#  '단맛',
#  '나다',
#  '계절',
#  '따르다',
#  '올리다',
#  '메뉴',
#  '달라지다',
#  '리뷰',
#  '대한',
#  '자부심',
#  '메뉴',
#  '맛있다',
#  '찾아보다',
#  '그냥',
#  '가다',
#  '먹다',
#  '싶다',
#  '시키다',
#  '성공하다',
#  '근처',
#  '지나가다',
#  '식사',
#  '시간대',
#  '항상',
#  '항상',
#  '항상',
#  '웨이팅',
#  '좁다',
#  '가게',
#  '맛집',
#  '진작',
#  '알다',
#  '상황',
#  '따르다',
#  '웨이',
#  '팅할',
#  '겨를',
#  '없다',
#  '지나가다',
#  '가격',
#  '식사',
#  '다소',
#  '담다',
#  '구성',
#  '보다',
#  '보다',
#  '그만하다',
#  '가치',
#  '한다는',
#  '여타',
#  '1.2',
#  '1.3만원',
#  '상당',
#  '카이센동',
#  '먹다',
#  '오늘',
#  '카이센동',
#  '오랜',
#  '먹다',
#  '느끼다',
#  '천원',
#  '덥다',
#  '이집',
#  '진또',
#  '배기',
#  '기분',
#  '좋다',
#  '식사',
#  '가게',
#  '협소해',
#  '금방',
#  '웨이팅',
#  '생기',
#  '그만큼',
#  '회전',
#  '율도',
#  '빠르다',
#  '맛집',
#  '특성',
#  '재료',
#  '진시',
#  '일찍',
#  '마감',
#  '인분',
#  '양으로',
#  '욕먹다',
#  '정도',
#  '먹다',
#  '방법',
#  '친절하다',
#  '알다',
#  '손님',
#  '엄청',
#  '친절하다',
#  '대해',
#  '가게',
#  '좁다',
#  '비다',
#  '직원',
#  '분들',
#  '많다',
#  '다소',
#  '놀라다',
#  '곱창',
#  '보쌈',
#  '명맥',
#  '유지',
#  '맛집',
#  '거의',
#  '찾아보다',
#  '힘드다',
#  '당산',
#  '위치',
#  '카이센동',
#  '동네',
#  '주민',
#  '가게',
#  '오픈',
#  '시기',
#  '지나다',
#  '내부',
#  '공간',
#  '자체',
#  '협소',
#  '해산물',
#  '사용',
#  '만큼',
#  '재료',
#  '진시',
#  '판매',
#  '중단',
#  '브레이크',
#  '타임',
#  '존재',
#  '시간',
#  '맞다',
#  '가보다',
#  '드디어',
#  '방문',
#  '다그',
#  '사이',
#  '소문',
#  '많이',
#  '나서다',
#  '상당하다',
#  '많이',
#  '알려지다',
#  '금요일',
#  '저녁',
#  '퇴근',
#  '자마자',
#  '방문',
#  '7시',
#  '조금',
#  '안되다',
#  '시간',
#  '웨이팅',
#  '조금',
#  '2~3',
#  '10~15분',
#  '정도',
#  '식사',
#  '무리',
#  '없다',
#  '내부',
#  '대부분',
#  '테이블',
#  '마주',
#  '보다',
#  '앉다',
#  '테이블',
#  '하나',
#  '테이블',
#  '하나',
#  '앉다',
#  '대기',
#  '실내',
#  '기석',
#  '자리',
#  '나머지',
#  '기다리다',
#  '스키야키',
#  '메뉴',
#  '많이',
#  '주문',
#  '카이센동',
#  '맛집',
#  '이면',
#  '카이센동',
#  '먹어주다',
#  '재료',
#  '신선하다',
#  '편이',
#  '훌륭하다',
#  '직원',
#  '일일이',
#  '먹다',
#  '알다',
#  '서빙',
#  '태도',
#  '상당하다',
#  '친절하다',
#  '펴다',
#  '고양',
#  '적지',
#  '많다',
#  '적당하다',
#  '펴다',
#  '성인',
#  '남성',
#  '기준',
#  '조금',
#  '모자라다',
#  '생각',
#  '들다',
#  '수도',
#  '최근',
#  '먹다',
#  '보다',
#  '카이센동',
#  '연남동',
#  '출발',
#  '오복',
#  '수산',
#  '방문',
#  '여의도',
#  '개인',
#  '평가',
#  '오복',
#  '수산',
#  '서서',
#  '먹다',
#  '모르다',
#  '제일',
#  '맛있다',
#  '먹다',
#  '카이센동',
#  '일본',
#  '시즈오카',
#  '오복',
#  '수산',
#  '우미',
#  '노미',
#  '확실하다',
#  '생각',
#  '당산',
#  '떠나다',
#  '근처',
#  '오다',
#  '다시',
#  '가보다',
#  '싶다',
#  '진짜',
#  '역대',
#  '맛있다',
#  '카이센동',
#  '가게',
#  '크다',
#  '웨이팅',
#  '시간',
#  '전혀',
#  '아깝다',
#  '주말',
#  '가다',
#  '저녁',
#  '7시',
#  '정도',
#  '재료',
#  '소진',
#  '주문',
#  '마감',
#  '되어다',
#  'ㅠㅠ',
#  '주말',
#  '가시다',
#  '분들',
#  '참고',
#  '와사비',
#  '간장',
#  '간이',
#  '짜지다',
#  '좋다',
#  '해산물',
#  '싱싱하다',
#  '자다',
#  '느껴지다',
#  '12시',
#  '오픈',
#  '들어가다',
#  '일단',
#  '11시',
#  '즈음',
#  '서다',
#  '맛보다',
#  '수가',
#  '내부',
#  '매장',
#  '워낙',
#  '작다',
#  '보다',
#  '여러',
#  '앉다',
#  '먹다',
#  '수가',
#  '없다',
#  '아쉽다',
#  '들어가다',
#  '대부분',
#  '서다',
#  '시즌',
#  '메뉴',
#  '바뀌다',
#  '얼마',
#  '가다',
#  '시금치',
#  '카레',
#  '카레',
#  '맛보다',
#  '카레',
#  '우리',
#  '알다',
#  '카레',
#  '뭔가',
#  '동양',
#  '느낌',
#  '물씬',
#  '풍기다',
#  '인도',
#  '강렬하다',
#  '카레',
#  '재료',
#  '모두',
#  '직접',
#  '일일이',
#  '손질',
#  '정성',
#  '가득',
#  '담다',
#  '만들다',
#  '같다',
#  '별미',
#  '먹다',
#  '싶다',
#  '평상시',
#  '맛보다',
#  '인도',
#  '커리',
#  '먹다',
#  '싶다',
#  '추천',
#  '자신',
#  '4.0',
#  '정성',
#  '들어가다',
#  '카레',
#  '깊다',
#  '부족하다',
#  '일본',
#  '카레',
#  '맛집',
#  '메뉴',
#  '종종',
#  '바뀌다',
#  '카페',
#  '인스타',
#  '확인',
#  '필수',
#  '분위기',
#  '4.0',
#  '감성',
#  '인테리어',
#  '사진',
#  '찍기',
#  '좋다',
#  '서비스',
#  '3.0',
#  '친절하다',
#  '임재',
#  '방문',
#  '의사',
#  '아직',
#  '시금치',
#  '카레',
#  '먹다',
#  '보지',
#  '메뉴',
#  '다음',
#  '먹다',
#  '싶다',
#  '혼밥',
#  '오시',
#  '대부분',
#  '가게',
#  '작다',
#  '이상',
#  '경우',
#  '좋다',
#  '길다',
#  '웨이',
#  '수도',
#  '시금치',
#  '카레',
#  '무슨',
#  '궁금하다',
#  '먹다',
#  '보다',
#  '크다',
#  '생각',
#  '우유',
#  '많이',
#  '나다',
#  '중간',
#  '물컹물컹하다',
#  '씹히다',
#  '그닥',
#  '유쾌하다',
#  '감다',
#  '간판',
#  '없다',
#  '자주',
#  '가다',
#  '기다',
#  '처음',
#  '방문',
#  '해보다',
#  '공간',
#  '워낙',
#  '좁다',
#  '웨이팅',
#  '시금치',
#  '카레',
#  '정말',
#  '맛있다',
#  '조용하다',
#  '분위기',
#  '좋다',
#  '다른',
#  '카레',
#  '솔드아웃',
#  '아쉽다',
#  '기본',
#  '시금치',
#  '카레',
#  '맛있다',
#  '카레',
#  '리필',
#  '좋다',
#  '위치',
#  '카레',
#  '전문점',
#  '식당',
#  '대표',
#  '메뉴인',
#  '새우',
#  '버터',
#  '카레',
#  '새우',
#  '키마',
#  '커리',
#  '가지',
#  '주문',
#  '21500원',
#  '결제',
#  '매장',
#  '한쪽',
#  '정숙',
#  '크게',
#  '붙이다',
#  '만큼',
#  '조용하다',
#  '분위기',
#  '식사',
#  '가능하다',
#  '음식',
#  '나오다',
#  '시간',
#  '20분',
#  '정도',
#  '무난',
#  '서빙',
#  '비비다',
#  '먹다',
#  '조금씩',
#  '뿌리다',
#  '먹다',
#  '새우',
#  '버터',
#  '카레',
#  '먹다',
#  '오뚜기',
#  '3분',
#  '카레',
#  '약간',
#  '버터',
#  '추가',
#  '친구',
#  '맛있다',
#  '먹다',
#  '하지만',
#  '가격',
#  '대비',
#  '전반',
#  '적다',
#  '느낌',
#  '강하다',
#  '리필',
#  '해주시',
#  '하나',
#  '기본',
#  '제공',
#  '적다',
#  '깍두기',
#  '없다',
#  '아쉽다',
#  '식당',
#  '분위기',
#  '조용하다',
#  '좋다',
#  'ㅎㅎㅎ',
#  '키마',
#  '카레',
#  '맛있다',
#  '웨이',
#  '먹다',
#  '엄청',
#  '맛있다',
#  '음식',
#  '무난',
#  '기분',
#  '좋다',
#  '먹다',
#  '깔끔하다',
#  '너무',
#  '맛있다',
#  '치킨',
#  '조금',
#  '짭짤하다',
#  '어울리다',
#  '치킨',
#  '버터',
#  '카레',
#  '정말',
#  '부드럽다',
#  'ㅠㅜ',
#  '결정',
#  '장애',
#  '위해',
#  '혼밥',
#  '세트',
#  '좋다',
#  '샐러드',
#  '야채',
#  '신선하다',
#  '무엇',
#  '분위기',
#  '최고',
#  '오늘',
#  '처음',
#  '가보다',
#  '아담하다',
#  '깨끗하다',
#  '인테리어',
#  '소박하다',
#  '분위기',
#  '좋다',
#  '역시',
#  '핵심',
#  '음식',
#  '오늘',
#  '메뉴',
#  '버터치킨',
#  '커리',
#  '거짓말',
#  '보태',
#  '지금',
#  '맛보다',
#  '커리',
#  '최고',
#  '서울',
#  '맛집',
#  '사실',
#  '감사하다',
#  '장어',
#  '덮다',
#  '먹다',
#  '가다',
#  '히쯔마부시',
#  '우나쥬',
#  '장어',
#  '많다',
#  '하지만',
#  '오차',
#  '육수',
#  '넣다',
#  '먹다',
#  '히쯔',
#  '부시',
#  '빠지다',
#  '항상',
#  '히쯔',
#  '부시',
#  '먹다',
#  '장어',
#  '덮다',
#  '정말',
#  '맛있다',
#  '정갈하다',
#  '나고야',
#  '덮다',
#  '배부르다',
#  '점심',
#  '먹다',
#  '싶다',
#  '가면',
#  '좋다',
#  '깔끔하다',
#  '장어',
#  '정식',
#  '특별하다',
#  '몸보',
#  '신용',
#  '먹기',
#  '적당하다',
#  '기분',
#  '좋다',
#  '배부르다',
#  '블로그',
#  '후기',
#  '평이',
#  '엄청',
#  '좋다',
#  '기대',
#  '많이',
#  '그렇게',
#  '특별하다',
#  '건가',
#  '싶다',
#  '반포',
#  '위치',
#  '히쯔',
#  '부시',
#  '맛집',
#  '국내',
#  '민물장어',
#  '일본',
#  '나고야',
#  '요리법',
#  '접목',
#  '만들다',
#  '요리',
#  '사이즈',
#  '미니',
#  '장어',
#  '마리',
#  '장어',
#  '마리',
#  '대개',
#  '여성',
#  '분들',
#  '장어',
#  '좋아하다',
#  '남성',
#  '분들',
#  '들다',
#  '숯불',
#  '가득하다',
#  '장어',
#  '간이',
#  '자다',
#  '베인',
#  '정말',
#  '자다',
#  '어울리다',
#  '메뉴판',
#  '명시',
#  '먹다',
#  '해보다',
#  '색다르다',
#  '맛있다',
#  '특히',
#  '마지막',
#  '육수',
#  '넣다',
#  '먹다',
#  '오차',
#  '가장',
#  '맛있다',
#  '사이드',
#  '메뉴',
#  '정갈하다',
#  '함께',
#  '나오다',
#  '배부르다',
#  '들다',
#  '같이',
#  '나오다',
#  '계란찜',
#  '맛있다',
#  '발렛',
#  '가능하다',
#  '어버이날',
#  '아이',
#  '선물',
#  '점심',
#  '마루',
#  '예약',
#  '가다',
#  '해주다',
#  '조용하다',
#  '먹다',
#  '언제',
#  '가도',
#  '한결같이',
#  '맛있다',
#  '그냥',
#  '먹다',
#  '맛있다',
#  '말다',
#  '먹다',
#  '비비다',
#  '먹다',
#  '맛있다',
#  '예전',
#  '그냥',
#  '요즘',
#  '손님',
#  '많다',
#  '예약',
#  '가야',
#  '기다리다',
#  '식사',
#  '같다',
#  '일본',
#  '장어',
#  '덮다',
#  '맛있다',
#  '먹다',
#  '가보다',
#  '소스',
#  '너무',
#  '타다',
#  '반감',
#  '진짜',
#  '맛있다',
#  '진짜',
#  '지금',
#  '먹다',
#  '맛집',
#  '최고',
#  '부족하다',
#  '정도',
#  '소바',
#  '처음',
#  '먹다',
#  '보다',
#  '기대하다',
#  '이상',
#  '맛있다',
#  '조금',
#  '적다',
#  '그건',
#  '공기밥',
#  '추가',
#  '나중',
#  '간식',
#  '하나',
#  '정도',
#  '먹다',
#  '정도',
#  '들다',
#  '다시마',
#  '식초',
#  '다지다',
#  '마늘',
#  '후추',
#  '추가',
#  '들다',
#  '보다',
#  '추천',
#  '드림',
#  '그냥',
#  '먹다',
#  '맛있다',
#  '가시',
#  '감다',
#  '감칠맛',
#  '잊다',
#  '수가',
#  '없다',
#  '브레이크',
#  '타임',
#  '휴업',
#  '확인',
#  '바라다',
#  '웨이팅',
#  '많다',
#  '재료',
#  '금방',
#  '소진',
#  '들다',
#  '수도',
#  '일찍',
#  '갈다',
#  '추천',
#  '드림',
#  ...]

# %%
# 리스트에 담긴 단어들을 대상으로 갯수를 세어,
# 단어를 key로 등장 횟수를 value로 하는 dict 만들기

word_dic = {}

for word in word_cleaned:
    if word not in word_dic:
        word_dic[word] = 1 # changed from "0" to "1"
    else:
        word_dic[word] += 1
        
word_dic
# Out:
# {'장어': 29,
#  '덮다': 19,
#  '정말': 22,
#  '맛있다': 109,
#  '정갈하다': 5,
#  '나고야': 4,
#  '배부르다': 13,
#  '점심': 6,
#  '먹다': 148,
#  '싶다': 24,
#  '가면': 5,
#  '좋다': 68,
#  '깔끔하다': 10,
#  '정식': 9,
#  '특별하다': 6,
#  '몸보': 2,
#  '신용': 2,
#  '먹기': 4,
#  '적당하다': 14,
#  '기분': 5,
#  '블로그': 2,
#  '후기': 2,
#  '평이': 3,
#  '엄청': 13,
#  '기대': 4,
#  '많이': 10,
#  '그렇게': 4,
#  '건가': 2,
#  '반포': 2,
#  '위치': 9,
#  '히쯔': 4,
#  '부시': 8,
#  '맛집': 27,
#  '국내': 2,
#  '민물장어': 2,
#  '일본': 16,
#  '요리법': 2,
#  '접목': 2,
#  '만들다': 6,
#  '요리': 4,
#  '사이즈': 2,
#  '미니': 3,
#  '마리': 4,
#  '대개': 2,
#  '여성': 2,
#  '분들': 10,
#  '좋아하다': 5,
#  '남성': 4,
#  '들다': 31,
#  '숯불': 2,
#  '가득하다': 3,
#  '간이': 4,
#  '자다': 23,
#  '베인': 2,
#  '어울리다': 4,
#  '메뉴판': 2,
#  '명시': 2,
#  '해보다': 5,
#  '색다르다': 3,
#  '특히': 6,
#  '마지막': 9,
#  '육수': 3,
#  '넣다': 3,
#  '오차': 3,
#  '가장': 5,
#  '사이드': 5,
#  '메뉴': 20,
#  '함께': 2,
#  '나오다': 25,
#  '같이': 7,
#  '계란찜': 4,
#  '발렛': 2,
#  '가능하다': 7,
#  '어버이날': 2,
#  '아이': 2,
#  '선물': 2,
#  '마루': 2,
#  '예약': 4,
#  '가다': 27,
#  '해주다': 8,
#  '조용하다': 6,
#  '언제': 2,
#  '가도': 2,
#  '한결같이': 2,
#  '그냥': 18,
#  '말다': 4,
#  '비비다': 12,
#  '예전': 3,
#  '요즘': 3,
#  '손님': 8,
#  '많다': 23,
#  '가야': 3,
#  '기다리다': 7,
#  '식사': 14,
#  '같다': 28,
#  '가보다': 12,
#  '소스': 18,
#  '너무': 26,
#  '타다': 4,
#  '반감': 2,
#  '진짜': 11,
#  '나서다': 3,
#  '자신': 2,
#  '성대': 1,
#  '제공': 5,
#  '방문': 28,
#  '1.5만원': 1,
#  '카이센동': 12,
#  '스끼야끼': 1,
#  '대접받다': 1,
#  '자리': 9,
#  '되어다': 10,
#  '혼밥': 4,
#  '적절하다': 4,
#  '아주': 13,
#  '조리': 3,
#  '매우': 5,
#  '어느': 1,
#  '퍼먹어': 1,
#  '새우': 12,
#  '참치': 2,
#  '연어': 2,
#  '관자': 1,
#  '오징어': 1,
#  '계란말이': 1,
#  '날치': 1,
#  '올리다': 2,
#  '무시': 1,
#  '절임': 4,
#  '된장국': 1,
#  '평일': 1,
#  '서서': 2,
#  '이유': 1,
#  '납득': 1,
#  '비리다': 3,
#  '없이': 5,
#  '해산물': 7,
#  '모두': 12,
#  '신선하다': 9,
#  '단맛': 3,
#  '나다': 10,
#  '계절': 1,
#  '따르다': 5,
#  '달라지다': 2,
#  '리뷰': 1,
#  '대한': 1,
#  '자부심': 1,
#  '찾아보다': 2,
#  '시키다': 16,
#  '성공하다': 1,
#  '근처': 5,
#  '지나가다': 2,
#  '시간대': 3,
#  '항상': 4,
#  '웨이팅': 17,
#  '좁다': 5,
#  '가게': 20,
#  '진작': 1,
#  '알다': 10,
#  '상황': 1,
#  '웨이': 6,
#  '팅할': 1,
#  '겨를': 1,
#  '없다': 35,
#  '가격': 25,
#  '다소': 4,
#  '담다': 2,
#  '구성': 2,
#  '보다': 37,
#  '그만하다': 1,
#  '가치': 2,
#  '한다는': 1,
#  '여타': 1,
#  '1.2': 1,
#  '1.3만원': 1,
#  '상당': 1,
#  '오늘': 3,
#  '오랜': 2,
#  '느끼다': 12,
#  '천원': 2,
#  '덥다': 1,
#  '이집': 4,
#  '진또': 1,
#  '배기': 2,
#  '협소해': 1,
#  '금방': 4,
#  '생기': 1,
#  '그만큼': 1,
#  '회전': 1,
#  '율도': 1,
#  '빠르다': 2,
#  '특성': 1,
#  '재료': 14,
#  '진시': 2,
#  '일찍': 4,
#  '마감': 2,
#  '인분': 4,
#  '양으로': 1,
#  '욕먹다': 1,
#  '정도': 25,
#  '방법': 5,
#  '친절하다': 12,
#  '대해': 1,
#  '비다': 3,
#  '직원': 12,
#  '놀라다': 1,
#  '곱창': 1,
#  '보쌈': 1,
#  '명맥': 1,
#  '유지': 2,
#  '거의': 3,
#  '힘드다': 1,
#  '당산': 2,
#  '동네': 2,
#  '주민': 1,
#  '오픈': 7,
#  '시기': 2,
#  '지나다': 2,
#  '내부': 4,
#  '공간': 4,
#  '자체': 3,
#  '협소': 1,
#  '사용': 2,
#  '만큼': 2,
#  '판매': 1,
#  '중단': 1,
#  '브레이크': 6,
#  '타임': 6,
#  '존재': 1,
#  '시간': 15,
#  '맞다': 5,
#  '드디어': 1,
#  '다그': 1,
#  '사이': 1,
#  '소문': 1,
#  '상당하다': 4,
#  '알려지다': 1,
#  '금요일': 2,
#  '저녁': 7,
#  '퇴근': 1,
#  '자마자': 1,
#  '7시': 2,
#  '조금': 21,
#  '안되다': 4,
#  '2~3': 1,
#  '10~15분': 1,
#  '무리': 1,
#  '대부분': 3,
#  '테이블': 9,
#  '마주': 2,
#  '앉다': 5,
#  '하나': 11,
#  '대기': 6,
#  '실내': 2,
#  '기석': 1,
#  '나머지': 2,
#  '스키야키': 1,
#  '주문': 19,
#  '이면': 1,
#  '먹어주다': 1,
#  '편이': 10,
#  '훌륭하다': 7,
#  '일일이': 2,
#  '서빙': 6,
#  '태도': 1,
#  '펴다': 3,
#  '고양': 1,
#  '적지': 1,
#  '성인': 1,
#  '기준': 2,
#  '모자라다': 1,
#  '생각': 5,
#  '수도': 8,
#  '최근': 4,
#  '연남동': 1,
#  '출발': 1,
#  '오복': 3,
#  '수산': 3,
#  '여의도': 1,
#  '개인': 4,
#  '평가': 1,
#  '모르다': 6,
#  '제일': 4,
#  '시즈오카': 1,
#  '우미': 1,
#  '노미': 1,
#  '확실하다': 1,
#  '떠나다': 1,
#  '오다': 11,
#  '다시': 6,
#  '역대': 1,
#  '크다': 12,
#  '전혀': 1,
#  '아깝다': 2,
#  '주말': 3,
#  '소진': 3,
#  'ㅠㅠ': 5,
#  '가시다': 2,
#  '참고': 8,
#  '와사비': 7,
#  '간장': 6,
#  '짜지다': 2,
#  '싱싱하다': 1,
#  '느껴지다': 5,
#  '12시': 1,
#  '들어가다': 8,
#  '일단': 6,
#  '11시': 4,
#  '즈음': 1,
#  '서다': 3,
#  '맛보다': 9,
#  '수가': 4,
#  '매장': 7,
#  '워낙': 3,
#  '작다': 3,
#  '여러': 3,
#  '아쉽다': 14,
#  '시즌': 1,
#  '바뀌다': 2,
#  '얼마': 3,
#  '시금치': 5,
#  '카레': 27,
#  '우리': 1,
#  '뭔가': 1,
#  '동양': 1,
#  '느낌': 9,
#  '물씬': 1,
#  '풍기다': 1,
#  '인도': 10,
#  '강렬하다': 1,
#  '직접': 6,
#  '손질': 1,
#  '정성': 3,
#  '가득': 1,
#  '별미': 2,
#  '평상시': 1,
#  '커리': 24,
#  '추천': 16,
#  '4.0': 2,
#  '깊다': 2,
#  '부족하다': 7,
#  '종종': 1,
#  '카페': 1,
#  '인스타': 1,
#  '확인': 3,
#  '필수': 2,
#  '분위기': 14,
#  '감성': 1,
#  '인테리어': 3,
#  '사진': 1,
#  '찍기': 1,
#  '서비스': 7,
#  '3.0': 1,
#  '임재': 1,
#  '의사': 5,
#  '아직': 1,
#  '보지': 1,
#  '다음': 6,
#  '오시': 2,
#  '이상': 5,
#  '경우': 3,
#  '길다': 3,
#  '무슨': 2,
#  '궁금하다': 2,
#  '우유': 1,
#  '중간': 2,
#  '물컹물컹하다': 1,
#  '씹히다': 1,
#  '그닥': 3,
#  '유쾌하다': 1,
#  '감다': 6,
#  '간판': 1,
#  '자주': 1,
#  '기다': 5,
#  '처음': 19,
#  '다른': 11,
#  '솔드아웃': 1,
#  '기본': 7,
#  '리필': 4,
#  '전문점': 5,
#  '식당': 9,
#  '대표': 1,
#  '메뉴인': 2,
#  '버터': 7,
#  '키마': 2,
#  '가지': 5,
#  '21500원': 1,
#  '결제': 1,
#  '한쪽': 1,
#  '정숙': 1,
#  '크게': 3,
#  '붙이다': 1,
#  '음식': 14,
#  '20분': 3,
#  '무난': 6,
#  '조금씩': 1,
#  '뿌리다': 6,
#  '오뚜기': 1,
#  '3분': 1,
#  '약간': 5,
#  '추가': 11,
#  '친구': 7,
#  '하지만': 9,
#  '대비': 4,
#  '전반': 3,
#  '적다': 10,
#  '강하다': 3,
#  '해주시': 1,
#  '깍두기': 1,
#  'ㅎㅎㅎ': 3,
#  '치킨': 7,
#  '짭짤하다': 1,
#  '부드럽다': 12,
#  'ㅠㅜ': 1,
#  '결정': 1,
#  '장애': 1,
#  '위해': 2,
#  '세트': 2,
#  '샐러드': 3,
#  '야채': 3,
#  '무엇': 2,
#  '최고': 5,
#  '아담하다': 1,
#  '깨끗하다': 2,
#  '소박하다': 1,
#  '역시': 4,
#  '핵심': 1,
#  '버터치킨': 1,
#  '거짓말': 1,
#  '보태': 1,
#  '지금': 5,
#  '서울': 3,
#  '사실': 2,
#  '감사하다': 1,
#  '히쯔마부시': 1,
#  '우나쥬': 1,
#  '빠지다': 2,
#  '소바': 13,
#  '기대하다': 3,
#  '그건': 2,
#  '공기밥': 2,
#  '나중': 2,
#  '간식': 2,
#  '다시마': 4,
#  '식초': 4,
#  '다지다': 4,
#  '마늘': 2,
#  '후추': 2,
#  '드림': 4,
#  '가시': 2,
#  '감칠맛': 2,
#  '잊다': 2,
#  '휴업': 3,
#  '바라다': 2,
#  '갈다': 4,
#  '마제': 9,
#  '국물': 4,
#  '따로': 6,
#  '새롭다': 7,
#  '남다': 9,
#  '양념': 8,
#  '달라': 3,
#  '충분하다': 4,
#  '찾아오다': 2,
#  '1일': 2,
#  '30': 4,
#  '한정판': 2,
#  '도니': 2,
#  '쿠나': 2,
#  '야마': 2,
#  '도착': 3,
#  '얼핏': 2,
#  '아슬하다': 2,
#  'ㅎㅎ': 5,
#  '종업원': 2,
#  '호출': 2,
#  '입장': 7,
#  '10': 3,
#  '여분': 2,
#  '드뎌': 2,
#  '비쥬': 2,
#  '그릇': 3,
#  '달걀': 3,
#  '노른자': 4,
#  '터뜨리다': 4,
#  '섞다': 2,
#  '대박': 3,
#  '라멘': 2,
#  '내다': 4,
#  '도니쿠': 2,
#  '먹음': 5,
#  '느끼하다': 20,
#  '꿀꺽': 2,
#  '넘어가다': 2,
#  '난생': 2,
#  '찾다': 5,
#  '가까이': 3,
#  '행복하다': 2,
#  '지점': 2,
#  '본점': 4,
#  '그래도': 6,
#  '손소독': 2,
#  '체크': 4,
#  '안내받다': 2,
#  '유명하다': 8,
#  '사람': 13,
#  '끊임없다': 2,
#  '우동': 5,
#  '계란': 7,
#  '특이하다': 4,
#  '살짝': 11,
#  '오이': 2,
#  '메시': 2,
#  '늘다': 3,
#  '회식': 1,
#  '해봤다': 1,
#  '다양하다': 7,
#  '잘못': 2,
#  '이해': 3,
#  '양고기': 7,
#  '전체': 5,
#  '망고': 5,
#  '쏘다': 3,
#  '쏘이다': 1,
#  '라씨': 8,
#  '플레인': 3,
#  '신맛': 1,
#  '입맛': 5,
#  '바나나': 1,
#  '과일': 1,
#  '탄두리': 1,
#  '프라': 2,
#  '살이': 3,
#  '튼실하다': 1,
#  '바짝': 1,
#  '말르다': 1,
#  '배다': 1,
#  '새우다': 4,
#  '껍질': 2,
#  '대충': 2,
#  '끄다': 2,
#  '다난': 1,
#  '쫄깃쫄깃해': 1,
#  '굿굿': 1,
#  '난도': 1,
#  '두다': 4,
#  '다가': 1,
#  '중요하다': 2,
#  '특유': 1,
#  '나쁘다': 1,
#  '향신료': 3,
#  '팔락': 3,
#  '파니': 2,
#  '푸드': 1,
#  '보고': 5,
#  '맥주': 4,
#  '안주': 2,
#  '평범하다': 2,
#  '따다': 1,
#  '실제': 1,
#  '노래': 1,
#  '티비': 1,
#  '뮤비': 1,
#  '현지': 3,
#  '예티': 1,
#  '괜찮다': 17,
#  '종류': 4,
#  '시도': 1,
#  '티벳': 1,
#  '국수': 1,
#  '한국인': 1,
#  '싫어하다': 2,
#  '여기다': 4,
#  '대신': 2,
#  '바삭': 8,
#  '부분': 4,
#  '싫다': 1,
#  '비추다': 1,
#  '입천장': 1,
#  '난이': 1,
#  '마냥': 1,
#  '호불호': 2,
#  '갈리다': 1,
#  '토마토': 5,
#  '달달': 5,
#  '소개': 1,
#  '베이스': 1,
#  '비슷하다': 6,
#  '차이': 1,
#  '예쁘다': 1,
#  '8~10': 1,
#  '인원': 1,
#  '홍대': 1,
#  '무조건': 1,
#  '여기': 3,
#  '히츠': 4,
#  '밥집': 1,
#  '인근': 2,
#  '주차장': 6,
#  '주차': 10,
#  '영수증': 1,
#  '내면': 1,
#  '1시간': 2,
#  '무료': 2,
#  '만원': 2,
#  '할인': 1,
#  '까다롭다': 1,
#  '반찬': 3,
#  '여름': 3,
#  '초복': 1,
#  '중복': 1,
#  '말복': 1,
#  '하루': 1,
#  '들리다': 1,
#  '따라가다': 1,
#  '심지어': 1,
#  '후쿠오카': 3,
#  '부산': 3,
#  '고옥': 4,
#  '본연': 1,
#  '살리다': 1,
#  '텁텁하거': 1,
#  '건조하다': 1,
#  '수분': 1,
#  '굽다': 4,
#  '얹다': 2,
#  '계속': 5,
#  '1/2': 2,
#  '양은': 3,
#  '동일하다': 1,
#  '장어구이': 1,
#  '밑반찬': 3,
#  '버섯': 3,
#  '매실': 4,
#  '그것': 1,
#  '설명': 1,
#  '보시': 1,
#  '정독': 1,
#  '4등': 1,
#  '자기': 1,
#  '그리고': 6,
#  '조심하다': 1,
#  'ㅜㅜㅋㅋ': 1,
#  '만족하다': 1,
#  '양도': 6,
#  '숟가락': 1,
#  '정돈': 1,
#  '어떻': 1,
#  '생기다': 4,
#  'GS': 1,
#  '찾아가다': 5,
#  '찍히다': 1,
#  '세무서': 1,
#  '찍다': 3,
#  '원래': 5,
#  '민영': 1,
#  '지원': 1,
#  '마련': 2,
#  '모양': 1,
#  '아오': 1,
#  '우메': 1,
#  '파다': 1,
#  '다기': 1,
#  '물렁물렁하다': 1,
#  '식감': 4,
#  '33': 1,
#  '퀄리티': 4,
#  '쬐다': 1,
#  '비리': 2,
#  '촉촉하다': 1,
#  '떨어지다': 3,
#  '보통': 1,
#  '상임': 1,
#  '베니': 1,
#  '빨갛다': 1,
#  '생강': 1,
#  '락교': 1,
#  '하얀색': 1,
#  '염통': 1,
#  '완제': 1,
#  '제품': 1,
#  '비싸다': 10,
#  '단가': 1,
#  '편일': 1,
#  '커플': 1,
#  '끼리': 2,
#  '또는': 2,
#  '간단하다': 2,
#  '곳임': 1,
#  '체적': 1,
#  '200': 6,
#  '미터': 1,
#  '읽다': 1,
#  '비빔밥': 1,
#  '아무리': 1,
#  '쎄다': 2,
#  '감동': 1,
#  '받다': 10,
#  '부타동': 3,
#  '신촌': 1,
#  '좌석': 3,
#  '피크타임': 1,
#  '고기': 14,
#  '냄새': 2,
#  '간도': 3,
#  '사장': 3,
#  '홋카이도': 1,
#  '팔다': 1,
#  '기지': 1,
#  '조화': 3,
#  '든든하다': 1,
#  '넓다': 3,
#  '단체': 1,
#  '가기': 1,
#  '적합하다': 1,
#  '세명': 1,
#  '주인': 1,
#  '건강': 1,
#  '사정': 1,
#  '오랫동안': 1,
#  '열다': 1,
#  '영업': 3,
#  '주다': 4,
#  '코로나': 4,
#  '맞추다': 3,
#  '자리다': 2,
#  '형식': 1,
#  '불편하다': 4,
#  '끼니': 1,
#  '꾸다': 1,
#  '불맛': 1,
#  '지인': 2,
#  '물리다': 1,
#  '하이': 5,
#  '별로': 6,
#  '취향': 1,
#  '6시': 2,
#  '넘어서다': 1,
#  '튀기다': 9,
#  '시작': 2,
#  '밀리다': 1,
#  '30분': 1,
#  '넘다': 2,
#  '여유': 1,
#  '저렴하다': 3,
#  '안남': 1,
#  '기고': 1,
#  '텐동': 47,
#  '가능': 1,
#  '명단': 1,
#  '이름': 1,
#  '번호': 1,
#  '작성': 1,
#  '연락': 1,
#  '데카': 1,
#  '적히다': 2,
#  '아무래도': 1,
#  '튀김': 40,
#  '세팅': 1,
#  '시진': 1,
#  '굉장하다': 5,
#  '골목': 2,
#  '짜다': 5,
#  '길가': 1,
#  '딱지': 1,
#  '떼다': 1,
#  '대놓고': 1,
#  '아나고': 2,
#  '기다림': 1,
#  '젊다': 1,
#  '열심히': 1,
#  '아마추어': 1,
#  '편임': 1,
#  '가성': 4,
#  '바삭바삭': 1,
#  '푸다': 3,
#  '마르다': 2,
#  '마파두부': 1,
#  '러버': 1,
#  '로써': 1,
#  '만족': 1,
#  '타이가': 3,
#  '다녀오다': 1,
#  '입구': 2,
#  '좌측': 1,
#  '오스': 2,
#  '거기': 2,
#  '먼저': 2,
#  '착석': 1,
#  '그걸': 1,
#  '헤매다': 1,
#  '씻다': 1,
#  '편하다': 2,
#  '고추': 1,
#  '이렇게': 2,
#  '반숙': 1,
#  '빼다': 3,
#  '접시': 1,
#  '덜다': 1,
#  '옮기다': 2,
#  '머쓱하다': 1,
#  '바삭바삭하다': 1,
#  '달짝지근하다': 1,
#  '중독': 1,
#  '남기다': 1,
#  '부족함': 1,
#  '숨다': 1,
#  '해운대해수욕장': 1,
#  '가깝다': 2,
#  '여행': 1,
#  '해운대': 2,
#  '상권': 1,
#  '캐널': 2,
#  '시티': 2,
#  '텐투파': 1,
#  '타카': 2,
#  '전수': 2,
#  '레시피': 1,
#  '한지': 1,
#  '15': 1,
#  '맞은편': 1,
#  '전용': 1,
#  '시설': 1,
#  '5분': 1,
#  '실하다': 2,
#  '충실하다': 1,
#  '달다': 2,
#  '메인': 3,
#  '9,000원': 2,
#  '10,000원': 1,
#  '도의': 1,
#  '토핑': 1,
#  '때문': 2,
#  '술안주': 1,
#  '삼다': 1,
#  '만족스럽다': 1,
#  '19': 1,
#  '망하다': 1,
#  '텐푸': 1,
#  '푸르다': 1,
#  '짱짱': 1,
#  '수준': 1,
#  '실력': 1,
#  '해도': 1,
#  '역사': 1,
#  '일만': 1,
#  '존맛': 2,
#  '고로케': 6,
#  '다만': 2,
#  '제외': 1,
#  '데리야끼': 1,
#  '감자': 2,
#  '기름': 2,
#  '지지': 1,
#  '얇다': 2,
#  '오므라이스': 1,
#  '짭쪼롬': 1,
#  '고소하다': 3,
#  '어우러지다': 3,
#  '함박스테이크': 2,
#  '포슬포슬': 2,
#  '뭉치다': 1,
#  '함박': 1,
#  '스타일': 2,
#  '퍼석': 1,
#  '속이다': 1,
#  '돈까스': 4,
#  '비법': 1,
#  '꿀맛': 1,
#  '평타': 1,
#  '치다': 1,
#  '옛날': 1,
#  '새다': 1,
#  '덜하다': 1,
#  '근방': 1,
#  '주차공간': 1,
#  '어렵다': 2,
#  '주의': 2,
#  '쯔유': 1,
#  '훨씬': 1,
#  '이미': 2,
#  '줄이다': 1,
#  '좀처럼': 1,
#  '힘들다': 2,
#  '다웨이': 1,
#  '걸리다': 5,
#  '스페셜': 3,
#  '산뜻하다': 1,
#  '입가심': 3,
#  '유자': 2,
#  '다르다': 4,
#  '몇번': 1,
#  '상큼': 2,
#  '벗기다': 1,
#  '유자청': 1,
#  '집중': 2,
#  'TOP': 1,
#  '인생': 1,
#  '일본인': 1,
#  '피셜': 1,
#  '클라스': 1,
#  '당연하다': 1,
#  '전복': 2,
#  '올라가다': 2,
#  '녹다': 1,
#  '기성품': 1,
#  '승부': 1,
#  '흔하다': 1,
#  '알차다': 1,
#  '최고다': 1,
#  '쫀득': 1,
#  '차다': 5,
#  '한국': 3,
#  '삼대': 1,
#  '삼십분': 1,
#  '또다른': 1,
#  '문후': 1,
#  '십오분': 1,
#  '베다': 1,
#  '부르다': 2,
#  '예정': 1,
#  '전국': 1,
#  '탄두르': 1,
#  '마살라': 1,
#  '파니르': 1,
#  '정확하다': 1,
#  '판단': 1,
#  '마카': 1,
#  '하기는': 1,
#  '쵸우': 1,
#  '달기': 1,
#  '허니': 1,
#  '깔리다': 1,
#  '심하다': 1,
#  '걱정': 1,
#  '데이트': 1,
#  '소로': 1,
#  '음식점': 1,
#  '장점': 1,
#  '이신': 1,
#  '식다': 1,
#  '속도': 1,
#  '세심': 2,
#  '보여주다': 1,
#  '바베큐': 1,
#  '닭고기': 1,
#  '각각': 1,
#  '덩이': 1,
#  '요거트': 2,
#  '음료': 1,
#  '엄청나다': 2,
#  '땡기다': 1,
#  '화장실': 1,
#  '마음': 2,
#  '풍부하다': 1,
#  '그나마': 1,
#  '영향': 1,
#  '짧다': 1,
#  '일품': 1,
#  '닫다': 1,
#  '우연히': 3,
#  '반지하': 1,
#  '안쪽': 1,
#  '군데': 3,
#  '한산하다': 1,
#  '이서': 1,
#  '계시다': 2,
#  '바로': 5,
#  '언제나': 1,
#  '진리': 1,
#  '태어나다': 1,
#  '눈물나다': 1,
#  'JMT': 1,
#  '생각나다': 1,
#  '이틀': 1,
#  'ㅋㅋㅋ': 1,
#  '완전': 2,
#  '그런데': 1,
#  '타이밍': 1,
#  '모든': 1,
#  '나가다': 1,
#  '두번째': 1,
#  '바질': 1,
#  '굳이': 2,
#  '필요': 1,
#  '온센': 2,
#  '다마': 2,
#  '고추가': 1,
#  '압구정': 1,
#  '찰지다': 1,
#  '우마': 1,
#  '1,000원': 1,
#  '싸다': 3,
#  '청결하다': 1,
#  '알맞다': 1,
#  '후반': 1,
#  '조합': 1,
#  '순서': 1,
#  '비우다': 2,
#  '시스템': 2,
#  ...}

# %%
# 테스트
import requests # from urllib.request import urlopen
from bs4 import BeautifulSoup # HTTP Response -> HTML 

import pandas as pd

from datetime import datetime


from selenium import webdriver
import time 
import re #정규 표현식 활용

from konlpy.tag import Twitter

# %%
## 작업중

# 이모티콘 없애기

TEXT = 'food_dining_review'

EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
TEXT_refine = EMOJI.sub(r'', TEXT)

def food_word_cloud(food_name):
    
    df = pd.read_excel('{}.xlsx'.format(food_name), encoding='utf-8')
    
    food_dining_review = df['다이닝코드리뷰'].dropna()
    food_dining_review = list(food_dining_review)
    food_dining_review = ' '.join(food_dining_review)
    
    
    TEXT = 'food_dining_review'

    EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
    TEXT_refine = EMOJI.sub(r'', TEXT)
    
    food_dining_review1 = food_dining_review[:5000]
    food_dining_review2 = food_dining_review[5000:10000]
    food_dining_review3 = food_dining_review[10000:15000]
    food_dining_review4 = food_dining_review[15000:20000]
    food_dining_review5 = food_dining_review[20000:25000]
    food_dining_review6 = food_dining_review[25000:]
    
    twitter = Twitter()
    raw_pos_tagged1 = twitter.pos(food_dining_review1, norm=True, stem=True) # POS Tagging
    raw_pos_tagged2 = twitter.pos(food_dining_review2, norm=True, stem=True) # POS Tagging
    raw_pos_tagged3 = twitter.pos(food_dining_review3, norm=True, stem=True) # POS Tagging
    raw_pos_tagged4 = twitter.pos(food_dining_review4, norm=True, stem=True) # POS Tagging
    raw_pos_tagged5 = twitter.pos(food_dining_review5, norm=True, stem=True) # POS Tagging
    raw_pos_tagged6 = twitter.pos(food_dining_review6, norm=True, stem=True) # POS Tagging

    
    raw_pos_tagged = []

    for raw_reviews in [food_dining_review1, food_dining_review2, food_dining_review3, food_dining_review4, food_dining_review5, food_dining_review6]:
        raw_pos_tagged += twitter.pos(raw_reviews, norm=True, stem=True)
        
    del_list = ['하다', '있다', '되다', '이다', '돼다', '않다', '그렇다', '아니다', '이렇다', '그렇다', '어떻다'] 

    word_cleaned = []
    for word in raw_pos_tagged: #  ('서울', 'Noun'),
        if not word[1] in ["Josa", "Eomi", "Punctuation", "Foreign"]: # Foreign == ”, “ 와 같이 제외되어야할 항목들
            if (len(word[0]) != 1) & (word[0] not in del_list): # 한 글자로 이뤄진 단어들을 제외 & 원치 않는 단어들을 제외
                word_cleaned.append(word[0])

    word_dic = {}

    for word in word_cleaned:
        if word not in word_dic:
            word_dic[word] = 1 # changed from "0" to "1"
        else:
            word_dic[word] += 1
    
    return word_dic

# %%
# 테스트
import requests # from urllib.request import urlopen
from bs4 import BeautifulSoup # HTTP Response -> HTML 

import pandas as pd

from datetime import datetime


from selenium import webdriver
import time 
import re #정규 표현식 활용

from konlpy.tag import Twitter

# 이모티콘 없애기

# import re

TEXT = 'food_dining_review'

EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
TEXT_refine = EMOJI.sub(r'', TEXT)

# %%
food_word_cloud('삼겹살')
# Out:
# C:\Users\James\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
word_dic.items()
# Out:
# dict_items([('족발', 16), ('입문', 7), ('데려오다', 1), ('곧바로', 1), ('보쌈', 4), ('파가', 1), ('오히려', 4), ('입맛', 11), ('너무', 45), ('까다롭다', 1), ('걱정', 2), ('앞다리', 2), ('부드럽다', 19), ('인기', 2), ('많다', 41), ('맵다', 10), ('양념', 14), ('소스', 6), ('맛있다', 93), ('자다', 34), ('먹다', 132), ('나로', 1), ('써다', 3), ('몇개', 1), ('집다', 3), ('싶다', 24), ('시키다', 19), ('조금', 30), ('곁들이다', 2), ('나오니', 2), ('방문', 25), ('라면', 5), ('참고', 4), ('같이', 21), ('나오다', 34), ('비냉', 5), ('막국수', 9), ('어지간하다', 1), ('냉면집', 18), ('그리다', 3), ('기지', 1), ('근처', 9), ('점도', 3), ('인분', 8), ('가격', 38), ('쎄다', 3), ('편이', 5), ('그래도', 7), ('놓치다', 2), ('없다', 47), ('vs', 1), ('무조건', 7), ('정도', 23), ('파이다', 1), ('여기', 3), ('보고', 6), ('자주', 13), ('오다', 13), ('우선', 2), ('특유', 8), ('냄새', 3), ('하나', 14), ('나다', 10), ('고기', 46), ('정말', 16), ('야들야들하다', 4), ('쑥쑥', 1), ('들어가다', 21), ('말다', 5), ('조합', 4), ('막히다', 2), ('그리고', 8), ('느끼하다', 8), ('즈음', 1), ('된장국', 1), ('마시다', 2), ('속이다', 3), ('풀리다', 1), ('시원하다', 5), ('좋아하다', 22), ('들이다', 3), ('특히', 7), ('맛보다', 6), ('야하다', 3), ('위치', 9), ('당산역', 3), ('내다', 11), ('바로', 5), ('접근성', 1), ('좋다', 93), ('찾기', 1), ('쉬다', 2), ('교통', 1), ('약속', 2), ('잡기', 1), ('친절', 3), ('대체로', 1), ('친절하다', 19), ('손님', 10), ('반찬', 6), ('같다', 41), ('셀프', 1), ('가져오다', 2), ('빨르다', 2), ('수육', 7), ('웬만하다', 1), ('이집', 4), ('라지', 2), ('주다', 14), ('비냉맛', 1), ('잇다', 3), ('자르다', 1), ('덩이', 1), ('되어다', 13), ('전반', 6), ('간이', 10), ('세다', 4), ('계란찜', 1), ('밸런스', 2), ('맞다', 9), ('jmt', 1), ('양은', 3), ('대비', 6), ('적지', 1), ('허브', 1), ('함께', 17), ('유명하다', 18), ('맛집', 40), ('개인', 19), ('평범하다', 4), ('동행', 1), ('사람', 17), ('바쁘다', 5), ('보이다', 5), ('정신', 2), ('화장실', 1), ('많이', 21), ('별로', 9), ('soso', 1), ('2.5', 1), ('만점', 1), ('차로', 1), ('가다', 31), ('불구', 2), ('도보', 1), ('1분', 1), ('갈수', 1), ('장점', 3), ('비빔냉면', 17), ('ㅋㅋ', 3), ('들다', 24), ('추천', 19), ('한글날', 1), ('데리', 1), ('분당', 1), ('정자동', 1), ('윤밀원', 1), ('평양', 113), ('냉면', 183), ('곰탕', 8), ('국수', 10), ('주문', 21), ('면발', 13), ('함량', 3), ('식감', 8), ('육수', 81), ('동치미', 5), ('짙다', 2), ('양지', 4), ('보지', 4), ('특색', 3), ('깊다', 8), ('칼칼하다', 2), ('잡다', 8), ('국물', 37), ('그다지', 1), ('깨끗하다', 2), ('개운하다', 4), ('다음', 6), ('보다', 34), ('주택가', 1), ('가로수', 1), ('단풍', 1), ('가을', 2), ('정취', 1), ('도심', 1), ('느끼다', 16), ('더욱', 1), ('가족', 1), ('요즘', 5), ('유행', 2), ('스타일', 12), ('제공', 3), ('고수', 3), ('깔끔하다', 38), ('역시', 10), ('무난', 4), ('칼국수', 10), ('대기', 7), ('일단', 9), ('입장', 1), ('음식', 28), ('빨리', 2), ('서비스', 8), ('기분', 4), ('식사', 18), ('가능하다', 6), ('주차', 13), ('공영', 2), ('주차장', 6), ('번째', 1), ('사진', 7), ('두번째', 2), ('세번', 2), ('종류', 4), ('늘다', 3), ('희다', 6), ('빨갛다', 1), ('가지', 3), ('순하다', 4), ('담백하다', 9), ('자극', 7), ('또한', 7), ('단백', 2), ('멀리', 1), ('갈다', 11), ('아주', 30), ('괜찮다', 22), ('선택', 4), ('의사', 3), ('상당하다', 2), ('대식', 1), ('가가', 1), ('인원', 2), ('적다', 10), ('경우', 4), ('전체', 12), ('고급', 5), ('지고', 1), ('어른', 1), ('아이', 7), ('메뉴', 23), ('어리다', 2), ('먹기', 8), ('거기', 2), ('대시', 1), ('진짜', 7), ('녹다', 1), ('나이', 2), ('상관없다', 1), ('즐기다', 3), ('행복하다', 1), ('장소', 3), ('골목', 2), ('호점', 2), ('가깝다', 7), ('붙다', 9), ('군데', 1), ('좁다', 6), ('회식', 3), ('예약', 3), ('겨우', 2), ('자리', 8), ('원래', 8), ('안되다', 7), ('대다', 4), ('우리', 2), ('약간', 11), ('난관', 1), ('신선하다', 1), ('굽다', 18), ('안데스', 1), ('소금', 3), ('와사비', 2), ('갈치', 1), ('각각', 2), ('찍다', 6), ('사먹다', 1), ('존맛', 1), ('웨이', 9), ('가보다', 8), ('고깃집', 2), ('특출나다', 1), ('부족하다', 5), ('목살', 3), ('쫄깃', 4), ('항정살', 2), ('탱글탱글', 1), ('적당하다', 11), ('기르다', 2), ('나물', 1), ('황태', 1), ('콩나물', 1), ('간도', 5), ('된장찌개', 5), ('간세', 1), ('야채', 6), ('찌개', 1), ('느낌', 24), ('ㅎㅎ', 7), ('직원', 7), ('편하다', 8), ('코로나', 1), ('시국', 1), ('그냥', 8), ('비싸다', 9), ('인생', 1), ('삼겹살', 4), ('가게', 8), ('발견', 4), ('밑반찬', 5), ('워낙', 4), ('서다', 3), ('감안', 3), ('이미', 1), ('솔드아웃', 1), ('육즙', 3), ('가득하다', 3), ('만족하다', 7), ('발렛비', 3), ('2천원', 1), ('후불', 1), ('솔직하다', 4), ('기대', 3), ('다른', 26), ('유명', 6), ('평냉', 22), ('아쉽다', 13), ('찰기', 1), ('불고기', 14), ('전혀', 4), ('착하다', 3), ('조용하다', 2), ('고개', 1), ('진미', 5), ('가세', 2), ('자라다', 1), ('시작', 3), ('절대', 2), ('실패하다', 2), ('여기다', 3), (' ...

# %%
# lambda 함수를 활용하여,
# 앞서 만든 dict를 item 단위(tuple)로 꺼내어, tuple(x)의 value(x[1])를 기준으로 하여 내림차순(reverse=True) 정렬합니다.

sorted_word_dic = sorted(word_dic.items(), key=lambda x:x[1], reverse=True)
sorted_word_dic
# Out:
# [('먹다', 148),
#  ('맛있다', 109),
#  ('좋다', 68),
#  ('텐동', 47),
#  ('튀김', 40),
#  ('보다', 37),
#  ('없다', 35),
#  ('들다', 31),
#  ('장어', 29),
#  ('같다', 28),
#  ('방문', 28),
#  ('맛집', 27),
#  ('가다', 27),
#  ('카레', 27),
#  ('너무', 26),
#  ('나오다', 25),
#  ('가격', 25),
#  ('정도', 25),
#  ('싶다', 24),
#  ('커리', 24),
#  ('자다', 23),
#  ('많다', 23),
#  ('정말', 22),
#  ('조금', 21),
#  ('메뉴', 20),
#  ('가게', 20),
#  ('느끼하다', 20),
#  ('덮다', 19),
#  ('주문', 19),
#  ('처음', 19),
#  ('그냥', 18),
#  ('소스', 18),
#  ('웨이팅', 17),
#  ('괜찮다', 17),
#  ('일본', 16),
#  ('시키다', 16),
#  ('추천', 16),
#  ('시간', 15),
#  ('적당하다', 14),
#  ('식사', 14),
#  ('재료', 14),
#  ('아쉽다', 14),
#  ('분위기', 14),
#  ('음식', 14),
#  ('고기', 14),
#  ('배부르다', 13),
#  ('엄청', 13),
#  ('아주', 13),
#  ('소바', 13),
#  ('사람', 13),
#  ('비비다', 12),
#  ('가보다', 12),
#  ('카이센동', 12),
#  ('새우', 12),
#  ('모두', 12),
#  ('느끼다', 12),
#  ('친절하다', 12),
#  ('직원', 12),
#  ('크다', 12),
#  ('부드럽다', 12),
#  ('진짜', 11),
#  ('하나', 11),
#  ('오다', 11),
#  ('다른', 11),
#  ('추가', 11),
#  ('살짝', 11),
#  ('깔끔하다', 10),
#  ('많이', 10),
#  ('분들', 10),
#  ('되어다', 10),
#  ('나다', 10),
#  ('알다', 10),
#  ('편이', 10),
#  ('인도', 10),
#  ('적다', 10),
#  ('주차', 10),
#  ('비싸다', 10),
#  ('받다', 10),
#  ('정식', 9),
#  ('위치', 9),
#  ('마지막', 9),
#  ('자리', 9),
#  ('신선하다', 9),
#  ('테이블', 9),
#  ('맛보다', 9),
#  ('느낌', 9),
#  ('식당', 9),
#  ('하지만', 9),
#  ('마제', 9),
#  ('남다', 9),
#  ('튀기다', 9),
#  ('부시', 8),
#  ('해주다', 8),
#  ('손님', 8),
#  ('수도', 8),
#  ('참고', 8),
#  ('들어가다', 8),
#  ('양념', 8),
#  ('유명하다', 8),
#  ('라씨', 8),
#  ('바삭', 8),
#  ('같이', 7),
#  ('가능하다', 7),
#  ('기다리다', 7),
#  ('해산물', 7),
#  ('오픈', 7),
#  ('저녁', 7),
#  ('훌륭하다', 7),
#  ('와사비', 7),
#  ('매장', 7),
#  ('부족하다', 7),
#  ('서비스', 7),
#  ('기본', 7),
#  ('버터', 7),
#  ('친구', 7),
#  ('치킨', 7),
#  ('새롭다', 7),
#  ('입장', 7),
#  ('계란', 7),
#  ('다양하다', 7),
#  ('양고기', 7),
#  ('점심', 6),
#  ('특별하다', 6),
#  ('만들다', 6),
#  ('특히', 6),
#  ('조용하다', 6),
#  ('웨이', 6),
#  ('브레이크', 6),
#  ('타임', 6),
#  ('대기', 6),
#  ('서빙', 6),
#  ('모르다', 6),
#  ('다시', 6),
#  ('간장', 6),
#  ('일단', 6),
#  ('직접', 6),
#  ('다음', 6),
#  ('감다', 6),
#  ('무난', 6),
#  ('뿌리다', 6),
#  ('따로', 6),
#  ('그래도', 6),
#  ('비슷하다', 6),
#  ('주차장', 6),
#  ('그리고', 6),
#  ('양도', 6),
#  ('200', 6),
#  ('별로', 6),
#  ('고로케', 6),
#  ('정갈하다', 5),
#  ('가면', 5),
#  ('기분', 5),
#  ('좋아하다', 5),
#  ('해보다', 5),
#  ('가장', 5),
#  ('사이드', 5),
#  ('제공', 5),
#  ('매우', 5),
#  ('없이', 5),
#  ('따르다', 5),
#  ('근처', 5),
#  ('좁다', 5),
#  ('방법', 5),
#  ('맞다', 5),
#  ('앉다', 5),
#  ('생각', 5),
#  ('ㅠㅠ', 5),
#  ('느껴지다', 5),
#  ('시금치', 5),
#  ('의사', 5),
#  ('이상', 5),
#  ('기다', 5),
#  ('전문점', 5),
#  ('가지', 5),
#  ('약간', 5),
#  ('최고', 5),
#  ('지금', 5),
#  ('ㅎㅎ', 5),
#  ('먹음', 5),
#  ('찾다', 5),
#  ('우동', 5),
#  ('전체', 5),
#  ('망고', 5),
#  ('입맛', 5),
#  ('보고', 5),
#  ('토마토', 5),
#  ('달달', 5),
#  ('계속', 5),
#  ('찾아가다', 5),
#  ('원래', 5),
#  ('하이', 5),
#  ('굉장하다', 5),
#  ('짜다', 5),
#  ('걸리다', 5),
#  ('차다', 5),
#  ('바로', 5),
#  ('한번', 5),
#  ('나고야', 4),
#  ('먹기', 4),
#  ('기대', 4),
#  ('그렇게', 4),
#  ('히쯔', 4),
#  ('요리', 4),
#  ('마리', 4),
#  ('남성', 4),
#  ('간이', 4),
#  ('어울리다', 4),
#  ('계란찜', 4),
#  ('예약', 4),
#  ('말다', 4),
#  ('타다', 4),
#  ('혼밥', 4),
#  ('적절하다', 4),
#  ('절임', 4),
#  ('항상', 4),
#  ('다소', 4),
#  ('이집', 4),
#  ('금방', 4),
#  ('일찍', 4),
#  ('인분', 4),
#  ('내부', 4),
#  ('공간', 4),
#  ('상당하다', 4),
#  ('안되다', 4),
#  ('최근', 4),
#  ('개인', 4),
#  ('제일', 4),
#  ('11시', 4),
#  ('수가', 4),
#  ('리필', 4),
#  ('대비', 4),
#  ('역시', 4),
#  ('다시마', 4),
#  ('식초', 4),
#  ('다지다', 4),
#  ('드림', 4),
#  ('갈다', 4),
#  ('국물', 4),
#  ('충분하다', 4),
#  ('30', 4),
#  ('노른자', 4),
#  ('터뜨리다', 4),
#  ('내다', 4),
#  ('본점', 4),
#  ('체크', 4),
#  ('특이하다', 4),
#  ('새우다', 4),
#  ('두다', 4),
#  ('맥주', 4),
#  ('종류', 4),
#  ('여기다', 4),
#  ('부분', 4),
#  ('히츠', 4),
#  ('고옥', 4),
#  ('굽다', 4),
#  ('매실', 4),
#  ('생기다', 4),
#  ('식감', 4),
#  ('퀄리티', 4),
#  ('주다', 4),
#  ('코로나', 4),
#  ('불편하다', 4),
#  ('가성', 4),
#  ('돈까스', 4),
#  ('다르다', 4),
#  ('돈가츠', 4),
#  ('소금', 4),
#  ('카츠', 4),
#  ('돈가스', 4),
#  ('아쉬움', 4),
#  ('평이', 3),
#  ('미니', 3),
#  ('가득하다', 3),
#  ('색다르다', 3),
#  ('육수', 3),
#  ('넣다', 3),
#  ('오차', 3),
#  ('예전', 3),
#  ('요즘', 3),
#  ('가야', 3),
#  ('나서다', 3),
#  ('조리', 3),
#  ('비리다', 3),
#  ('단맛', 3),
#  ('시간대', 3),
#  ('오늘', 3),
#  ('비다', 3),
#  ('거의', 3),
#  ('자체', 3),
#  ('대부분', 3),
#  ('펴다', 3),
#  ('오복', 3),
#  ('수산', 3),
#  ('주말', 3),
#  ('소진', 3),
#  ('서다', 3),
#  ('워낙', 3),
#  ('작다', 3),
#  ('여러', 3),
#  ('얼마', 3),
#  ('정성', 3),
#  ('확인', 3),
#  ('인테리어', 3),
#  ('경우', 3),
#  ('길다', 3),
#  ('그닥', 3),
#  ('크게', 3),
#  ('20분', 3),
#  ('전반', 3),
#  ('강하다', 3),
#  ('ㅎㅎㅎ', 3),
#  ('샐러드', 3),
#  ('야채', 3),
#  ('서울', 3),
#  ('기대하다', 3),
#  ('휴업', 3),
#  ('달라', 3),
#  ('도착', 3),
#  ('10', 3),
#  ('그릇', 3),
#  ('달걀', 3),
#  ('대박', 3),
#  ('가까이', 3),
#  ('늘다', 3),
#  ('이해', 3),
#  ('쏘다', 3),
#  ('플레인', 3),
#  ('살이', 3),
#  ('향신료', 3),
#  ('팔락', 3),
#  ('현지', 3),
#  ('여기', 3),
#  ('반찬', 3),
#  ('여름', 3),
#  ('후쿠오카', 3),
#  ('부산', 3),
#  ('양은', 3),
#  ('밑반찬', 3),
#  ('버섯', 3),
#  ('찍다', 3),
#  ('떨어지다', 3),
#  ('부타동', 3),
#  ('좌석', 3),
#  ('간도', 3),
#  ('사장', 3),
#  ('조화', 3),
#  ('넓다', 3),
#  ('영업', 3),
#  ('맞추다', 3),
#  ('저렴하다', 3),
#  ('푸다', 3),
#  ('타이가', 3),
#  ('빼다', 3),
#  ('메인', 3),
#  ('고소하다', 3),
#  ('어우러지다', 3),
#  ('스페셜', 3),
#  ('입가심', 3),
#  ('한국', 3),
#  ('우연히', 3),
#  ('군데', 3),
#  ('싸다', 3),
#  ('높다', 3),
#  ('로스', 3),
#  ('몸보', 2),
#  ('신용', 2),
#  ('블로그', 2),
#  ('후기', 2),
#  ('건가', 2),
#  ('반포', 2),
#  ('국내', 2),
#  ('민물장어', 2),
#  ('요리법', 2),
#  ('접목', 2),
#  ('사이즈', 2),
#  ('대개', 2),
#  ('여성', 2),
#  ('숯불', 2),
#  ('베인', 2),
#  ('메뉴판', 2),
#  ('명시', 2),
#  ('함께', 2),
#  ('발렛', 2),
#  ('어버이날', 2),
#  ('아이', 2),
#  ('선물', 2),
#  ('마루', 2),
#  ('언제', 2),
#  ('가도', 2),
#  ('한결같이', 2),
#  ('반감', 2),
#  ('자신', 2),
#  ('참치', 2),
#  ('연어', 2),
#  ('올리다', 2),
#  ('서서', 2),
#  ('달라지다', 2),
#  ('찾아보다', 2),
#  ('지나가다', 2),
#  ('담다', 2),
#  ('구성', 2),
#  ('가치', 2),
#  ('오랜', 2),
#  ('천원', 2),
#  ('배기', 2),
#  ('빠르다', 2),
#  ('진시', 2),
#  ('마감', 2),
#  ('유지', 2),
#  ('당산', 2),
#  ('동네', 2),
#  ('시기', 2),
#  ('지나다', 2),
#  ('사용', 2),
#  ('만큼', 2),
#  ('금요일', 2),
#  ('7시', 2),
#  ('마주', 2),
#  ('실내', 2),
#  ('나머지', 2),
#  ('일일이', 2),
#  ('기준', 2),
#  ('아깝다', 2),
#  ('가시다', 2),
#  ('짜지다', 2),
#  ('바뀌다', 2),
#  ('별미', 2),
#  ('4.0', 2),
#  ('깊다', 2),
#  ('필수', 2),
#  ('오시', 2),
#  ('무슨', 2),
#  ('궁금하다', 2),
#  ('중간', 2),
#  ('메뉴인', 2),
#  ('키마', 2),
#  ('위해', 2),
#  ('세트', 2),
#  ('무엇', 2),
#  ('깨끗하다', 2),
#  ('사실', 2),
#  ('빠지다', 2),
#  ('그건', 2),
#  ('공기밥', 2),
#  ('나중', 2),
#  ('간식', 2),
#  ('마늘', 2),
#  ('후추', 2),
#  ('가시', 2),
#  ('감칠맛', 2),
#  ('잊다', 2),
#  ('바라다', 2),
#  ('찾아오다', 2),
#  ('1일', 2),
#  ('한정판', 2),
#  ('도니', 2),
#  ('쿠나', 2),
#  ('야마', 2),
#  ('얼핏', 2),
#  ('아슬하다', 2),
#  ('종업원', 2),
#  ('호출', 2),
#  ('여분', 2),
#  ('드뎌', 2),
#  ('비쥬', 2),
#  ('섞다', 2),
#  ('라멘', 2),
#  ('도니쿠', 2),
#  ('꿀꺽', 2),
#  ('넘어가다', 2),
#  ('난생', 2),
#  ('행복하다', 2),
#  ('지점', 2),
#  ('손소독', 2),
#  ('안내받다', 2),
#  ('끊임없다', 2),
#  ('오이', 2),
#  ('메시', 2),
#  ('잘못', 2),
#  ('프라', 2),
#  ('껍질', 2),
#  ('대충', 2),
#  ('끄다', 2),
#  ('중요하다', 2),
#  ('파니', 2),
#  ('안주', 2),
#  ('평범하다', 2),
#  ('싫어하다', 2),
#  ('대신', 2),
#  ('호불호', 2),
#  ('인근', 2),
#  ('1시간', 2),
#  ('무료', 2),
#  ('만원', 2),
#  ('얹다', 2),
#  ('1/2', 2),
#  ('마련', 2),
#  ('비리', 2),
#  ('끼리', 2),
#  ('또는', 2),
#  ('간단하다', 2),
#  ('쎄다', 2),
#  ('냄새', 2),
#  ('자리다', 2),
#  ('지인', 2),
#  ('6시', 2),
#  ('시작', 2),
#  ('넘다', 2),
#  ('적히다', 2),
#  ('골목', 2),
#  ('아나고', 2),
#  ('마르다', 2),
#  ('입구', 2),
#  ('오스', 2),
#  ('거기', 2),
#  ('먼저', 2),
#  ('편하다', 2),
#  ('이렇게', 2),
#  ('옮기다', 2),
#  ('가깝다', 2),
#  ('해운대', 2),
#  ('캐널', 2),
#  ('시티', 2),
#  ('타카', 2),
#  ('전수', 2),
#  ('실하다', 2),
#  ('달다', 2),
#  ('9,000원', 2),
#  ('때문', 2),
#  ('존맛', 2),
#  ('다만', 2),
#  ('감자', 2),
#  ('기름', 2),
#  ('얇다', 2),
#  ('함박스테이크', 2),
#  ('포슬포슬', 2),
#  ('스타일', 2),
#  ('어렵다', 2),
#  ('주의', 2),
#  ('이미', 2),
#  ('힘들다', 2),
#  ('유자', 2),
#  ('상큼', 2),
#  ('집중', 2),
#  ('전복', 2),
#  ('올라가다', 2),
#  ('부르다', 2),
#  ('세심', 2),
#  ('요거트', 2),
#  ('엄청나다', 2),
#  ('마음', 2),
#  ('계시다', 2),
#  ('완전', 2),
#  ('굳이', 2),
#  ('온센', 2),
#  ('다마', 2),
#  ('비우다', 2),
#  ('시스템', 2),
#  ('돈카츠', 2),
#  ('지다', 2),
#  ('벅차다', 2),
#  ('또한', 2),
#  ('여러가지', 2),
#  ('이후', 2),
#  ('가츠산도', 2),
#  ('씹다', 2),
#  ('올리브오일', 2),
#  ('한가지', 2),
#  ('특색', 2),
#  ('일반', 2),
#  ('그런', 2),
#  ('세다', 2),
#  ('바람', 2),
#  ('가끔', 2),
#  ('들르다', 2),
#  ('돈까쓰', 2),
#  ('캐다', 2),
#  ('갈비', 2),
#  ('프렌치', 2),
#  ('발레', 2),
#  ('화로', 2),
#  ('바다', 2),
#  ('찌리', 2),
#  ('에피타이저', 2),
#  ('디저트', 2),
#  ('군자역', 2),
#  ('성대', 1),
#  ('1.5만원', 1),
#  ('스끼야끼', 1),
#  ('대접받다', 1),
#  ('어느', 1),
#  ('퍼먹어', 1),
#  ('관자', 1),
#  ('오징어', 1),
#  ('계란말이', 1),
#  ('날치', 1),
#  ('무시', 1),
#  ('된장국', 1),
#  ('평일', 1),
#  ('이유', 1),
#  ('납득', 1),
#  ('계절', 1),
#  ('리뷰', 1),
#  ('대한', 1),
#  ('자부심', 1),
#  ('성공하다', 1),
#  ('진작', 1),
#  ('상황', 1),
#  ('팅할', 1),
#  ('겨를', 1),
#  ('그만하다', 1),
#  ('한다는', 1),
#  ('여타', 1),
#  ('1.2', 1),
#  ('1.3만원', 1),
#  ('상당', 1),
#  ('덥다', 1),
#  ('진또', 1),
#  ('협소해', 1),
#  ('생기', 1),
#  ('그만큼', 1),
#  ('회전', 1),
#  ('율도', 1),
#  ('특성', 1),
#  ('양으로', 1),
#  ('욕먹다', 1),
#  ('대해', 1),
#  ('놀라다', 1),
#  ('곱창', 1),
#  ('보쌈', 1),
#  ('명맥', 1),
#  ('힘드다', 1),
#  ('주민', 1),
#  ('협소', 1),
#  ('판매', 1),
#  ('중단', 1),
#  ('존재', 1),
#  ('드디어', 1),
#  ('다그', 1),
#  ('사이', 1),
#  ('소문', 1),
#  ('알려지다', 1),
#  ('퇴근', 1),
#  ('자마자', 1),
#  ('2~3', 1),
#  ('10~15분', 1),
#  ('무리', 1),
#  ('기석', 1),
#  ('스키야키', 1),
#  ('이면', 1),
#  ('먹어주다', 1),
#  ('태도', 1),
#  ('고양', 1),
#  ('적지', 1),
#  ('성인', 1),
#  ('모자라다', 1),
#  ('연남동', 1),
#  ('출발', 1),
#  ('여의도', 1),
#  ('평가', 1),
#  ('시즈오카', 1),
#  ('우미', 1),
#  ('노미', 1),
#  ('확실하다', 1),
#  ('떠나다', 1),
#  ('역대', 1),
#  ('전혀', 1),
#  ('싱싱하다', 1),
#  ('12시', 1),
#  ('즈음', 1),
#  ('시즌', 1),
#  ('우리', 1),
#  ('뭔가', 1),
#  ('동양', 1),
#  ('물씬', 1),
#  ('풍기다', 1),
#  ('강렬하다', 1),
#  ('손질', 1),
#  ('가득', 1),
#  ('평상시', 1),
#  ('종종', 1),
#  ('카페', 1),
#  ('인스타', 1),
#  ('감성', 1),
#  ('사진', 1),
#  ('찍기', 1),
#  ('3.0', 1),
#  ('임재', 1),
#  ('아직', 1),
#  ('보지', 1),
#  ('우유', 1),
#  ('물컹물컹하다', 1),
#  ('씹히다', 1),
#  ('유쾌하다', 1),
#  ('간판', 1),
#  ('자주', 1),
#  ('솔드아웃', 1),
#  ('대표', 1),
#  ('21500원', 1),
#  ('결제', 1),
#  ('한쪽', 1),
#  ('정숙', 1),
#  ('붙이다', 1),
#  ('조금씩', 1),
#  ('오뚜기', 1),
#  ('3분', 1),
#  ('해주시', 1),
#  ('깍두기', 1),
#  ('짭짤하다', 1),
#  ('ㅠㅜ', 1),
#  ('결정', 1),
#  ('장애', 1),
#  ('아담하다', 1),
#  ('소박하다', 1),
#  ('핵심', 1),
#  ('버터치킨', 1),
#  ('거짓말', 1),
#  ('보태', 1),
#  ('감사하다', 1),
#  ('히쯔마부시', 1),
#  ('우나쥬', 1),
#  ('회식', 1),
#  ('해봤다', 1),
#  ('쏘이다', 1),
#  ('신맛', 1),
#  ('바나나', 1),
#  ('과일', 1),
#  ('탄두리', 1),
#  ('튼실하다', 1),
#  ('바짝', 1),
#  ('말르다', 1),
#  ('배다', 1),
#  ('다난', 1),
#  ('쫄깃쫄깃해', 1),
#  ('굿굿', 1),
#  ('난도', 1),
#  ('다가', 1),
#  ('특유', 1),
#  ('나쁘다', 1),
#  ('푸드', 1),
#  ('따다', 1),
#  ('실제', 1),
#  ('노래', 1),
#  ('티비', 1),
#  ('뮤비', 1),
#  ('예티', 1),
#  ('시도', 1),
#  ('티벳', 1),
#  ('국수', 1),
#  ('한국인', 1),
#  ('싫다', 1),
#  ('비추다', 1),
#  ('입천장', 1),
#  ('난이', 1),
#  ('마냥', 1),
#  ('갈리다', 1),
#  ('소개', 1),
#  ('베이스', 1),
#  ('차이', 1),
#  ('예쁘다', 1),
#  ('8~10', 1),
#  ('인원', 1),
#  ('홍대', 1),
#  ('무조건', 1),
#  ('밥집', 1),
#  ('영수증', 1),
#  ('내면', 1),
#  ('할인', 1),
#  ('까다롭다', 1),
#  ('초복', 1),
#  ('중복', 1),
#  ('말복', 1),
#  ('하루', 1),
#  ('들리다', 1),
#  ('따라가다', 1),
#  ('심지어', 1),
#  ('본연', 1),
#  ('살리다', 1),
#  ('텁텁하거', 1),
#  ('건조하다', 1),
#  ('수분', 1),
#  ('동일하다', 1),
#  ('장어구이', 1),
#  ('그것', 1),
#  ('설명', 1),
#  ('보시', 1),
#  ('정독', 1),
#  ('4등', 1),
#  ('자기', 1),
#  ('조심하다', 1),
#  ('ㅜㅜㅋㅋ', 1),
#  ('만족하다', 1),
#  ('숟가락', 1),
#  ('정돈', 1),
#  ('어떻', 1),
#  ('GS', 1),
#  ('찍히다', 1),
#  ('세무서', 1),
#  ('민영', 1),
#  ('지원', 1),
#  ('모양', 1),
#  ('아오', 1),
#  ('우메', 1),
#  ('파다', 1),
#  ('다기', 1),
#  ('물렁물렁하다', 1),
#  ('33', 1),
#  ('쬐다', 1),
#  ('촉촉하다', 1),
#  ('보통', 1),
#  ('상임', 1),
#  ('베니', 1),
#  ('빨갛다', 1),
#  ('생강', 1),
#  ('락교', 1),
#  ('하얀색', 1),
#  ('염통', 1),
#  ('완제', 1),
#  ('제품', 1),
#  ('단가', 1),
#  ('편일', 1),
#  ('커플', 1),
#  ('곳임', 1),
#  ('체적', 1),
#  ('미터', 1),
#  ('읽다', 1),
#  ('비빔밥', 1),
#  ('아무리', 1),
#  ('감동', 1),
#  ('신촌', 1),
#  ('피크타임', 1),
#  ('홋카이도', 1),
#  ('팔다', 1),
#  ('기지', 1),
#  ('든든하다', 1),
#  ('단체', 1),
#  ('가기', 1),
#  ('적합하다', 1),
#  ('세명', 1),
#  ('주인', 1),
#  ('건강', 1),
#  ('사정', 1),
#  ('오랫동안', 1),
#  ('열다', 1),
#  ('형식', 1),
#  ('끼니', 1),
#  ('꾸다', 1),
#  ('불맛', 1),
#  ('물리다', 1),
#  ('취향', 1),
#  ('넘어서다', 1),
#  ('밀리다', 1),
#  ('30분', 1),
#  ('여유', 1),
#  ('안남', 1),
#  ('기고', 1),
#  ('가능', 1),
#  ('명단', 1),
#  ('이름', 1),
#  ('번호', 1),
#  ('작성', 1),
#  ('연락', 1),
#  ('데카', 1),
#  ('아무래도', 1),
#  ('세팅', 1),
#  ('시진', 1),
#  ('길가', 1),
#  ('딱지', 1),
#  ('떼다', 1),
#  ('대놓고', 1),
#  ('기다림', 1),
#  ('젊다', 1),
#  ('열심히', 1),
#  ('아마추어', 1),
#  ('편임', 1),
#  ('바삭바삭', 1),
#  ('마파두부', 1),
#  ('러버', 1),
#  ('로써', 1),
#  ('만족', 1),
#  ('다녀오다', 1),
#  ('좌측', 1),
#  ('착석', 1),
#  ('그걸', 1),
#  ('헤매다', 1),
#  ('씻다', 1),
#  ('고추', 1),
#  ('반숙', 1),
#  ('접시', 1),
#  ('덜다', 1),
#  ('머쓱하다', 1),
#  ('바삭바삭하다', 1),
#  ('달짝지근하다', 1),
#  ('중독', 1),
#  ('남기다', 1),
#  ('부족함', 1),
#  ('숨다', 1),
#  ('해운대해수욕장', 1),
#  ('여행', 1),
#  ('상권', 1),
#  ('텐투파', 1),
#  ('레시피', 1),
#  ('한지', 1),
#  ('15', 1),
#  ('맞은편', 1),
#  ('전용', 1),
#  ('시설', 1),
#  ('5분', 1),
#  ('충실하다', 1),
#  ('10,000원', 1),
#  ('도의', 1),
#  ('토핑', 1),
#  ('술안주', 1),
#  ('삼다', 1),
#  ('만족스럽다', 1),
#  ('19', 1),
#  ('망하다', 1),
#  ('텐푸', 1),
#  ('푸르다', 1),
#  ('짱짱', 1),
#  ('수준', 1),
#  ('실력', 1),
#  ('해도', 1),
#  ('역사', 1),
#  ('일만', 1),
#  ('제외', 1),
#  ('데리야끼', 1),
#  ('지지', 1),
#  ('오므라이스', 1),
#  ('짭쪼롬', 1),
#  ('뭉치다', 1),
#  ('함박', 1),
#  ('퍼석', 1),
#  ('속이다', 1),
#  ('비법', 1),
#  ('꿀맛', 1),
#  ('평타', 1),
#  ('치다', 1),
#  ('옛날', 1),
#  ('새다', 1),
#  ('덜하다', 1),
#  ('근방', 1),
#  ('주차공간', 1),
#  ('쯔유', 1),
#  ('훨씬', 1),
#  ('줄이다', 1),
#  ('좀처럼', 1),
#  ('다웨이', 1),
#  ('산뜻하다', 1),
#  ('몇번', 1),
#  ('벗기다', 1),
#  ('유자청', 1),
#  ('TOP', 1),
#  ('인생', 1),
#  ('일본인', 1),
#  ('피셜', 1),
#  ('클라스', 1),
#  ('당연하다', 1),
#  ('녹다', 1),
#  ('기성품', 1),
#  ('승부', 1),
#  ('흔하다', 1),
#  ('알차다', 1),
#  ('최고다', 1),
#  ('쫀득', 1),
#  ('삼대', 1),
#  ('삼십분', 1),
#  ('또다른', 1),
#  ('문후', 1),
#  ('십오분', 1),
#  ('베다', 1),
#  ('예정', 1),
#  ('전국', 1),
#  ('탄두르', 1),
#  ('마살라', 1),
#  ('파니르', 1),
#  ('정확하다', 1),
#  ('판단', 1),
#  ('마카', 1),
#  ('하기는', 1),
#  ('쵸우', 1),
#  ('달기', 1),
#  ('허니', 1),
#  ('깔리다', 1),
#  ('심하다', 1),
#  ('걱정', 1),
#  ('데이트', 1),
#  ('소로', 1),
#  ('음식점', 1),
#  ('장점', 1),
#  ('이신', 1),
#  ('식다', 1),
#  ('속도', 1),
#  ('보여주다', 1),
#  ('바베큐', 1),
#  ('닭고기', 1),
#  ('각각', 1),
#  ('덩이', 1),
#  ('음료', 1),
#  ('땡기다', 1),
#  ...]

# %%
# 내림차순 정렬된 단어 중 상위 50개를 살펴보면 다음과 같습니다.


for word, count in sorted_word_dic[:50]:
    print("{0}({1})".format(word, count), end=" ")
# Out:
# 먹다(148) 맛있다(109) 좋다(68) 텐동(47) 튀김(40) 보다(37) 없다(35) 들다(31) 장어(29) 같다(28) 방문(28) 맛집(27) 가다(27) 카레(27) 너무(26) 나오다(25) 가격(25) 정도(25) 싶다(24) 커리(24) 자다(23) 많다(23) 정말(22) 조금(21) 메뉴(20) 가게(20) 느끼하다(20) 덮다(19) 주문(19) 처음(19) 그냥(18) 소스(18) 웨이팅(17) 괜찮다(17) 일본(16) 시키다(16) 추천(16) 시간(15) 적당하다(14) 식사(14) 재료(14) 아쉽다(14) 분위기(14) 음식(14) 고기(14) 배부르다(13) 엄청(13) 아주(13) 소바(13) 사람(13)

# %%
# WordCloud 패키지 import
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
word_cloud.generate_from_frequencies(word_dic) # Generate wordcloud from word "frequency" data.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-29ae4db7ff29> in <module>
# ----> 1 word_cloud.generate_from_frequencies(word_dic) # Generate wordcloud from word "frequency" data.
#
# NameError: name 'word_cloud' is not defined

# %%
# 아래 코드에 사용 가능한 것들
#                        max_words=50, # max words
#                        prefer_horizontal= 1.0, # 이 부분의 주석을 해제하시면 단어들이 가로로만 그려지게 됩니다. (0~1)

# %%
from PIL import Image

donkatsu_coloring = np.array(Image.open("카레카레.png"))

word_cloud = WordCloud(font_path="C:/Windows/Fonts/malgun.ttf", # font_path="C:/Windows/Fonts/NanumSquareB.ttf"
                       width=2000, height=1000, 
                       mask=donkatsu_coloring, # "마스크를 씌운다"라고 표현합니다. (masking)
                       background_color='white').generate_from_frequencies(word_dic)

plt.figure(figsize=(15,15))
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# 파일 저장하기

word_cloud.to_file("카레 completed.png")
