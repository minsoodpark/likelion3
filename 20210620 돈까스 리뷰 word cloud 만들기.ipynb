# %%
import requests # from urllib.request import urlopen
from bs4 import BeautifulSoup # HTTP Response -> HTML 

import pandas as pd

from datetime import datetime


from selenium import webdriver
import time 
import re #정규 표현식 활용

# %%
#망고플레이트에서 음식을 키워드로 맛집 리스트 가져오는 function
def get_rest_list(keyword):
    
    #페이지, 맛집리스트 초기화
    pagenum = 1
    restaurant_list = []
    
    #page별로 while 루프 돌려서 상호명 뽑아오기
    while pagenum <= 2: 
        try:
            url = 'https://www.mangoplate.com/search/?keyword='+keyword+'&page='+str(pagenum)#keyword를 input으로 망고플레이트 url 생성

            session = requests.Session()
            headers = {
            "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit 537.36 (KHTML, like Gecko) Chrome",
            "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8"
            }
            html = session.get(url, headers=headers).content 
            source = BeautifulSoup(html, 'html.parser')

            restaurants = source.find_all('h2', {'class' : 'title'}) #h2태그의 class 'title' => 상호명

            for restaurant in restaurants:#텍스트 깔끔하게 처리 및 리스트에 상호명 추가 루프

                n_restaurant = re.sub('\s', '', restaurant.get_text()) #텍스트 중간에 빈칸 없애기
                restaurant_list.append(n_restaurant)#리스트에 상호명 추가
        except:
            print(pagenum,'페이지 까지의 결과입니다.')
        
        pagenum += 1
        
    return restaurant_list #keyword 관련 맛집 리스트 생성

# %%
cnoodlelist = get_rest_list('냉면') #냉면 맛집 리스트 생성

# %%
cnoodlelist
# Out:
# ['허브족발(본점)',
#  '윤밀원',
#  '김진목삼',
#  '진미평양냉면',
#  '을지면옥',
#  '서관면옥',
#  '광릉한옥집',
#  '광화문국밥',
#  '춘향미엔',
#  '우래옥(을지로점)',
#  '설눈',
#  '봉밀가',
#  '봉피양(방이점)',
#  '미엔아이',
#  '윤선희의평양냉면양각도',
#  '청기와타운',
#  '서평면옥',
#  '몽탄',
#  '정인면옥',
#  '오장동흥남집(본점)',
#  '거대갈비',
#  '평안도상원냉면',
#  '명지원이동갈비',
#  '벽제갈비(신촌점)',
#  '공단떡볶이',
#  '고명집',
#  '우밀면옥',
#  '단천식당',
#  '명인등심(압구정점)',
#  '평남면옥',
#  '서정가야밀면',
#  '더진미평냉',
#  '명인등심(삼성직영점)',
#  '영동냉면',
#  '을밀대(본점)',
#  '능라도(강남점)',
#  '능라도(분당점)',
#  '강서면옥',
#  '옥돌현옥',
#  '진남포면옥']

# %%
currylist = get_rest_list('카레')

# %%
currylist
# Out:
# ['마루심',
#  '우미노미',
#  '카레',
#  '공기식당',
#  '요시즈카우나기야/吉塚うなぎ屋',
#  '마루심(마포점)',
#  '멘야하나비(신사점)',
#  '예티',
#  '고옥',
#  '홋카이도부타동스미레',
#  '데카망(휴업중)',
#  '요우란',
#  '온정',
#  '타이가텐푸라',
#  '오사카카레콘유',
#  '텐동요츠야',
#  '멘야하나비',
#  '깔리',
#  '우마텐',
#  '부타이',
#  '에베레스트(동대문점)',
#  '가츠오',
#  '교양식사',
#  '도요스6가',
#  '텐동한',
#  '현우동',
#  '라하노카레',
#  '포탈라(종로점)',
#  '후라토식당(아브뉴프랑판교점)',
#  '운멜로랩',
#  '이치젠(망원본점)',
#  'BARN110',
#  '후라토식당',
#  '오복수산(도산점)',
#  '우동카덴(연희점)',
#  '멘야코노하카레',
#  '사쿠텐',
#  '이코이',
#  '스아게/すあげ',
#  '주간소바식당산']

# %%
 url = 'https://www.mangoplate.com/search/?keyword='+'마루심' #상호명으로 망고플레이트 검색 url

session = requests.Session()
headers = {
"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit 537.36 (KHTML, like Gecko) Chrome",
"Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8"
}
html = session.get(url, headers=headers).content 
source = BeautifulSoup(html, 'html.parser')

rest_code = source.find('div',{'class':'list-restaurant-item'}).find('a')['href']
rest_code
# Out:
# '/restaurants/KU-4QO6Yvt'

# %%
for rest in currylist:
    get_mango_info(rest)
    print(rest,'의 정보 획득!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9f5e3a3a8626> in <module>
#       1 for rest in currylist:
# ----> 2     get_mango_info(rest)
#       3     print(rest,'의 정보 획득!')
#
# NameError: name 'get_mango_info' is not defined

# %%
def get_mango_info(restaurant):#상호명을 input으로 관련 정보 받아오는 function

    mango_info = {} #빈 dict 생성

    url = 'https://www.mangoplate.com/search/'+restaurant #상호명으로 망고플레이트 검색 url

    session = requests.Session()
    headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit 537.36 (KHTML, like Gecko) Chrome",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8"
    }
    html = session.get(url, headers=headers).content 
    source = BeautifulSoup(html, 'html.parser')
    
    try:
        rest_code = source.find('div',{'class':'list-restaurant-item'}).find('a')['href']#검색결과에서 첫번째 결과의 고유 코드 따오기 
        newurl = 'https://www.mangoplate.com'+rest_code #고유 코드 활용한 url 주소 생성
        newhtml = session.get(newurl, headers=headers).content 
        newsource = BeautifulSoup(newhtml, 'html.parser')

        rate = float(re.sub('\s','',newsource.find('strong',{'class':'rate-point'}).get_text()))#평점이 속한 태그에서 텍스트 가져와 float로 바꾸기 (나중에 계산 용이)

        rest_table = newsource.find('table',{'class':'info'})#관련 정보가 있는 테이블 경로

        address = rest_table.find_all('td')[0].find_all('span')[1].get_text()#주소
        phone = rest_table.find_all('td')[1].get_text()#전화번호
        kind = re.sub('\s','',rest_table.find_all('td')[2].get_text())#음식 종류(정규표현식 활용하여 깔끔하게 정리)
        price = rest_table.find_all('td')[3].get_text()#가격대

        #각각의 정보를 만든 dict의 key값의 value로 추가
        mango_info['name'] = restaurant
        mango_info['rate'] = rate
        mango_info['address'] = address
        mango_info['phone'] = phone
        mango_info['kind'] = kind
        mango_info['price'] = price
        
    except:
        mango_info['name'] = restaurant
        mango_info['rate'] = 'N/A'
        mango_info['address'] = 'N/A'
        mango_info['phone'] = 'N/A'
        mango_info['kind'] = 'N/A'
        mango_info['price'] = 'N/A'
    
    return mango_info #하나의 dict를 최종 값으로 return

# %%
print(get_mango_info('윤밀원'))
# Out:
# {'name': '윤밀원', 'rate': 4.6, 'address': '경기도 성남시 분당구 정자동 223-9', 'phone': '031-714-8388', 'kind': '국수/면요리', 'price': '만원 미만'}

# %%
def get_naver_info(restaurant): #네이버 평점 및 리뷰 가져오기
    
    naver_info = {}
    
    #정규표현식 활용해 상호명에 있는 괄호 및 특수문자 제거
    regex = "\(.*\)|\s-\s.*" 
    query = re.sub(regex, '', restaurant)
    
    url = "https://search.naver.com/search.naver?where=nexearch&sm=tab_jum&query=" + query
    web = requests.get(url).content
    source = BeautifulSoup(web, 'html.parser')
    
    try:
        reviewcount = int(source.find_all('span', {'class': 'count'})[1].get_text())
        rate = float(source.find_all('div', {'class': 'star_area'})[0].find('em').get_text())
    except:
        reviewcount = 'N/A'
        rate = 'N/A'
    
    naver_info['reviewcount'] = reviewcount
    naver_info['rate'] = rate
    
    return naver_info

# %%
print(get_naver_info('윤밀원'))
# Out:
# {'reviewcount': 'N/A', 'rate': 'N/A'}

# %%
def get_dining_info(restaurant): #다이닝코드 평점/별점/리뷰 가져오기
    
    dining_info = {}
    review_list = []
    
    #정규표현식 활용해 상호명에 있는 괄호 및 특수문자 제거
    regex = "\(.*\)|\s-\s.*"
    query = re.sub(regex, '', restaurant)
    
    url = 'https://www.diningcode.com/isearch.php?query=' + query
    web = requests.get(url).content
    source = BeautifulSoup(web, 'html.parser')
    
    #다이닝코드에 해당 식당이 없는 경우를 예상하여 try/except로 error 발생 시 'N/A'로 데이터 대체
    try:
        ul_tag = source.find('div', {'id':'div_rn'})
        li_tag = ul_tag.find('li')
        a_tag = li_tag.find('a')
        target_url = 'https://www.diningcode.com' + a_tag.attrs['href']
        target_url

        web_review = requests.get(target_url).content
        source_review = BeautifulSoup(web_review, 'html.parser')

        #평균 평점 꺼내기
        p_tag = source_review.find('p', {'class':'grade'})
        # p_tag
        review_point = int(p_tag.find('strong').get_text().replace('점',''))

        #평균 별점 꺼내기
        star_point = source_review.find('p', {'id':'lbl_star_point'}).get_text()
        star_point = star_point.replace("\n", "")
        star_point = float(star_point.replace('점',''))# 교체하다

        reviews = source_review.find_all('p',{'class':'review_contents btxt'})

        for review in reviews:
            review_list.append(re.sub('\n','',review.get_text()))

        dining_info['review_point'] = review_point
        dining_info['star_point'] = star_point
        dining_info['review'] = review_list
                               
    except:
        dining_info['review_point'] = 'N/A'
        dining_info['star_point'] = 'N/A'
        dining_info['review'] = 'N/A'
        
    return dining_info

# %%
print(get_dining_info('윤밀원'))
# Out:
# {'review_point': 67, 'star_point': 4.7, 'review': ['한글날 딸들을 데리고 분당 정자동 윤밀원으로  평양냉면 양곰탕 양지국수를 주문 평양냉면 면발 매밀함량 굿 식감 굿 육수는 동치미맛이 짙음 양지국수 먹어보지 못했던 특색있는 깊고 칼칼한 맛 굿 양 곰탕은 고기냄새는잘 잡았으나 국물은 그다지 깨끗하게 개운하지 못했음 다음엔 족발을 꼭 먹어봐야겠다 주택가에 위치해 가로수들이 단풍이들어 가을 정취를 도심에서 느낄수있어 더더욱 좋았던 가족나들이였습니다', '족발은 요즘 유행하는 스타일이고 제공되는 고수와 소스등으로 깔끔함. 평양냉면 역시 입문자가 먹어도 무난한 맛. 칼국수는 개인적으로 별로였습니다. 대기가 길지만 일단 입장하면 음식도 빨리 나오고 서비스도 좋아서 기분 좋게 식사 가능합니다. 주차는 근처 공영 주차장 추천합니다.', '첫번째 사진 : 양지칼국수두번째 사진 : 막국수세번째 사진 : 냉면칼국수 종류(양지칼국수, 칼국수)는 흰국물과 빨간국물 두가지 종류가 있다고 한다. 양지칼국수 흰국물로 시켰는데 순하고 담백한 맛이었다.막국수는 막국수보단 비빔냉면 같은 느낌이었다. 자극적이지 않으며 얘 또한 순하고 단백한 맛이었다.냉면은 평양냉면 스타일같고, 순한 맛이었다.총평 : 멀리갈게 아니라면 아주 괜찮은 선택지가 될거같다. 재방문의사 있음.양이 상당히 많다. 대식가가 아니라면 인원수보다 적게 시키는데 좋을거같으며, 족발을 시키는 경우에는 더 적게 시켜도 될거 같다. 전체적으로 고급지고 단백하고 순한 맛으로 어른들이 좋아할것 같고, 아이들도 칼국수와 막국수는 좋아할것 같다. 메뉴가 전체적으로 순한맛이라 막국수도 자극적이지 않아서 어린 아이들이 먹기 좋을거같다. 재방문의사 있음.', '근처에 공영 주차장이 있어서 거기에 차 대시면 됩니다. 막국수가 진짜 부드럽게 녹아요. 맛있어요. 족발도 잡내 없고 정말 맛있네요.', '나이와 상관없이 맛난 음식을 즐길수있는 행복한 장소']}

# %%
#음식을 키워드로 해당 음식 맛집리스트를 뽑아오는 function
def get_restaurant_data(menu):
    
    #만들어놓은 get_rest_list function으로 상호명 리스트 생성
    restaurant_list = get_rest_list(menu)
    print(len(restaurant_list),'개의 식당 검색 완료.')
    
    #DataFrame을 위한 빈 리스트 생성

    mango_name = []
    mango_rate = []
    mango_address = []
    mango_phone = []
    mango_kind = []
    mango_price = []
    naver_reviewcount = []
    naver_rate = []
    dining_review_point = []
    dining_star_point = []
    dining_review = []
    count = 1

    #상호명 리스트를 활용하여 각각의 점포의 정보를 망고플레이트, 네이버, 다이닝코드로 부터 받아오는 for loop
    for restaurant in restaurant_list:

        mango_info = get_mango_info(restaurant)
        naver_info = get_naver_info(restaurant)
        dining_info = get_dining_info(restaurant)
        #위에서 정의한 망고플레이트 음식점 정보를 하나의 dict로 가져옴

        #각각의 리스트에 고유 정보 추가
        mango_name.append(mango_info['name'])
        mango_rate.append(mango_info['rate'])
        mango_address.append(mango_info['address'])
        mango_phone.append(mango_info['phone'])
        mango_kind.append(mango_info['kind'])
        mango_price.append(mango_info['price'])
        naver_reviewcount.append(naver_info['reviewcount'])
        naver_rate.append(naver_info['rate'])
        dining_review_point.append(dining_info['review_point'])
        dining_star_point.append(dining_info['star_point'])
        dining_review.append(dining_info['review'])
        
        print(count,'번째 식당 정보 수집중...')
        count += 1
    
    #생성된 리스트로 pandas dataframe 생성
    restaurant_df = pd.DataFrame({'음식점':mango_name,
                         '망고평점': mango_rate,
                         '네이버평점': naver_rate,
                         '네이버리뷰수': naver_reviewcount,
                         '다이닝코드평점': dining_review_point,
                         '다이닝코드별점': dining_star_point,
                         '다이닝코드리뷰': dining_review,     
                         '주소': mango_address,
                         '전화': mango_phone,
                         '종류': mango_kind,
                         '가격': mango_price})
    
    #완성된 DataFrame으로 excel파일 생성
    restaurant_df.to_excel('{}맛집리스트_{}.xlsx'.format(menu,datetime.now().strftime('%y%m%d_%H%M')), index=False, encoding='utf-8')
    print(menu,'맛집리스트가 완성되었습니다.')
    print(restaurant_df.head())
    
    #완성된 Dataframe을 return
    return restaurant_df

# %%
get_restaurant_data('돈까스')
# Out:
# 40 개의 식당 검색 완료.
# 1 번째 식당 정보 수집중...
# 2 번째 식당 정보 수집중...
# 3 번째 식당 정보 수집중...
# 4 번째 식당 정보 수집중...
# 5 번째 식당 정보 수집중...
# 6 번째 식당 정보 수집중...
# 7 번째 식당 정보 수집중...
# 8 번째 식당 정보 수집중...
# 9 번째 식당 정보 수집중...
# 10 번째 식당 정보 수집중...
# 11 번째 식당 정보 수집중...
# 12 번째 식당 정보 수집중...
# 13 번째 식당 정보 수집중...
# 14 번째 식당 정보 수집중...
# 15 번째 식당 정보 수집중...
# 16 번째 식당 정보 수집중...
# 17 번째 식당 정보 수집중...
# 18 번째 식당 정보 수집중...
# 19 번째 식당 정보 수집중...
# 20 번째 식당 정보 수집중...
# 21 번째 식당 정보 수집중...
# 22 번째 식당 정보 수집중...
# 23 번째 식당 정보 수집중...
# 24 번째 식당 정보 수집중...
# 25 번째 식당 정보 수집중...
# 26 번째 식당 정보 수집중...
# 27 번째 식당 정보 수집중...
# 28 번째 식당 정보 수집중...
# 29 번째 식당 정보 수집중...
# 30 번째 식당 정보 수집중...
# 31 번째 식당 정보 수집중...
# 32 번째 식당 정보 수집중...
# 33 번째 식당 정보 수집중...
# 34 번째 식당 정보 수집중...
# 35 번째 식당 정보 수집중...
# 36 번째 식당 정보 수집중...
# 37 번째 식당 정보 수집중...
# 38 번째 식당 정보 수집중...
# 39 번째 식당 정보 수집중...
# 40 번째 식당 정보 수집중...
# 돈까스 맛집리스트가 완성되었습니다.
#                 음식점  망고평점 네이버평점 네이버리뷰수 다이닝코드평점 다이닝코드별점  \
# 0              시키카츠   4.7   N/A    N/A     N/A     N/A
# 1              카와카츠   4.6  4.43    425      60     4.4
# 2               오제제   4.6   N/A    N/A      43     4.6
# 3            카츠바이콘반   4.5   N/A    N/A      59     4.9
# 4  후니도니(르메이에르종로타운점)   4.5   N/A    N/A      59     4.5
#
#                                              다이닝코드리뷰  \
# 0                                                N/A
# 1  [◈ 맛집기록 #9 '카와카츠'(5.0점 / 5점 만점)- 유명한 프리미엄 돈가스집...
# 2  [최근 몇년간 먹은 중에 우동과 돈까스를 가장 맛있게 먹은 곳. 가격이 별로 신경쓰...
# 3  [11시 30분 오픈! 토요일이어서그런지 11시 전부터 대기 4팀이나 있드라구요. ...
# 4  [유명한이유가 있어요 치즈돈까스와 모밀이 단짠단짠마냥 맛있게느끼하고 개운하고 바삭하...
#
#                              주소             전화        종류      가격
# 0           서울시 동대문구 회기동 60-147   02-6081-8753      까스요리  만원-2만원
# 1     서울시 마포구 서교동 465-1 1F 102호  070-8801-2053      까스요리  만원-2만원
# 2          서울시 용산구 동자동 43-22 1F  070-4647-4650  라멘/소바/우동   만원 미만
# 3            서울시 강남구 신사동 647-22    02-547-3903      까스요리  만원-2만원
# 4  서울시 종로구 종로1가 24 르메이에르종로타운 B1    02-722-5402      까스요리   만원 미만
#                  음식점  망고평점 네이버평점 네이버리뷰수 다이닝코드평점 다이닝코드별점  \
# 0               시키카츠   4.7   N/A    N/A     N/A     N/A
# 1               카와카츠   4.6  4.43    425      60     4.4
# 2                오제제   4.6   N/A    N/A      43     4.6
# 3             카츠바이콘반   4.5   N/A    N/A      59     4.9
# 4   후니도니(르메이에르종로타운점)   4.5   N/A    N/A      59     4.5
# 5               시키카츠   4.7   N/A    N/A     N/A     N/A
# 6               드림카츠   4.5   N/A    N/A     N/A     N/A
# 7             크레이지카츠   4.4  4.55    849      75     4.1
# 8             정돈프리미엄   4.4   N/A    N/A      61     4.1
# 9            망원동즉석우동   4.4   N/A    N/A      70     3.9
# 10                북천   4.4   N/A    N/A      58     4.1
# 11             돈까스전원   4.4   N/A    N/A     N/A     N/A
# 12              얌얌카츠   4.4   N/A    N/A      25       5
# 13           햇살머무는식탁   4.4   N/A    N/A      47     4.4
# 14          정돈(강남역점)   4.3   N/A    N/A      92     4.3
# 15               부타이   4.4   N/A    N/A      57     3.8
# 16            최강금돈까스   4.3  4.58    707      56     4.8
# 17               가츠오   4.3   N/A    N/A      54     4.2
# 18           즐거운맛돈까스   4.3   N/A    N/A      57     4.6
# 19           마쯔무라돈까스   4.3   4.5    937     N/A     N/A
# 20             라하노카레   4.3   N/A    N/A      25     3.5
# 21                우츠   4.3   N/A    N/A      20     4.3
# 22             키친우라와   4.3   N/A    N/A      22       4
# 23               시올돈   4.3   N/A    N/A      45     4.6
# 24      오리지날분식(이대본점)   4.3   N/A    N/A      27       5
# 25             돈까스정석   4.3   N/A    N/A      50     4.3
# 26         한성돈까스(별관)   4.3   N/A    N/A      74     3.8
# 27                곤돈   4.3   N/A    N/A     N/A     N/A
# 28             따봉돈까스   4.3   N/A    N/A      27     3.7
# 29           주간소바식당산   4.2  4.48    234      43     4.2
# 30                만돈   4.2   N/A    N/A      52     4.2
# 31               가쯔야   4.2  4.38    725      33     4.1
# 32                가일   4.3   N/A    N/A      54     4.8
# 33         The92산들바다   4.2   N/A    N/A     N/A     N/A
# 34          바삭공장(본점)   4.2   N/A    N/A      32     4.3
# 35                리애   4.5   N/A    N/A      23     4.4
# 36             오레노카츠   4.2   N/A    N/A      53     4.3
# 37              경양미식   4.2  4.51    138     N/A     N/A
# 38              민정식당   4.2  4.36    193      65     4.8
# 39              경성모밀   4.2   N/A    N/A      63     4.7
#
#                                               다이닝코드리뷰  \
# 0                                                 N/A
# 1   [◈ 맛집기록 #9 '카와카츠'(5.0점 / 5점 만점)- 유명한 프리미엄 돈가스집...
# 2   [최근 몇년간 먹은 중에 우동과 돈까스를 가장 맛있게 먹은 곳. 가격이 별로 신경쓰...
# 3   [11시 30분 오픈! 토요일이어서그런지 11시 전부터 대기 4팀이나 있드라구요. ...
# 4   [유명한이유가 있어요 치즈돈까스와 모밀이 단짠단짠마냥 맛있게느끼하고 개운하고 바삭하...
# 37                         서울시 강동구 성내동 12-38     02-472-1418         기타한식
# 38                         서울시 광진구 자양동 232-4     02-452-3574      탕/찌개/전골
# 39                         서울시 동작구 사당동 88-18     02-532-6670       국수/면요리
#
#          가격
# 0    만원-2만원
# 1    만원-2만원
# 2     만원 미만
# 3    만원-2만원
# 4     만원 미만
# 5    만원-2만원
# 6    만원-2만원
# 7     만원 미만
# 8   2만원-3만원
# 9     만원 미만
# 10    만원 미만
# 11   만원-2만원
# 12   만원-2만원
# 13    만원 미만
# 14   만원-2만원
# 15    만원 미만
# 16   만원-2만원
# 17   만원-2만원
# 18   만원-2만원
# 19    만원 미만
# 20    만원 미만
# 21   만원-2만원
# 22   만원-2만원
# 23   만원-2만원
# 24    만원 미만
# 25    만원 미만
# 26   만원-2만원
# 27   만원-2만원
# 28    만원 미만
# 29    만원 미만
# 30   만원-2만원
# 31   만원-2만원
# 32  2만원-3만원
# 33    만원 미만
# 34    만원 미만
# 35   4만원 이상
# 36   만원-2만원
# 37    만원 미만
# 38   만원-2만원
# 39    만원 미만

# %%
get_restaurant_data('카레')
# Out:
# 40 개의 식당 검색 완료.
# 1 번째 식당 정보 수집중...
# 2 번째 식당 정보 수집중...
# 3 번째 식당 정보 수집중...
# 4 번째 식당 정보 수집중...
# 5 번째 식당 정보 수집중...
# 6 번째 식당 정보 수집중...
# 7 번째 식당 정보 수집중...
# 8 번째 식당 정보 수집중...
# 9 번째 식당 정보 수집중...
# 10 번째 식당 정보 수집중...
# 11 번째 식당 정보 수집중...
# 12 번째 식당 정보 수집중...
# 13 번째 식당 정보 수집중...
# 14 번째 식당 정보 수집중...
# 15 번째 식당 정보 수집중...
# 16 번째 식당 정보 수집중...
# 17 번째 식당 정보 수집중...
# 18 번째 식당 정보 수집중...
# 19 번째 식당 정보 수집중...
# 20 번째 식당 정보 수집중...
# 21 번째 식당 정보 수집중...
# 22 번째 식당 정보 수집중...
# 23 번째 식당 정보 수집중...
# 24 번째 식당 정보 수집중...
# 25 번째 식당 정보 수집중...
# 26 번째 식당 정보 수집중...
# 27 번째 식당 정보 수집중...
# 28 번째 식당 정보 수집중...
# 29 번째 식당 정보 수집중...
# 30 번째 식당 정보 수집중...
# 31 번째 식당 정보 수집중...
# 32 번째 식당 정보 수집중...
# 33 번째 식당 정보 수집중...
# 34 번째 식당 정보 수집중...
# 35 번째 식당 정보 수집중...
# 36 번째 식당 정보 수집중...
# 37 번째 식당 정보 수집중...
# 38 번째 식당 정보 수집중...
# 39 번째 식당 정보 수집중...
# 40 번째 식당 정보 수집중...
# 카레 맛집리스트가 완성되었습니다.
#                음식점 망고평점 네이버평점 네이버리뷰수 다이닝코드평점 다이닝코드별점  \
# 0              마루심  4.7   4.4    776      73     4.1
# 1             우미노미  4.7   N/A    N/A      52     4.6
# 2               카레  4.7   N/A    N/A      34     4.3
# 3             공기식당  4.5   N/A    N/A      60     3.6
# 4  요시즈카우나기야/吉塚うなぎ屋  N/A   N/A    N/A      25       5
#
#                                              다이닝코드리뷰  \
# 0  [장어덮밥이 정말 맛있습니다. 정갈한 나고야식 덮밥입니다. 배부르게 점심을 먹고 싶...
# 1  [고된 일하고 나서 내가 내자신에게 정말 성대한 식사를 제공하고 싶을때 방문하는 집...
# 2  [12시 오픈인데 들어가려면 일단 11시 반 즈음부터 줄을 서야 맛볼 수가 있는 곳...
# 3  [서촌에 위치한 카레 전문점 공기식당입니다. 대표 메뉴인 새우버터카레와 새우키마커리...
# 4  [장어덮밥 먹으러 가는 곳! 히쯔마부시보다 우나쥬가 장어양이 더 많긴 하지만 오차즈...
#
#                             주소             전화           종류       가격
# 0       서울시 서초구 반포동 54-10 청구빌딩    02-592-8998  돈부리/일본카레/벤토  3만원-4만원
# 1  서울시 영등포구 당산동4가 31-2 신우빌딩 1F  070-4367-7116  돈부리/일본카레/벤토   만원-2만원
# 2       서울시 서초구 반포동 54-10 청구빌딩    02-592-8998  돈부리/일본카레/벤토  3만원-4만원
# 3          서울시 종로구 통인동 46-5 1F  010-4750-0930  돈부리/일본카레/벤토    만원 미만
# 4                          N/A            N/A          N/A      N/A
#                 음식점 망고평점 네이버평점 네이버리뷰수 다이닝코드평점 다이닝코드별점  \
# 0               마루심  4.7   4.4    776      73     4.1
# 1              우미노미  4.7   N/A    N/A      52     4.6
# 2                카레  4.7   N/A    N/A      34     4.3
# 3              공기식당  4.5   N/A    N/A      60     3.6
# 4   요시즈카우나기야/吉塚うなぎ屋  N/A   N/A    N/A      25       5
# 5          마루심(마포점)  4.5   4.4    776      73     4.1
# 6        멘야하나비(신사점)  4.4  4.51    285      78     4.1
# 7                예티  4.4   N/A    N/A      41     4.2
# 8                고옥  4.4   N/A    N/A      75     4.4
# 9        홋카이도부타동스미레  4.4   N/A    N/A      38       5
# 10         데카망(휴업중)  N/A   N/A    N/A      35     4.4
# 11              요우란  4.4   N/A    N/A     N/A     N/A
# 12               온정  4.4   N/A    N/A      22       5
# 13           타이가텐푸라  4.4   N/A    N/A      39     4.4
# 14          오사카카레콘유  4.4   N/A    N/A      45     4.3
# 15            텐동요츠야  4.3  4.34    937      81     4.3
# 16            멘야하나비  4.4  4.51    285      78     4.1
# 17               깔리  4.3   N/A    N/A      77     4.2
# 18              우마텐  4.3   N/A    N/A      58     4.2
# 19              부타이  4.4   N/A    N/A      57     3.8
# 20      에베레스트(동대문점)  4.3   N/A    N/A      78     4.4
# 21              가츠오  4.3   N/A    N/A      54     4.2
# 22             교양식사  4.3   N/A    N/A      51       4
# 23            도요스6가  4.3  4.59    235      51     4.1
# 24              텐동한  4.3   N/A    N/A      43     4.5
# 25              현우동  4.3  4.41    382      50     4.3
# 26            라하노카레  4.3   N/A    N/A      25     3.5
# 27         포탈라(종로점)  4.3   N/A    N/A      24       0
# 28  후라토식당(아브뉴프랑판교점)  N/A   N/A    N/A      59     4.7
# 29             운멜로랩  4.3  4.41    466      32     4.3
# 30        이치젠(망원본점)  4.2   N/A    N/A      76     4.4
# 31          BARN110  4.2  4.48    364     N/A     N/A
# 32            후라토식당  4.3   N/A    N/A      59     4.7
# 33        오복수산(도산점)  4.2  4.44    514      63     4.4
# 34        우동카덴(연희점)  4.2   N/A    N/A      61     3.7
# 35          멘야코노하카레  4.2   N/A    N/A      33     4.3
# 36              사쿠텐  4.2   N/A    N/A     N/A     N/A
# 37              이코이  4.2   N/A    N/A      26       5
# 38          스아게/すあげ  N/A   N/A    N/A      50     4.1
# 39          주간소바식당산  4.2  4.48    234      43     4.2
#
#                                               다이닝코드리뷰  \
# 0   [장어덮밥이 정말 맛있습니다. 정갈한 나고야식 덮밥입니다. 배부르게 점심을 먹고 싶...
# 1   [고된 일하고 나서 내가 내자신에게 정말 성대한 식사를 제공하고 싶을때 방문하는 집...
# 2   [12시 오픈인데 들어가려면 일단 11시 반 즈음부터 줄을 서야 맛볼 수가 있는 곳...
# 3   [서촌에 위치한 카레 전문점 공기식당입니다. 대표 메뉴인 새우버터카레와 새우키마커리...
# 4   [장어덮밥 먹으러 가는 곳! 히쯔마부시보다 우나쥬가 장어양이 더 많긴 하지만 오차즈...
# 5   [장어덮밥이 정말 맛있습니다. 정갈한 나고야식 덮밥입니다. 배부르게 점심을 먹고 싶...
# 6   [진짜 지금까지 먹었던 맛집 중에 최고였음 (별 5개가 부족할 정도) 소바 처음 먹...
# 7   [회식으로 방문해봤다커리를 다양하게 먹어보고싶었는데 인도분이 말을 잘못이해하셔서 양...
# 8   [깔끔한 히츠마부시 장어덮밥집입니다 큰게 양이 많고 좋고 브레이크타임 있습니다. 인...
# 9   [먹고 감동받은 부타동집입니다. 신촌에 위치한 작은 가게이고 ㄷ자 테이블로 되어있어...
# 10  [- 친구 추천으로 방문한 식당 - 저녁 6시 넘어서 방문. 주문 후에 튀기기 시작...
# 11                                                N/A
# 12  [맛있습니다 가성비 좋고요 마라마파두부를 먹었는데 마라러버로써 대만족 재방문의사 있어요]
# 13  [텐동으로 유명한 타이가에 다녀왔습니다. 가게 입구 좌측에 키오스크 있는데 거기서 ...
# 14  [조금 느끼하긴 해도 역시 역사가 있는 맛집일만 하네여 존맛탱, 고로케가 정말 맛있...
# 15  [텐동은 이집이죠 쯔유가 정말 맛있어요 튀김도 느끼하지않고 최근에 먹었던 다른 텐동...
# 16  [진짜 지금까지 먹었던 맛집 중에 최고였음 (별 5개가 부족할 정도) 소바 처음 먹...
# 17  [탄두르치킨은 살이 부드럽고 간도 괜찮았어요~ 커리는 양고기 마살라는 무난,팔락 파...
# 18  [원래 가려던 식당이 문을 닫아서 다른 곳 찾다가 우연히 방문텐동 한 번도 안 먹어...
# 19  [삼성동 현대백화점 건너편 휘문중학교 인근에 위치한 일본식 돈카츠 전문점.상당히 빠...
# 20  [커리와 난 맛은 전체적으로 괜찮았어요. 한가지 흠이 있다면 커리에 든 고기가 모두...
# 21  [맛있다! 일부러 찾아가서 먹는 돈가츠집. 가끔 줄을 설 가치가 있다. 제주도산이라...
# 22  [분위기도 좋고 평도 좋아서 왔어요 근데 조금 가격이 있긴 하지만 양고기 원래 좀 ...
# 23  [일본에서 청소년기를 보낸 직원 추천으로 찾은 집이다.본토 맛을 아는 사람의 추천이...
# 16                    서울시 서초구 잠원동 10-44         070-8847-7788     라멘/소바/우동
# 17                   서울시 종로구 명륜4가 170-3           02-747-5050         인도음식
# 18                서울시 강남구 신사동 661-10 B1           02-548-5833  돈부리/일본카레/벤토
# 19                서울시 마포구 합정동 395-16 1F         070-8836-8490     라멘/소바/우동
# 20                    서울시 종로구 창신동 148-1           02-766-8850         인도음식
# 21                  서울시 서초구 서초동 1658-17          02-6338-5154         까스요리
# 22                  서울시 용산구 한남동 683-134           02-795-4040    정통일식/일반일식
# 23           서울시 송파구 송파동 58-15 트윈레이크팰리스           02-416-6802  돈부리/일본카레/벤토
# 24                서울시 광진구 중곡동 341-26 1F          02-6080-5856  돈부리/일본카레/벤토
# 25                     서울시 강남구 논현동 11-1           02-515-3622     라멘/소바/우동
# 26       경기도 성남시 분당구 서현동 247-4 은성프라자 2F         070-8193-2821  돈부리/일본카레/벤토
# 27               서울시 종로구 관철동 35-2 수표교빌딩           02-318-0094         인도음식
# 28                                  N/A                   N/A          N/A
# 29             경기도 수원시 팔달구 신풍동 120-1 1F          031-258-0149         퓨전양식
# 30              서울시 마포구 망원동 415-31 101호         070-7740-0321  돈부리/일본카레/벤토
# 31          경기도 고양시 일산동구 정발산동 1334-5 1F          031-908-1968        다국적퓨전
# 32             경기도 성남시 분당구 삼평동 740 220호          031-607-7090  돈부리/일본카레/벤토
# 33                서울시 강남구 신사동 666-25 2F           02-545-9966  돈부리/일본카레/벤토
# 34            서울시 서대문구 연희동 81-1 거화빌딩 1F           02-337-6360     라멘/소바/우동
# 35            서울시 도봉구 창동 635-42 103동 1F           02-999-5746  돈부리/일본카레/벤토
# 36  인천시 연수구 송도동 22-21 푸르지오월드마크 7단지 104호          032-831-4910  돈부리/일본카레/벤토
# 37                    서울시 도봉구 창동 651-77           02-991-2344  돈부리/일본카레/벤토
# 38                                  N/A                   N/A          N/A
# 39                    서울시 종로구 통인동 154-8          02-3210-0113     라멘/소바/우동
#
#          가격
# 0   3만원-4만원
# 1    만원-2만원
# 2   3만원-4만원
# 3     만원 미만
# 4       N/A
# 5   3만원-4만원
# 6    만원-2만원
# 7    만원-2만원
# 8   2만원-3만원
# 9   주차공간없음
# 10      N/A
# 11  주차공간없음
# 12   만원-2만원
# 13   만원-2만원
# 14   만원-2만원
# 15    만원 미만
# 16   만원-2만원
# 17   만원-2만원
# 18   만원-2만원
# 19    만원 미만
# 20   만원-2만원
# 21   만원-2만원
# 22  2만원-3만원
# 23   만원-2만원
# 24    만원 미만
# 25   만원-2만원
# 26    만원 미만
# 27   만원-2만원
# 28      N/A
# 29   만원-2만원
# 30   만원-2만원
# 31   만원-2만원
# 32   만원-2만원
# 33   만원-2만원
# 34    만원 미만
# 35    만원 미만
# 36   만원-2만원
# 37   만원-2만원
# 38      N/A
# 39    만원 미만

# %%
get_restaurant_data('삼겹살')
# Out:
# 40 개의 식당 검색 완료.
# 1 번째 식당 정보 수집중...
# 2 번째 식당 정보 수집중...
# 3 번째 식당 정보 수집중...
# 4 번째 식당 정보 수집중...
# 5 번째 식당 정보 수집중...
# 6 번째 식당 정보 수집중...
# 7 번째 식당 정보 수집중...
# 8 번째 식당 정보 수집중...
# 9 번째 식당 정보 수집중...
# 10 번째 식당 정보 수집중...
# 11 번째 식당 정보 수집중...
# 12 번째 식당 정보 수집중...
# 13 번째 식당 정보 수집중...
# 14 번째 식당 정보 수집중...
# 15 번째 식당 정보 수집중...
# 16 번째 식당 정보 수집중...
# 17 번째 식당 정보 수집중...
# 18 번째 식당 정보 수집중...
# 19 번째 식당 정보 수집중...
# 20 번째 식당 정보 수집중...
# 21 번째 식당 정보 수집중...
# 22 번째 식당 정보 수집중...
# 23 번째 식당 정보 수집중...
# 24 번째 식당 정보 수집중...
# 25 번째 식당 정보 수집중...
# 26 번째 식당 정보 수집중...
# 27 번째 식당 정보 수집중...
# 28 번째 식당 정보 수집중...
# 29 번째 식당 정보 수집중...
# 30 번째 식당 정보 수집중...
# 31 번째 식당 정보 수집중...
# 32 번째 식당 정보 수집중...
# 33 번째 식당 정보 수집중...
# 34 번째 식당 정보 수집중...
# 35 번째 식당 정보 수집중...
# 36 번째 식당 정보 수집중...
# 37 번째 식당 정보 수집중...
# 38 번째 식당 정보 수집중...
# 39 번째 식당 정보 수집중...
# 40 번째 식당 정보 수집중...
# 삼겹살 맛집리스트가 완성되었습니다.
#          음식점  망고평점 네이버평점 네이버리뷰수 다이닝코드평점 다이닝코드별점  \
# 0         길목   4.6   N/A    N/A      62       4
# 1       김진목삼   4.6  4.69    248      55     4.9
# 2  육전식당(4호점)   4.5  4.39    739      76     4.2
# 3       한림돈가   4.4   N/A    N/A      64     4.1
# 4  육전식당(1호점)   4.4  4.39    739      76     4.2
#
#                                              다이닝코드리뷰  \
# 0  [예쁘장한 삼겹살집이라고 정의하고 싶네요. 실내가 아기자기합니다. 여성분들만의 모임...
# 1  [주차할 수 없는 서촌 골목에 위치. 1호점과 2호점이 아주 가깝게 붙어있는데 두 ...
# 2  [이 정도 돼지고기면 옷에 냄새 다 배겨도 인정이다. 청계천 나들이 필수 코스라고 ...
# 3  [칼집 넣고 초벌한 삼겹살이 달달하니 맛나요. 메뉴 중 삼겹살 특히 추천. 고사리와...
# 4  [이 정도 돼지고기면 옷에 냄새 다 배겨도 인정이다. 청계천 나들이 필수 코스라고 ...
#
#                            주소            전화    종류       가격
# 0            서울시 강남구 삼성동 58-6   02-518-9710  고기요리   만원-2만원
# 1             서울시 종로구 필운동 154   02-929-2929  고기요리   만원-2만원
# 2  서울시 강남구 역삼동 823-10 신도빌딩 1F  02-3452-6373  고기요리  2만원-3만원
# 3      서울시 서대문구 창천동 52-124 1F   02-338-6604  고기요리   만원-2만원
# 4          서울시 동대문구 신설동 104-3  02-2253-6373  고기요리   만원-2만원
#             음식점  망고평점 네이버평점 네이버리뷰수 다이닝코드평점 다이닝코드별점  \
# 0            길목   4.6   N/A    N/A      62       4
# 1          김진목삼   4.6  4.69    248      55     4.9
# 2     육전식당(4호점)   4.5  4.39    739      76     4.2
# 3          한림돈가   4.4   N/A    N/A      64     4.1
# 4     육전식당(1호점)   4.4  4.39    739      76     4.2
# 5            꿉당   4.4   4.5    320      41       4
# 6           남영돈   4.4   N/A    N/A      61     4.5
# 7    홋카이도부타동스미레   4.4   N/A    N/A      38       5
# 8           숙성도   4.8   N/A    N/A      60     4.4
# 9         일품생고기   4.4   N/A    N/A     N/A     N/A
# 10         분당그릴   4.4   N/A    N/A      24       5
# 11        금돼지식당   4.3   N/A    N/A      77     4.2
# 12           몽탄   4.3   N/A    N/A      63     4.3
# 13          853   4.3   N/A    N/A      41       4
# 14    명봉샤브샤브양꼬치   4.3   N/A    N/A      29     3.1
# 15  하이디라오(서초지점)   4.3   N/A    N/A      67     4.1
# 16       땅코참숯구이   4.3   N/A    N/A      78     4.5
# 17     나정순할매쭈꾸미   4.3   N/A    N/A      65     4.1
# 18      양지말화로구이   4.3  4.24    527      72     4.3
# 19    한림돈가(서교점)   4.3   N/A    N/A      64     4.1
# 20        광화문뚝감   4.3   N/A    N/A      61     4.3
# 21         양인환대   4.3  4.59    179      58     4.4
# 22       투뿔등심고담   4.3  4.18    161      50       4
# 23           해몽   4.3   N/A    N/A      56     4.6
# 24       노원목고기집   4.3   N/A    N/A      37     3.9
# 25         고깃집열   4.3   4.4    124      29     4.6
# 26       효자동목고기   4.3   N/A    N/A      36       4
# 27          고명집   4.3  4.13     60      52     3.9
# 28           돈멜   4.3  4.66    317      29       5
# 29         신흥식당   4.3   N/A    N/A      23       5
# 30         운산식당   4.3   N/A    N/A      20     3.1
# 31         을지육점   4.3   N/A    N/A      45     4.4
# 32         큰손식당   4.3   N/A    N/A      50       5
# 33     삼육가(야탑점)   4.3   N/A    N/A      53     4.2
# 34   제주도그릴(연희점)   4.3   N/A    N/A      28     4.2
# 35   숙달돼지(문래본점)   4.2   N/A    N/A      51     4.4
# 36       땅코참숯구이   4.3   N/A    N/A      78     4.5
# 37  교대이층집(광화문점)   4.2   N/A    N/A      61       4
# 38          조연탄   4.2  4.61    488      58     4.2
# 39      칠돈가(본점)   4.2  4.43    846      60     4.2
#
#                                               다이닝코드리뷰  \
# 0   [예쁘장한 삼겹살집이라고 정의하고 싶네요. 실내가 아기자기합니다. 여성분들만의 모임...
# 1   [주차할 수 없는 서촌 골목에 위치. 1호점과 2호점이 아주 가깝게 붙어있는데 두 ...
# 2   [이 정도 돼지고기면 옷에 냄새 다 배겨도 인정이다. 청계천 나들이 필수 코스라고 ...
# 3   [칼집 넣고 초벌한 삼겹살이 달달하니 맛나요. 메뉴 중 삼겹살 특히 추천. 고사리와...
# 4   [이 정도 돼지고기면 옷에 냄새 다 배겨도 인정이다. 청계천 나들이 필수 코스라고 ...
# 5   [#주님이먹여살려주시는인생 #꿉당⠀핫하다던 돼지고기집 솔직후기 = 약간 아쉽다.──...
# 6   [시작은 기분좋게 웨이팅 등록. 하지만 기다림은 너무너무 지치고, 슬슬 열받다가, ...
# 7   [먹고 감동받은 부타동집입니다. 신촌에 위치한 작은 가게이고 ㄷ자 테이블로 되어있어...
# 30              제주 제주시 삼도이동 1113-1          064-758-0330        고기요리  2만원-3만원
# 31              서울시 중구 을지로3가 321-2          02-2269-3398        고기요리   만원-2만원
# 32          경기도 용인시 기흥구 공세동 390-15          031-287-3383        고기요리   만원-2만원
# 33  경기도 성남시 분당구 야탑동 361-2 우송프라자 1F          031-706-3637        고기요리   만원-2만원
# 34              서울시 서대문구 연희동 188-5           02-324-3724        고기요리   만원-2만원
# 35         서울시 영등포구 양평동1가 13-18 1F         070-4205-8433        고기요리   만원-2만원
# 36                 서울시 강남구 역삼동 835           02-562-2009        고기요리   만원-2만원
# 37                 서울시 종로구 견지동 110           02-723-6692        고기요리   만원-2만원
# 38              서울시 강서구 화곡동 782-12         070-7641-2008        고기요리   만원-2만원
# 39              제주 제주시 용담이동 2695-4          064-727-9092        고기요리   만원-2만원

# %%
donkatsu_df = get_restaurant_data('돈까스')
# Out:
# 40 개의 식당 검색 완료.
# 1 번째 식당 정보 수집중...
# 2 번째 식당 정보 수집중...
# 3 번째 식당 정보 수집중...
# 4 번째 식당 정보 수집중...
# 5 번째 식당 정보 수집중...
# 6 번째 식당 정보 수집중...
# 7 번째 식당 정보 수집중...
# 8 번째 식당 정보 수집중...
# 9 번째 식당 정보 수집중...
# 10 번째 식당 정보 수집중...
# 11 번째 식당 정보 수집중...
# 12 번째 식당 정보 수집중...
# 13 번째 식당 정보 수집중...
# 14 번째 식당 정보 수집중...
# 15 번째 식당 정보 수집중...
# 16 번째 식당 정보 수집중...
# 17 번째 식당 정보 수집중...
# 18 번째 식당 정보 수집중...
# 19 번째 식당 정보 수집중...
# 20 번째 식당 정보 수집중...
# 21 번째 식당 정보 수집중...
# 22 번째 식당 정보 수집중...
# 23 번째 식당 정보 수집중...
# 24 번째 식당 정보 수집중...
# 25 번째 식당 정보 수집중...
# 26 번째 식당 정보 수집중...
# 27 번째 식당 정보 수집중...
# 28 번째 식당 정보 수집중...
# 29 번째 식당 정보 수집중...
# 30 번째 식당 정보 수집중...
# 31 번째 식당 정보 수집중...
# 32 번째 식당 정보 수집중...
# 33 번째 식당 정보 수집중...
# 34 번째 식당 정보 수집중...
# 35 번째 식당 정보 수집중...
# 36 번째 식당 정보 수집중...
# 37 번째 식당 정보 수집중...
# 38 번째 식당 정보 수집중...
# 39 번째 식당 정보 수집중...
# 40 번째 식당 정보 수집중...
# 돈까스 맛집리스트가 완성되었습니다.
#                 음식점  망고평점 네이버평점 네이버리뷰수 다이닝코드평점 다이닝코드별점  \
# 0              시키카츠   4.7   N/A    N/A     N/A     N/A
# 1              카와카츠   4.6  4.43    425      60     4.4
# 2               오제제   4.6   N/A    N/A      43     4.6
# 3            카츠바이콘반   4.5   N/A    N/A      59     4.9
# 4  후니도니(르메이에르종로타운점)   4.5   N/A    N/A      59     4.5
#
#                                              다이닝코드리뷰  \
# 0                                                N/A
# 1  [◈ 맛집기록 #9 '카와카츠'(5.0점 / 5점 만점)- 유명한 프리미엄 돈가스집...
# 2  [최근 몇년간 먹은 중에 우동과 돈까스를 가장 맛있게 먹은 곳. 가격이 별로 신경쓰...
# 3  [11시 30분 오픈! 토요일이어서그런지 11시 전부터 대기 4팀이나 있드라구요. ...
# 4  [유명한이유가 있어요 치즈돈까스와 모밀이 단짠단짠마냥 맛있게느끼하고 개운하고 바삭하...
#
#                              주소             전화        종류      가격
# 0           서울시 동대문구 회기동 60-147   02-6081-8753      까스요리  만원-2만원
# 1     서울시 마포구 서교동 465-1 1F 102호  070-8801-2053      까스요리  만원-2만원
# 2          서울시 용산구 동자동 43-22 1F  070-4647-4650  라멘/소바/우동   만원 미만
# 3            서울시 강남구 신사동 647-22    02-547-3903      까스요리  만원-2만원
# 4  서울시 종로구 종로1가 24 르메이에르종로타운 B1    02-722-5402      까스요리   만원 미만

# %%
import numpy as np
# import pandas as pd

# %%
df = pd.read_excel('돈까스맛집리스트_210620_1728.xlsx', encoding='utf-8')
df.head()
# Out:
#                 음식점  망고평점  네이버평점  네이버리뷰수  다이닝코드평점  다이닝코드별점  \
# 0              시키카츠   4.7    NaN     NaN      NaN      NaN
# 1              카와카츠   4.6   4.43   425.0     60.0      4.4
# 2               오제제   4.6    NaN     NaN     43.0      4.6
# 3            카츠바이콘반   4.5    NaN     NaN     59.0      4.9
# 4  후니도니(르메이에르종로타운점)   4.5    NaN     NaN     59.0      4.5
#
#                                              다이닝코드리뷰  \
# 0                                                NaN
# 1  ["◈ 맛집기록 #9 '카와카츠'(5.0점 / 5점 만점)- 유명한 프리미엄 돈가스...
# 2  ['최근 몇년간 먹은 중에 우동과 돈까스를 가장 맛있게 먹은 곳. 가격이 별로 신경...
# 3  ['11시 30분 오픈! 토요일이어서그런지 11시 전부터 대기 4팀이나 있드라구요....
# 4  ['유명한이유가 있어요 치즈돈까스와 모밀이 단짠단짠마냥 맛있게느끼하고 개운하고 바삭...
#
#                              주소             전화        종류      가격
# 0           서울시 동대문구 회기동 60-147   02-6081-8753      까스요리  만원-2만원
# 1     서울시 마포구 서교동 465-1 1F 102호  070-8801-2053      까스요리  만원-2만원
# 2          서울시 용산구 동자동 43-22 1F  070-4647-4650  라멘/소바/우동   만원 미만
# 3            서울시 강남구 신사동 647-22    02-547-3903      까스요리  만원-2만원
# 4  서울시 종로구 종로1가 24 르메이에르종로타운 B1    02-722-5402      까스요리   만원 미만

# %%
# series를 list로 
# 돈까스 다이닝코드 리뷰

donkatsu_dining_review = df['다이닝코드리뷰'].dropna()

donkatsu_dining_review = list(donkatsu_dining_review)
donkatsu_dining_review
# Out:
# ['["◈ 맛집기록 #9 \'카와카츠\'(5.0점 / 5점 만점)- 유명한 프리미엄 돈가스집. 한정메뉴인 특로스카츠 정식이 인기메뉴고, 로스 정식, 히레정식, 모둠카츠 등이 있다.- 월요일 점심 11시 반 오픈에 맞춰 도착했더니 이미 거의 만석이었다. 오픈시간보다 조금 더 이른 시간에도 들어갈 수 있으니, 웨이팅이 싫다면 미리 도착해 있어야한다.- 16000원짜리 특로스카츠 정식 주문. 가브리살이 붙은 등심 부위로 만들었다. 일단 양이 상당히 많다. 심지어 밥도 리필 가능하니 양은 걱정 안해도 될 듯.- 일단 돈가스의 첫입은 환상적이었다. 육즙이 가득하고 부드러웠다. 후추를 뿌려주는 것이 특징. (뿌리기 전에 괜찮은지 주인 분이 물어봐주신다.) 물론 돈가스의 특성상 뒤로 갈수록 좀 느끼하긴 했다.- 로즈마리 오일에 살짝 찍어서 히말라야 솔트에 찍어먹는 방식이 제일 맛있었다. 샐러드도 나름 괜찮았다. - 딱히 불만족스러운 점이 없었고, 일찍 간 덕에 웨이팅도 피할 수 있었다. 혼밥하기에도 좋은 구조라 매우 좋았다.", \'총평: 이 돈까스가 대단해 우승할 만한 가게혜화의 일식 카츠로 유명한 가게는 한시간 웨이팅 후 음식 맛에 실망이 이만저만 아니었던 반면, 이곳은 한시간 웨이팅 후 음식을 맛보고 나서 두시간도 기다릴 수 있을 것 같다고 생각함재방문의사 500배, 주변인에게 망설임 없이 추천할 만한 가게\', \'브레이크타임이 끝나기 20분전쯤?줄서서 기다려서 들어간곳우리뒤로도 줄을 계속해서 섰고 평도 좋아서 기대가 되었던곳이입니다특로스카츠가 궁금했으나 품절이라고하여모둠카츠 두개를 하려다가 로스하나 히레하나를 주문했고결론적으로 모둠가츠 두개를 했으면 많이 남겼을것같아요배부름+개인적으로는 먹으면서 물리는 느낌이 있어 두명이 간다면 로스하나 히레하나 해서 먹어도 될듯우선 맛과는 별개로 안심카츠의 식감과 질감은 돈까스에서 처음 느껴보는 부드러움이었어요입에 걸리는것이 없는 입에서 풀어지는 정도의 부드러움?히말라야 핑크솔트, 로즈마리올리브유,수제돈키츠 소스가 준비되어있고 나름대로 신경을 쓰신 느낌맛은 개인적으로 한번 먹어본걸로 충분한맛 그리고 이날만 그랬던건지 직원 중 한분이 손님들한테 너무 다그치듯이 말해서 보는사람이 민망했던 상황이 몇번있었고자리에 앉자마자 쭉 주문을 받는데 마치 이 가게의 모든 시스템과 메뉴를 미리 다 알고와야하는 느낌을 받았고 손님들이 음식을 다먹어가는지 언제 일어날건지 고개를 쑥 내밀고 여기저기 확인을 하는게 느껴져서 좀 별로였어요\', \'근방에서는 가장 질 좋은 돈까스를 먹을 수 있는 곳입니다. 인근의 가츠시가 가성비로 압살한다면 여긴 고기의 질로 밀어붙이는 느낌(사실 퀄을 생각하면 여기도 가성비가 절대 떨어지지 않는다고 생각합니다).아주 높은 확률로 (꽤 긴) 웨이팅이 있으나, 카톡을 활용한 차례 알림이 잘 되어 있고, 근처의 카페(요호)와 협의하여 음료를 할인받을 수 있어 기다리는 대 편의를 제공하고 있습니다.돈까스는 고기 질이 정말 좋고, 로스카츠도 히레 못지 않을 정도로 부드러워서 먹는 즐거움이 있습니다. 와사비도 좋은 걸 쓰시는지 살짝 단맛이 돌아 고기와 함께 먹기에 좋습니다. 함께 나오는 샐러드도 상당히 맛이 좋아요.좌석이 조금 좁긴 하지만, 데이트 코스로도 나쁘지 않습니다. 노 키즈 존이라는 점은 참고하셔야 할 듯합니다.\', \'이 정도의 돈까스는 어딜가도 만나보기가 어려
도로 담백합니다. 카레도 주문했는데, 카레맛은 그리 인상적이진 않았고 정식에 나오는 국이 짜지않고 적당히 감칠맛 나며 맛났습니다. 치킨 카라아게는 두 조각 나오는데 갓 튀겨나와 촉촉하고 부드럽고요. 특히 치킨가라아게 소스가 레몬향이 새콤하게 나면서 매우 맛나요. 하지만 무엇보다 돈까스가 찐입니다. 비치된 트러플 소금과 함께 찍어먹는걸 추천드립니다. 직원들은 제가 갔을땐 꽤 친절했습니다. 물잔이 비면 바로바로 채워주고 구간마다 담당 서버가 있어 요청사항 피드백이 빨랐구요. 또한 오픈 주방이라 메뉴 기다릴때 구경하는 재미도 쏠쏠합니다. 단지 바 형태로 일본 스타일처럼 둘러앉아 먹기에 사생활 보호가 안되는 점, 코로나인데 오붓하게 먹을 수 없단 점이 단점입니다. 중간중간 일본음악이 나오는데, 이 시국에 살짝 일본 골목에 와 있는듯한 느낌이었어요 ㅋ', '주말점심으로 방문했습니다 동생이 인생돈까스라고하여 기대했는데만족 대만족입니다.일단 여기는 대기가 길어서 어플로 미리 예약하고 가시는걸 추천드려요저희도 근처에 다른곳 들렀다가 출발하면서 예약걸었는데 도착하여 바로 들어갈 수 있었어요내부구조가 특이해요 테이블이 ㄹ 모양으로 있고 한쪽에 오픈키친으로 되어있습니다안심스테이크는 보기에 양이 적어보였지만 성인여자가 먹기에 충분한 양이였어요부들부들 냄새1도 없고, 샐러드 드레싱도 일반 참깨드레싱이 아닌것 같습니다밥도 윤기가 흐르고 친구는 밥이 너무 맛있다고 했어요국은 일본에서 흔히먹는 돈지루(돼지고기 된장찌개) 였는데 간도 잘맞고 맛있습니다이쪽 라인이 다 핫플이여서 근처오시면 들렀다가 디저트까지 한번에 끝낼 수 있을거에요요즘 프리미엄돈까스 유행인데 꼭 방문해서 맛보셔요 엄지척입니다', '인생 체고 돈까스,, 고기가 거의 고급 레스토랑 스테이크급으로 부드럽고 소금찍어먹으면 너무맛있고 양배추피클도 직접담그시는지 너무너무 맛있어서 먹는내내 감탄하고왔어요. 도산공원만가면 자동으로 생각날 꺼 같은 맛입니다.', '인생돈까스입니다. 기름지지도 않고, 고기가 굉장히 부드럽습니다. 돈까스먹다보면 김치가 생각나는데 여긴 전혀 생각안납니다. 같이 나온 양배추도 너무 맛있고, 돈까스 양이 적나 싶었지만 먹고나면 엄청 배부릅니다. 먹고나서 배부른데 너무 만족스러워서 또 생각나는 맛입니다', '트러플 소금에 찍어먹으면 진짜 맛있습니닷👍🏻 같이 나오는 국도.. 리필해서 먹었어요. 추가 비용 있는데 그냥 서비스로 주시더라고요. 로스가츠 히레가츠 둘 다 너무 맛있어요! 처음에 나온거 보고 양이 너무 적지 않나 싶었는데 먹고 나니 배 부르더라고요.ㅎㅎ 깔끔하고 내부에 기름냄새도 나지 않고 재방문 의사 있습니당. (^^)']",
이 맛이면 ‘30분정도는 기다릴만 하다’ 가 총평이에요. 부드럽고  촉촉한데 겉은 바삭해서 맛있었습니다~! 특히 로카츠가 겨자와 잘어울린다는 사실을 처음 알았습니다. 히말라야 소금 찍어 먹는 것도 너무 맛있었습니다~~\', \'작은 반지하 식당인데 오픈부터 사람이 많고 줄을 섭니다. 음식은 가성비가 아주 괜찮고, 깔끔해요. 레모네이드는.. 구지 시킬 필요는 없다고 봅니다. 음식이 천천히 나오는 편인데 데이트하거나 여유있을 때 가면 웨이팅리스트에 이름 올려놓으면 되서 실제로 서서 줄을 서는게 아니라 기다릴만한 정도 입니다.\', \'바 형태의 자리인데 가게가 넓은 편이 아니라 조금 좁긴 하지만 돈까스는 맛있었어요\', "◈ 맛집기록 #1 \'크레이지카츠\' (4.0점 / 5점 만점)- 우리나라 3대 돈가스 식당을 언급할 때마다 등장하는 곳. 웨이팅을 피하기 위해 오픈 30분 전부터 미리 와있었다. 다행히 3번째 정도로 입장 성공.- 크레이지 돈맥세트를 주문했더니, 이곳의 대표메뉴인 특로스가츠를 비롯해, 로스가스/히레가스/새우튀김/고로케가 골고루 나왔다. 시원한 생맥주랑 잘 어울리는 조합이었다.- 특로스가츠는 그 유명세만큼 실망시키지 않는 맛이었다. 사실 일반 로스가스도 충분히 맛있어서, 가격대가 부담스럽다면 일반으로 주문해도 문제 없다.- 웨이팅이 많은 것도 불편하고, 내부 테이블이 미로처럼 되어있어 앉기도 불편한 건 단점. 주차할 곳 없는 것도 불편하다..- 가격대도 조금 높은 편이지만, 맛만 생각하면, 돈가스 성애자라면 한번쯤은 방문해봐야 할 곳이다. 하지만 개인적으로는 정돈이 더 만족스러웠다..!", \'너무 기대를 하고 가서 그런지 생각만큼 그렇게 맛있다고 말하기가 좀 그렇습니다.맛이 없는것은 아니지만 1시간 웨이팅해서까지 먹을 정도는 아닌거 같습니다.로스카츠를 먹었는데 살짝 오버쿡 된 느낌이 듭니다. 주말이라 사람이 많아서 그런건지 원래 그런건지는 모르겠지만 다음에 평일에 와서 히레카츠를 한번 먹어보고나서 재방문은 다시 생각해봐야겠습니다.\']',
#  '["\'프리미엄이라는 타이틀을 유지한다는 것\'2세대 프리미엄 돈까스의 선두 주자 중 하나인 정돈의 강남ㅡ프리미엄점입니다. 먼저 이 거리에서 지하주차장을 갖추고 있다는 것은 엄청난 장점이라고 생각됩니다. 입장하니 매니저분이 무척 프로페셔널하게 응대를 해주십니다. 하이 테이블에 앉았는데 만석이므로 늦게 온  손님들을 위해 자리를 한번 옮겼습니다. 무척 정중하게 양해를 구하셔서 괜찮았습니다. 따뜻한 차는 좋았습니다. 고기는 4도씨 정도에 보관하는 듯 했습니다. 400시간 정도 숙성을 한다고 하는데 사실 고기ㅡ특히 돼지고기의 경우 숙성은 2~3일이 지나면 의미가 없고 보관 정도 라고 보시면 됩니다. 고기는 프리미엄 점이기 때문에 A++만 쓴다고 합니다. 저온으로 튀겨내면 단백질의 변형은 최소화할 수 있지만 지나치게 기름을 많이 머금게 되는데 사진을 보시면 아시겠지만 빵가루가 기름을 머금고있어 느끼했습니다. 된장국도 미소시루가 아닌 돈지루를 내어주기 때문에 느끼함이 배가 되는 것을 느꼈습니다. 그냥 먹기는 힘들어 레몬을 뿌려먹었습니다. 소금은 트러플 소금과의 궁합이 가장 좋았는데 밑반찬을 너무 조금씩 주셔서 그릇에 비해 초라해보이는 면이 있었습니다. 이 날만 컨디션이 그랬던 것인지 모르겠지만 개인적으로 실망스러운 경험이었습니다. 프리미엄 돈까스의 프리미엄 점인만큼 가격은 이 동네에서라면 불만은 없지만 프리미엄 가격을 지불할 맛을 보여주셨으면 좋겠다는 생각을 했습니다. 대부분 가로수길 점이 혜화점에 비해 완성도가 떨어진다는 평이 있던데 사진으로만 보아도 저 역시 그 평에 동의할 수 있을 듯 합니다.", \'[가로수길 맛집]그야말로 프리미엄 돈가스.국내 최초 저온튀김 기법을 통해 만든다는데그래서인지 주문 후 음식이 나오기까지 오래걸려서 직장인들 점심때 가기는 무리!심지어 웨이팅도 있어요. 기본 20-30분웨이팅 필수지만 먹어보고 기다릴만하다고 느낀 곳입니다 ㅎㅎ 반찬도 맛있고 본 메뉴 자체도 훌륭해서 또 가고싶은곳이에요~!\', \'히레보다는 로스 추천합니다정돈 프리미엄이라 기존 정돈보다 맛날거라 기대했지만가격은 더 비싸지만 더 맛난지는 모르겠어요히레의 경우 먹기가 힘들만큼커서 잘라달라했는데 가위를 줍니다유자소금은 수분기가 많아 뭉치네요\', \'프리미엄 돈까스의 대표주자 인 만큼 맛있네요. 깨끗한 튀김옷과 부드러운 고기, 대접받는 듯한 친절한 서비스가 돈까스로도 고급’요리’가 될수 있음을 알게 하네요. 다만 가격부담때문에.. 자주가긴 힘들겠어요\', \'정돈을 무척 좋아해서, 무엇이 다를까 싶어서 방문한 정돈입니다.일단 정돈 스탠다드와는 아예 돈까스가 다른 형태로 만들어 나옵니다. 정돈은 고기 단면이 보이게 나오는 반면, 프리미엄에서는 고기를 동그랗게 뭉쳐서 나와서 색다른 식감입니다.초창기 정돈에서처럼 여러 종류의 소금이 같이 나옵니다.전반적으로 정돈 스탠다드보다 맛은 있지만, 가격이 약 5천원 정도의 차이가 납니다. 이 가격을 내고 그 이상의 맛의 차이는 나진 않는 것 같습니다.웬만해선 스탠다드를 방문할 것 같으며, 신사 부근에 있는데, 돈까스가 땡긴다면 방문하는 정도일 것 같습니다.\']',
#  "['아주매운맛 어묵우동 양념장이 잘 숙성된 막연히 매운맛이 아니라 부드럽게 뭉근히 오르는 맛 즉석면 양도 많고 어묵도 맛있어요 배고플때 다시 가보고 싶은집', '흔한 우동을 기대하고 가세요. 그러면 맛있습니다. 우동의 맵기를 조절할 수 있는데 전 매운맛 호구라 보통도 매웠네요. 영업시간이 메뉴선택보다 어렵습니다.', '-돈까스와 우동을 술과함께 먹을수 있는 곳-인근 주민은 물론, 서울내에서는 이미 꽤 유명한 곳이라고하여 벼르고 있다 기회가 되어 방문.-밤 11시가 넘은 시간에 갔는데도 손님들이 끊임없이 들어오고 나가더라.. 대단한 한국사람들. 기계로 뽑아낸 우동과 한국스타일 돈까스를 주문.-우동은 쑥갓과 어묵이 함께 들어가서 푸짐한 비쥬얼로 나온다. 살짝 칼칼하고 매콤한게 술안주로도, 술먹은뒤 해장하기에도 좋을것 같은 느낌. 돈까스는 우리가 흔히 생각하는 왕돈까스 집 비쥬얼로 나온다. 달달한 소스에 흠뻑 적셔져서 나오는 데 이런 스타일의 돈까스를 오히려 좋아하는 입맛이라 맛있게 잘 먹었음.-돈까스와 우동을 그냥 먹을수도, 술과함께 먹을수도 있는 곳. 밤 늦게까지해서 좋지만 타이밍 잘못맞춰가면 웨이팅할수도 있어요', '일본 우동과는 다른 한국의 가락국수 느낌이 더 강함. 분식 국수 느낌이고, 국물이 깔끔하고 면도 맛있어서 정말 내타입이었다. 칼칼하고, 뜨끈함. 보통맛도 꽤 맵기 때문에 매운걸 못먹으면 순한맛을 추천. 어묵우동은 일반우동에 어묵이 들어간 차이. 맛있다.', '청양고추와 양념장으로 맵기조절이 가능하며 기본 우동면발보다 좀더 얇은 면을 사용합니다. 국물이 우선 찐 이며 면발이 부드럽고 식감이 좋습니다. 서울 우동집중 TOP 3.']",
#  "['용산 우체국 뒷골목에 있는 밥집거리에 위치한 북천입니다. 평일에는 주변의 직장인들이 찾는 가게로, 1층에는 2인 테이블이 3개, 2층에는 12개의 테이블이 있습니다. 특이하게도 연어와 관련된 인테리어가 되어있는데, 사장님의 취향이 반영된 것으로 보입니다. 메뉴판은 따로 없고 계산서 뭉치를 가져다 주는데 여기 적힌 메뉴를 보고 주문하는 식입니다. 돈까스 종류는 고기가 상당히 두꺼운 편이지만 잘 익혀져서 나옵니다. 브라운이나 로스까스의 소스도 맛있습니다. 같이 나오는 양배추와 생강절임도 돈까스에 잘 어울립니다. 특이하다면 특이하다고 하겠지만, 단무지가 살짝 두껍습니다. 식사에 영향을 미치는 수준은 아니지만, 특이하긴 합니다. 먹다보니 튀김옷이 벗겨진다는 것을 알았는데 튀김옷이 벗겨지는 돈까스집은 오랜만에 본 거 같습니다. 소스를 부어서 나오는 브라운까스야 그렇다고 치더라도 찍어먹는 종류인 로스까스도 같은 현상이 발견되었습니다.다만 질이 좋지 않은 고기를 사용하거나 수분제거과정이 충분치 않아 처음에 써는 순간 튀김옷이 홀랑 벗겨지는 실력미달 가게와는 살짝 다르게 고기 중앙부분의 한 조각 정도에서만 일어나는 것으로 보아 지나치게 두꺼워보이는 두께 때문에 발생하는 현상임이 거의 확실해 보입니다. 튀김옷이 벗겨진다는 거 자체가 사장님의 조리실력에 의구심을 자아내기에 충분한 일이기 때문에 개선이 필요할 거 같긴 하지만 동시에 두께 자체가 이 가게의 특징이라는 걸 생각하면 한 조각 정도는 감내할만하다는 생각도 듭니다. 우동은 정말 평범했습니다. 국물이든, 면이든 시판제품을 쓰는 다른 가게와 같았습니다.전반적으로 일부러 찾아가는 가게라기 보다는 주변에서 일을 하거나 일이 있어서 들렀을 때 식사시간이 겹쳤을 때 고려할만한 가치가 있는 가게라고 봅니다. 다른 곳에서 
오픈되어 있어 만드는 모습이 다 보인다.- 일단 돈가스 자체는 바삭바삭한 스타일. 근데 생각보다 내 취향은 아니었다. 고기의 씹는 맛이 잘 안 느껴질 정도로 두께가 얇았고, 그 중 몇개는 탄맛이 나는 것들도 있었다.- 많은 기대를 했지만, 그 기대에는 부응하지 못했던 곳.", \'우선 회전이 빠른 매장답게 재료가 신선하다. 최적화된 메뉴구성과 홀의 움직임이 노포의 그것이다. 잡다한 기교가 절제되어있는 심플한 맛과 구성이다. 돈가스를 즐긴다면 한번 경험해 볼 만하다.\', \'전 돈까스 않좋아하는 데 느끼해서 이건좀 괘안았어요후기보구걱정했는데 엄마랑남동생도한번쯤은데려오고픈데\', \'신사역 4번출구에서 3분 거리에 위치한 한성돈까스. 먼저 역과의 근접성이 너무 좋았습니다.도착해서 가게앞에 사람이 많길래 웨이팅이 많은가 싶었는데 모두 포장손님 이셨어요. 포장손님 꽤나 많더군요..안쪽에 작은 방들이 꽤 많았어요. 미로를 통해 방으로 가는 것 같은 기분.메뉴는 단촐합니다. 기본 찬은 깍두기와 된장국 밥.비후까스와 히레까스를 시켜서 먹었는데 총평먼저 말하자면, 고기향이 살아있는 돈까스였어요. 느끼하지않고 생각보다 양도 푸짐했습니다. 튀김옷은 바삭한데, 옆에 준비된 돈까스 소스와 궁합이 최고였네요. 다음엔 돈까스와 치킨까스 먹으러 와야겠어요.\']',
#  "['동네 돈까스분식집에서 돈까스로 전환한 집으로 보인다위치도 규모도...토요일 점심인데 끊임없이 손님이 들어온다꽤 인기가 있는 집인가보다음식은깔끔하고 고만고만하다단지 돈까스를 튀김으로 알고 먹어야한다는거 빼고 ㅎㅎ내취향으로는 별셋인데손님많고 애들이 좋다해서 별넷...', '가격대비 돈까스 치즈돈까스 둘다 맛있었다. 근데 남자직원이 불친절해서 다시 가고싶지는 않다. 주차관련 물어봤는데 알아볼 생각은 없었고 말로만 들으면 모른다고 알아서 오라고 해서 도착전부터 기분이 별로였다.', '주차장을 찾느라 시간이 마니 걸렸다 치즈돈까스는 진짜 맛있어서 추천하고 싶다']",
#  "['검색해서 간곳은 아니고 식당가 있는곳에 조용한 분위기라 방문했는데 맛은 무난했고 가격도 비싸지 않고 괜찮았다.특별히 여기만을 위해서 시간내서 올 정도는 아니지만 경복궁역 근처에 방문했을때 무난하게 먹을 수 있을 만한 곳이다.', '식당 내부는 깔끔했고 조용했다. 혼자 앉을 수 있는 자리도 마련되어 있어 혼밥하기 좋을 것 같다. 돈카츠는 맛있지만 계속 먹다보면 비계부분이 특히 물렸다. 비계는 돈카츠의 3분의 1정도 있었고 소바는 깔끔했고 맛있었다.', '길거리에서 봤을 땐 눈에 띄지않을 수 있는 차분한 외관. 그리고 인테리어 역시 일본 분위기의 정갈한 느낌임. 소바나 돈까스 모두 평균 이상이었음. 좌석은 많지 않은 편.', '소바 맛집이라 해서갔는데 맛있어요!! 미니 돈가스도 먹었는데 돈가스도 진짜맛있네용 또갈게용', '샐러드소바 깔끔하게 맛있었음! 정식이라 돈까스도 같이 맛볼수잇어서 조음! 고급스럽진 않디만 간단히 식사하기 괜찮음 양이 많딘 않음']",
# %%
# # 테스트
# donkatsu_dining_review = list(map(str, donkatsu_dining_review))

# %%
donkatsu_dining_review = ' '.join(donkatsu_dining_review)
donkatsu_dining_review[:1000]
# Out:
# '["◈ 맛집기록 #9 \'카와카츠\'(5.0점 / 5점 만점)- 유명한 프리미엄 돈가스집. 한정메뉴인 특로스카츠 정식이 인기메뉴고, 로스 정식, 히레정식, 모둠카츠 등이 있다.- 월요일 점심 11시 반 오픈에 맞춰 도착했더니 이미 거의 만석이었다. 오픈시간보다 조금 더 이른 시간에도 들어갈 수 있으니, 웨이팅이 싫다면 미리 도착해 있어야한다.- 16000원짜리 특로스카츠 정식 주문. 가브리살이 붙은 등심 부위로 만들었다. 일단 양이 상당히 많다. 심지어 밥도 리필 가능하니 양은 걱정 안해도 될 듯.- 일단 돈가스의 첫입은 환상적이었다. 육즙이 가득하고 부드러웠다. 후추를 뿌려주는 것이 특징. (뿌리기 전에 괜찮은지 주인 분이 물어봐주신다.) 물론 돈가스의 특성상 뒤로 갈수록 좀 느끼하긴 했다.- 로즈마리 오일에 살짝 찍어서 히말라야 솔트에 찍어먹는 방식이 제일 맛있었다. 샐러드도 나름 괜찮았다. - 딱히 불만족스러운 점이 없었고, 일찍 간 덕에 웨이팅도 피할 수 있었다. 혼밥하기에도 좋은 구조라 매우 좋았다.", \'총평: 이 돈까스가 대단해 우승할 만한 가게혜화의 일식 카츠로 유명한 가게는 한시간 웨이팅 후 음식 맛에 실망이 이만저만 아니었던 반면, 이곳은 한시간 웨이팅 후 음식을 맛보고 나서 두시간도 기다릴 수 있을 것 같다고 생각함재방문의사 500배, 주변인에게 망설임 없이 추천할 만한 가게\', \'브레이크타임이 끝나기 20분전쯤?줄서서 기다려서 들어간곳우리뒤로도 줄을 계속해서 섰고 평도 좋아서 기대가 되었던곳이입니다특로스카츠가 궁금했으나 품절이라고하여모둠카츠 두개를 하려다가 로스하나 히레하나를 주문했고결론적으로 모둠가츠 두개를 했으면 많이 남겼을것같아요배부름+개인적으로는 먹으면서 물리는 느낌이 있어 두명이 간다면 로스하나 히레하나 해서 먹어도 될듯우선 맛과는 별개로 안심카츠의 식감과 질감은 돈까스에서 처음 느껴보는 부드러움이었어요입에 걸리는것이 없는 입에서 풀어지는 정도의 부드러움?히말라야 핑크솔트, 로즈마리올리브유,수제돈키츠 소스가 준비되어있고 나름대로 신경'

# %%
len(donkatsu_dining_review)
# Out:
# 26632

# %%
# 이모티콘 없애기

# import re

TEXT = 'donkatsu_dining_review'

EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
TEXT_refine = EMOJI.sub(r'', TEXT)

# %%
donkatsu_dining_review1 = donkatsu_dining_review[:6000]
donkatsu_dining_review2 = donkatsu_dining_review[6000:12000]
donkatsu_dining_review3 = donkatsu_dining_review[12000:18000]
donkatsu_dining_review4 = donkatsu_dining_review[18000:]

# %%
from konlpy.tag import Twitter

twitter = Twitter()
raw_pos_tagged1 = twitter.pos(donkatsu_dining_review1, norm=True, stem=True) # POS Tagging
raw_pos_tagged2 = twitter.pos(donkatsu_dining_review2, norm=True, stem=True) # POS Tagging
raw_pos_tagged3 = twitter.pos(donkatsu_dining_review3, norm=True, stem=True) # POS Tagging
raw_pos_tagged4 = twitter.pos(donkatsu_dining_review4, norm=True, stem=True) # POS Tagging

# %%
raw_pos_tagged = []

for raw_reviews in [donkatsu_dining_review1, donkatsu_dining_review2, donkatsu_dining_review3, donkatsu_dining_review4]:
    raw_pos_tagged += twitter.pos(raw_reviews, norm=True, stem=True)

# %%
del_list = ['하다', '있다', '되다', '이다', '돼다', '않다', '그렇다', '아니다', '이렇다', '그렇다', '어떻다'] 

word_cleaned = []
for word in raw_pos_tagged: #  ('서울', 'Noun'),
    if not word[1] in ["Josa", "Eomi", "Punctuation", "Foreign"]: # Foreign == ”, “ 와 같이 제외되어야할 항목들
        if (len(word[0]) != 1) & (word[0] not in del_list): # 한 글자로 이뤄진 단어들을 제외 & 원치 않는 단어들을 제외
            word_cleaned.append(word[0])
        
word_cleaned
# Out:
# ['맛집',
#  '기록',
#  '카츠',
#  '5.0',
#  '만점',
#  '유명하다',
#  '프리미엄',
#  '돈가스',
#  '한정',
#  '메뉴인',
#  '로스',
#  '카츠',
#  '정식',
#  '인기',
#  '메뉴',
#  '로스',
#  '정식',
#  '히레',
#  '정식',
#  '두다',
#  '카츠',
#  '월요일',
#  '점심',
#  '11시',
#  '오픈',
#  '맞추다',
#  '도착',
#  '이미',
#  '거의',
#  '만석',
#  '오픈',
#  '시간',
#  '조금',
#  '이르다',
#  '시간',
#  '들어가다',
#  '웨이팅',
#  '싫다',
#  '미리',
#  '도착',
#  '야하다',
#  '16000원',
#  '로스',
#  '카츠',
#  '정식',
#  '주문',
#  '가다',
#  '브리',
#  '살이',
#  '붙다',
#  '등심',
#  '부위',
#  '만들다',
#  '일단',
#  '상당하다',
#  '많다',
#  '심지어',
#  '리필',
#  '가능하다',
#  '양은',
#  '걱정',
#  '안해',
#  '일단',
#  '돈가스',
#  '환상',
#  '육즙',
#  '가득하다',
#  '부드럽다',
#  '후추',
#  '뿌리다',
#  '특징',
#  '뿌리다',
#  '괜찮다',
#  '주인',
#  '물어보다',
#  '주다',
#  '물론',
#  '돈가스',
#  '특성',
#  '갈수록',
#  '느끼하다',
#  '로즈마리',
#  '오일',
#  '살짝',
#  '찍다',
#  '히말라야',
#  '솔트',
#  '찍다',
#  '먹다',
#  '방식',
#  '제일',
#  '맛있다',
#  '샐러드',
#  '나름',
#  '괜찮다',
#  '딱하다',
#  '불만족',
#  '없다',
#  '일찍',
#  '웨이팅',
#  '혼밥',
#  '좋다',
#  '구조',
#  '매우',
#  '좋다',
#  '돈까스',
#  '대단하다',
#  '우승하다',
#  '가게',
#  '화의',
#  '일식',
#  '카츠',
#  '유명하다',
#  '가게',
#  '시간',
#  '웨이',
#  '음식',
#  '실망',
#  '이만',
#  '저만',
#  '반면',
#  '시간',
#  '웨이',
#  '음식',
#  '맛보다',
#  '나서다',
#  '시간',
#  '기다리다',
#  '같다',
#  '생각',
#  '함재',
#  '방문',
#  '의사',
#  '500',
#  '주변인',
#  '망설이다',
#  '없이',
#  '추천',
#  '가게',
#  '브레이크',
#  '타임',
#  '끝나다',
#  '20분',
#  '서서',
#  '기다리다',
#  '들어가다',
#  '우리',
#  '계속',
#  '서다',
#  '좋다',
#  '기대',
#  '되어다',
#  '로스',
#  '카츠',
#  '궁금하다',
#  '품절',
#  '두다',
#  '카츠',
#  '로스',
#  '하나',
#  '히레',
#  '하나',
#  '주문',
#  '결론',
#  '모둠가츠',
#  '많이',
#  '남기다',
#  '같다',
#  '배부르다',
#  '개인',
#  '먹다',
#  '물리다',
#  '느낌',
#  '간다',
#  '로스',
#  '하나',
#  '히레하',
#  '먹다',
#  '우선',
#  '별개',
#  '안심',
#  '카츠',
#  '식감',
#  '질감',
#  '돈까스',
#  '처음',
#  '느끼다',
#  '보다',
#  '부드러움',
#  '걸리다',
#  '없다',
#  '풀어지다',
#  '정도',
#  '부드러움',
#  '히말라야',
#  '핑크',
#  '솔트',
#  '로즈마리',
#  '올리브유',
#  '키츠',
#  '소스',
#  '준비',
#  '되어다',
#  '나름',
#  '신경',
#  '쓸다',
#  '느낌',
#  '개인',
#  '한번',
#  '먹다',
#  '보다',
#  '충분하다',
#  '그리고',
#  '건지다',
#  '직원',
#  '손님',
#  '너무',
#  '다그치다',
#  '보다',
#  '사람',
#  '민망하다',
#  '상황',
#  '몇번',
#  '자리',
#  '앉다',
#  '주문',
#  '받다',
#  '마치',
#  '가게',
#  '모든',
#  '시스템',
#  '메뉴',
#  '미리',
#  '알다',
#  '야하다',
#  '느낌',
#  '받다',
#  '손님',
#  '음식',
#  '먹다',
#  '언제',
#  '일어나다',
#  '건지다',
#  '고개',
#  '밀고',
#  '여기저기',
#  '확인',
#  '느껴지다',
#  '별로',
#  '근방',
#  '가장',
#  '좋다',
#  '돈까스',
#  '먹다',
#  '인근',
#  '가츠시',
#  '가성',
#  '압살',
#  '여기다',
#  '고기',
#  '밀다',
#  '붙이다',
#  '느낌',
#  '사실',
#  '생각',
#  '여기',
#  '가성',
#  '절대',
#  '떨어지다',
#  '생각',
#  '아주',
#  '높다',
#  '확률',
#  '기다',
#  '웨이팅',
#  '카톡',
#  '활용',
#  '차례',
#  '알림',
#  '자다',
#  '되어다',
#  '근처',
#  '카페',
#  '요호',
#  '오다',
#  '협의',
#  '음료',
#  '할인',
#  '받다',
#  '기다리다',
#  '대다',
#  '편의',
#  '제공',
#  '돈까스',
#  '고기',
#  '정말',
#  '좋다',
#  '로스',
#  '카츠',
#  '히레',
#  '정도',
#  '부드럽다',
#  '먹다',
#  '즐거움',
#  '와사비',
#  '좋다',
#  '쓸다',
#  '살짝',
#  '단맛',
#  '돌다',
#  '고기',
#  '함께',
#  '먹기',
#  '좋다',
#  '함께',
#  '나오다',
#  '샐러드',
#  '상당하다',
#  '좋다',
#  '좌석',
#  '조금',
#  '좁다',
#  '하지만',
#  '데이트',
#  '코스',
#  '나쁘다',
#  '키즈',
#  '참고',
#  '정도',
#  '돈까스',
#  '어딜',
#  '가도',
#  '만나다',
#  '보기',
#  '어리다',
#  '재료',
#  '떨어지다',
#  '영업',
#  '때문',
#  '빨리',
#  '가다',
#  '좋다',
#  '소스',
#  '로즈마리',
#  '올리브',
#  '오일이',
#  '특이하다',
#  '아주',
#  '풍부하다',
#  '돈까스',
#  '밉다',
#  '살리다',
#  '먼저',
#  '로스',
#  '카츠',
#  '튀김',
#  '거치다',
#  '두껍다',
#  '굉장하다',
#  '바삭',
#  '진짜',
#  '육즙',
#  '살다',
#  '맛있다',
#  '소금',
#  '허브',
#  '어우러지다',
#  '그냥',
#  '설명',
#  '필요',
#  '없다',
#  '미치다',
#  '히레',
#  '로스',
#  '다소',
#  '아쉽다',
#  '비교',
#  '거지',
#  '엄청나다',
#  '약간',
#  '아쉽다',
#  '먹다',
#  '살짝',
#  '느낌',
#  '살짝',
#  '익다',
#  '좋다',
#  '그치다',
#  '안심',
#  '특유',
#  '부드러움',
#  '그대로',
#  '살다',
#  '최근',
#  '먹다',
#  '우동',
#  '돈까스',
#  '가장',
#  '맛있다',
#  '먹다',
#  '가격',
#  '별로',
#  '신경',
#  '쓰이다',
#  '무조건',
#  '가야',
#  '근데',
#  '줄이다',
#  '너무',
#  '길다',
#  '11시',
#  '오픈',
#  '오픈',
#  '가야',
#  '웨이팅',
#  '없다',
#  '오픈',
#  '가도',
#  '웨이팅',
#  '생기다',
#  '같다',
#  '인테리어',
#  '좋다',
#  '음식',
#  '킹왕짱',
#  '우동',
#  '먹다',
#  '맛있다',
#  '돈까츠',
#  '너무',
#  '맛있다',
#  '우열',
#  '가리다',
#  '힘들다',
#  '모밀',
#  '그냥',
#  '여기',
#  '돈까스',
#  '정말',
#  '충격',
#  '맛있다',
#  '평소',
#  '안심',
#  '돈까스',
#  '별로',
#  '좋아하다',
#  '여기다',
#  '정말',
#  '너무',
#  '맛있다',
#  '안심',
#  '돈까스',
#  '좋아하다',
#  '맛있다',
#  '안심',
#  '돈까스',
#  '아직',
#  '만나다',
#  '정말',
#  '촉촉하다',
#  '빠삭',
#  '탱탱하다',
#  '젓가락',
#  '누르다',
#  '육즙',
#  '베다',
#  '나오다',
#  '돈까스',
#  '조각',
#  '먹다',
#  '감동',
#  '밀려오다',
#  '전혀',
#  '퍽퍽',
#  '기르다',
#  '느끼하다',
#  '부담스럽다',
#  '느낌',
#  '없다',
#  '매우',
#  '깔끔하다',
#  '정성',
#  '느껴지다',
#  '트러플',
#  '소금',
#  '와사비',
#  '돈까스',
#  '소스',
#  '어느',
#  '하나',
#  '거슬리다',
#  '없다',
#  '같이',
#  '내다',
#  '샐러드',
#  '직접',
#  '만들다',
#  '유자',
#  '드레싱',
#  '츠케모노',
#  '산뜻하다',
#  '물리다',
#  '없다',
#  '너무',
#  '너무',
#  '지다',
#  '돈까스',
#  '아주',
#  '자다',
#  '어울리다',
#  '심지어',
#  '장국',
#  '너무',
#  '맛있다',
#  '기다',
#  '시간',
#  '오다',
#  '보상',
#  '받다',
#  '느끼다',
#  '등심',
#  '돈까스',
#  '먹다',
#  '보다',
#  '갈다',
#  '식당',
#  '다녀오다',
#  '하루',
#  '성공하다',
#  '생각',
#  'ㅠㅠ',
#  '감동',
#  'ㅠㅠ',
#  '여기',
#  '돈까스',
#  '맛있다',
#  '심다',
#  '아주',
#  '부드럽다',
#  '담백하다',
#  '소스',
#  '괜찮다',
#  '편이',
#  '모든',
#  '평타',
#  '이상',
#  '최근',
#  '돈까스',
#  '상향',
#  '평준화',
#  '느낌',
#  '방문',
#  '의사',
#  '11시',
#  '30분',
#  '오픈',
#  '토요일',
#  '11시',
#  '대기',
#  '고요',
#  '테이블',
#  '어플',
#  '미리',
#  '원격',
#  '예약',
#  '추천',
#  '드리다',
#  '평일',
#  '항상',
#  '웨이',
#  '그래서',
#  '오픈',
#  '시간',
#  '방문',
#  '추천',
#  '드리다',
#  '희다',
#  '히레가츠',
#  '로스',
#  '카츠',
#  '등심',
#  '로만',
#  '주문',
#  '마디',
#  '육즙',
#  '식감',
#  '시간',
#  '지나다',
#  '살다',
#  '등심',
#  '촉촉하다',
#  '식감',
#  '얇다',
#  '바삭',
#  '튀김',
#  '정말',
#  '고소하다',
#  '자다',
#  '어울리다',
#  '평소',
#  '돈가스',
#  '느끼하다',
#  '생각',
#  '그리다',
#  '즐기다',
#  '먹다',
#  '김치',
#  '피클',
#  '생각',
#  '날다',
#  '정도',
#  '담백하다',
#  '카레',
#  '주문',
#  '카레',
#  '그리다',
#  '인상',
#  '이진',
#  '정식',
#  '나오다',
#  '짜지다',
#  '적당하다',
#  '감칠맛',
#  '나다',
#  '나다',
#  '치킨',
#  '카라',
#  '조각',
#  '나오다',
#  '튀기다',
#  '촉촉하다',
#  '부드럽다',
#  '특히',
#  '치킨',
#  '가라아게',
#  '소스',
#  '레몬',
#  '나다',
#  '매우',
#  '하지만',
#  '무엇',
#  '돈까스',
#  '찌다',
#  '비치',
#  '트러플',
#  '소금',
#  '함께',
#  '찍다',
#  '먹다',
#  '추천',
#  '드리다',
#  '직원',
#  '가다',
#  '친절하다',
#  '물다',
#  '바로바로',
#  '채우다',
#  '구간',
#  '담당',
#  '서버',
#  '요청',
#  '사항',
#  '피드백',
#  '빨르다',
#  '또한',
#  '오픈',
#  '주방',
#  '메뉴',
#  '기다리다',
#  '구경',
#  '재미',
#  '쏠쏠하다',
#  '단지',
#  '형태',
#  '일본',
#  '스타일',
#  '둘러앉다',
#  '먹기',
#  '사생활',
#  '보호',
#  '안되다',
#  '코로나',
#  '오붓하다',
#  '먹다',
#  '없다',
#  '단점',
#  '중간',
#  '중간',
#  '음악',
#  '나오다',
#  '시국',
#  '살짝',
#  '일본',
#  '골목',
#  '오다',
#  '느끼다',
#  '주말',
#  '점심',
#  '방문',
#  '동생',
#  '인생',
#  '돈까스',
#  '기대하다',
#  '만족',
#  '만족',
#  '일단',
#  '여기다',
#  '대기',
#  '기다',
#  '어플',
#  '미리',
#  '예약',
#  '갈다',
#  '추천',
#  '드리다',
#  '저희',
#  '근처',
#  '다른',
#  '들르다',
#  '출발',
#  '예약',
#  '걸다',
#  '도착',
#  '바로',
#  '들어가다',
#  '내부',
#  '구조',
#  '특이하다',
#  '테이블',
#  '모양',
#  '한쪽',
#  '오픈',
#  '키친',
#  '되어다',
#  '안심',
#  '스테이크',
#  '보기',
#  '적다',
#  '보이다',
#  '성인',
#  '여자',
#  '먹기',
#  '충분하다',
#  '부들부들',
#  '냄새',
#  '없다',
#  '샐러드',
#  '드레싱',
#  '일반',
#  '참깨',
#  '드레싱',
#  '같다',
#  '윤기',
#  '흐르다',
#  '친구',
#  '너무',
#  '맛있다',
#  '일본',
#  '흔하다',
#  '먹다',
#  '돈지루',
#  '돼지고기',
#  '된장찌개',
#  '간도',
#  '잘맞다',
#  '맛있다',
#  '라인',
#  '여서',
#  '근처',
#  '오시',
#  '들르다',
#  '디저트',
#  '한번',
#  '끝내다',
#  '요즘',
#  '프리미엄',
#  '돈까스',
#  '유행',
#  '방문',
#  '맛보다',
#  '엄지',
#  '인생',
#  '체고',
#  '돈까스',
#  '고기',
#  '거의',
#  '고급',
#  '레스토랑',
#  '스테이크',
#  '부드럽다',
#  '소금',
#  '찍다',
#  '먹다',
#  '너무',
#  '맛있다',
#  '양배추',
#  '피클',
#  '직접',
#  '담그다',
#  '너무',
#  '너무',
#  '맛있다',
#  '먹다',
#  '감탄',
#  '오다',
#  '도산',
#  '만가',
#  '자동',
#  '생각나다',
#  '끄다',
#  '같다',
#  '인생',
#  '돈까스',
#  '기름',
#  '지지도',
#  '고기',
#  '굉장하다',
#  '부드럽다',
#  '돈까스',
#  '먹다',
#  '보다',
#  '김치',
#  '생각나다',
#  '여기다',
#  '전혀',
#  '생각',
#  '나다',
#  '같이',
#  '나오다',
#  '양배추',
#  '너무',
#  '맛있다',
#  '돈까스',
#  '싶다',
#  '먹다',
#  '엄청',
#  '배부르다',
#  '먹다',
#  '배부르다',
#  '너무',
#  '만족스럽다',
#  '생각나다',
#  '트러플',
#  '소금',
#  '찍다',
#  '먹다',
#  '진짜',
#  '맛있다',
#  '같이',
#  '나오다',
#  '국도',
#  '리필',
#  '먹다',
#  '추가',
#  '비용',
#  '그냥',
#  '서비스',
#  '주다',
#  '로스',
#  '히레가츠',
#  '너무',
#  '맛있다',
#  '처음',
#  '나오다',
#  '보고',
#  '너무',
#  '적지',
#  '싶다',
#  '먹다',
#  '나니',
#  '부르다',
#  'ㅎㅎ',
#  '깔끔하다',
#  '내부',
#  '기름',
#  '냄새',
#  '나다',
#  '방문',
#  '의사',
#  '유명하다',
#  '이유',
#  '치즈',
#  '돈까스',
#  '모밀',
#  '짜다',
#  '짜다',
#  '마냥',
#  '맛있다',
#  '느끼하다',
#  '개운하다',
#  '바삭',
#  '개운하다',
#  '순삭',
#  '모밀',
#  '리필',
#  '해주다',
#  '만족',
#  '양도',
#  '혜자',
#  '점심시간',
#  '너무',
#  '기다',
#  '12:30',
#  '이후',
#  '추천',
#  '치즈',
#  '살살',
#  '녹다',
#  '고기',
#  '부드럽다',
#  '끝내주다',
#  '듣다',
#  '환상',
#  '비빔',
#  '밀도',
#  '맛있다',
#  '깜놀',
#  '줄이다',
#  '관리',
#  '그리다',
#  '오래',
#  '대기',
#  '광화문',
#  '메이',
#  '에르',
#  '건물',
#  '지하상가',
#  '위치',
#  '돈까스',
#  '메밀',
#  '전문점',
#  '지하상가',
#  '자체',
#  '복잡하다',
#  '안내',
#  '미흡하다',
#  '메다',
#  '상가',
#  '하나',
#  '화장실',
#  '파다',
#  '따라가다',
#  '보다',
#  '쉬다',
#  '찾다',
#  '상가',
#  '매장',
#  '크다',
#  '주변',
#  '직장인',
#  '인기',
#  '많다',
#  '웨이팅',
#  '돈까스',
#  '정통',
#  '일본',
#  '얇다',
#  '고기',
#  '사용',
#  '바삭',
#  '맛있다',
#  '편이',
#  '메뉴',
#  '새우다',
#  '생선',
#  '까스',
#  '같다',
#  '모습',
#  '그대로',
#  '그냥',
#  '새우',
#  '튀김',
#  '곁들이다',
#  '나오다',
#  '미니',
#  '우동',
#  '국물',
#  '얼큰하다',
#  '편이',
#  '돈까스',
#  '느끼하다',
#  '자다',
#  '잡다',
#  '주다',
#  '소스',
#  '너무',
#  '좋다',
#  '전반',
#  '바삭',
#  '맛있다',
#  '바삭',
#  '돈새까스',
#  '7.5천원',
#  '치즈',
#  '돈까스',
#  '10.0천원',
#  '메밀',
#  '비빔',
#  '7.0천원',
#  '정도',
#  ...]

# %%
# 리스트에 담긴 단어들을 대상으로 갯수를 세어,
# 단어를 key로 등장 횟수를 value로 하는 dict 만들기

word_dic = {}

for word in word_cleaned:
    if word not in word_dic:
        word_dic[word] = 1 # changed from "0" to "1"
    else:
        word_dic[word] += 1
        
word_dic
# Out:
# {'맛집': 23,
#  '기록': 3,
#  '카츠': 32,
#  '5.0': 1,
#  '만점': 3,
#  '유명하다': 15,
#  '프리미엄': 19,
#  '돈가스': 41,
#  '한정': 1,
#  '메뉴인': 3,
#  '로스': 23,
#  '정식': 15,
#  '인기': 7,
#  '메뉴': 24,
#  '히레': 6,
#  '두다': 4,
#  '월요일': 1,
#  '점심': 5,
#  '11시': 6,
#  '오픈': 19,
#  '맞추다': 7,
#  '도착': 7,
#  '이미': 3,
#  '거의': 5,
#  '만석': 2,
#  '시간': 25,
#  '조금': 14,
#  '이르다': 2,
#  '들어가다': 11,
#  '웨이팅': 29,
#  '싫다': 1,
#  '미리': 6,
#  '야하다': 3,
#  '16000원': 1,
#  '주문': 22,
#  '가다': 36,
#  '브리': 3,
#  '살이': 1,
#  '붙다': 1,
#  '등심': 12,
#  '부위': 2,
#  '만들다': 8,
#  '일단': 7,
#  '상당하다': 5,
#  '많다': 41,
#  '심지어': 3,
#  '리필': 6,
#  '가능하다': 9,
#  '양은': 2,
#  '걱정': 4,
#  '안해': 1,
#  '환상': 3,
#  '육즙': 11,
#  '가득하다': 1,
#  '부드럽다': 31,
#  '후추': 1,
#  '뿌리다': 3,
#  '특징': 3,
#  '괜찮다': 19,
#  '주인': 2,
#  '물어보다': 4,
#  '주다': 11,
#  '물론': 4,
#  '특성': 1,
#  '갈수록': 1,
#  '느끼하다': 23,
#  '로즈마리': 3,
#  '오일': 2,
#  '살짝': 14,
#  '찍다': 18,
#  '히말라야': 5,
#  '솔트': 3,
#  '먹다': 134,
#  '방식': 1,
#  '제일': 3,
#  '맛있다': 108,
#  '샐러드': 10,
#  '나름': 3,
#  '딱하다': 2,
#  '불만족': 1,
#  '없다': 37,
#  '일찍': 2,
#  '혼밥': 3,
#  '좋다': 78,
#  '구조': 2,
#  '매우': 16,
#  '돈까스': 123,
#  '대단하다': 3,
#  '우승하다': 1,
#  '가게': 23,
#  '화의': 1,
#  '일식': 3,
#  '웨이': 14,
#  '음식': 20,
#  '실망': 3,
#  '이만': 1,
#  '저만': 1,
#  '반면': 2,
#  '맛보다': 7,
#  '나서다': 3,
#  '기다리다': 22,
#  '같다': 36,
#  '생각': 30,
#  '함재': 2,
#  '방문': 37,
#  '의사': 8,
#  '500': 1,
#  '주변인': 1,
#  '망설이다': 1,
#  '없이': 10,
#  '추천': 18,
#  '브레이크': 2,
#  '타임': 3,
#  '끝나다': 2,
#  '20분': 2,
#  '서서': 5,
#  '우리': 4,
#  '계속': 3,
#  '서다': 7,
#  '기대': 7,
#  '되어다': 22,
#  '궁금하다': 3,
#  '품절': 1,
#  '하나': 25,
#  '결론': 1,
#  '모둠가츠': 1,
#  '많이': 11,
#  '남기다': 2,
#  '배부르다': 5,
#  '개인': 8,
#  '물리다': 3,
#  '느낌': 21,
#  '간다': 2,
#  '히레하': 1,
#  '우선': 4,
#  '별개': 1,
#  '안심': 15,
#  '식감': 10,
#  '질감': 1,
#  '처음': 9,
#  '느끼다': 12,
#  '보다': 41,
#  '부드러움': 4,
#  '걸리다': 5,
#  '풀어지다': 1,
#  '정도': 33,
#  '핑크': 2,
#  '올리브유': 1,
#  '키츠': 1,
#  '소스': 39,
#  '준비': 3,
#  '신경': 3,
#  '쓸다': 4,
#  '한번': 13,
#  '충분하다': 6,
#  '그리고': 5,
#  '건지다': 4,
#  '직원': 8,
#  '손님': 12,
#  '너무': 43,
#  '다그치다': 1,
#  '사람': 15,
#  '민망하다': 1,
#  '상황': 1,
#  '몇번': 1,
#  '자리': 10,
#  '앉다': 8,
#  '받다': 9,
#  '마치': 1,
#  '모든': 4,
#  '시스템': 1,
#  '알다': 11,
#  '언제': 2,
#  '일어나다': 2,
#  '고개': 1,
#  '밀고': 1,
#  '여기저기': 1,
#  '확인': 1,
#  '느껴지다': 6,
#  '별로': 7,
#  '근방': 2,
#  '가장': 8,
#  '인근': 4,
#  '가츠시': 1,
#  '가성': 6,
#  '압살': 1,
#  '여기다': 4,
#  '고기': 49,
#  '밀다': 1,
#  '붙이다': 1,
#  '사실': 4,
#  '여기': 14,
#  '절대': 1,
#  '떨어지다': 4,
#  '아주': 9,
#  '높다': 5,
#  '확률': 1,
#  '기다': 9,
#  '카톡': 1,
#  '활용': 2,
#  '차례': 1,
#  '알림': 1,
#  '자다': 27,
#  '근처': 8,
#  '카페': 2,
#  '요호': 1,
#  '오다': 21,
#  '협의': 1,
#  '음료': 2,
#  '할인': 1,
#  '대다': 5,
#  '편의': 1,
#  '제공': 4,
#  '정말': 19,
#  '즐거움': 1,
#  '와사비': 12,
#  '단맛': 2,
#  '돌다': 1,
#  '함께': 6,
#  '먹기': 6,
#  '나오다': 41,
#  '좌석': 4,
#  '좁다': 7,
#  '하지만': 10,
#  '데이트': 2,
#  '코스': 2,
#  '나쁘다': 1,
#  '키즈': 1,
#  '참고': 8,
#  '어딜': 1,
#  '가도': 3,
#  '만나다': 4,
#  '보기': 4,
#  '어리다': 1,
#  '재료': 9,
#  '영업': 4,
#  '때문': 10,
#  '빨리': 1,
#  '올리브': 1,
#  '오일이': 1,
#  '특이하다': 12,
#  '풍부하다': 2,
#  '밉다': 1,
#  '살리다': 3,
#  '먼저': 4,
#  '튀김': 33,
#  '거치다': 1,
#  '두껍다': 10,
#  '굉장하다': 4,
#  '바삭': 22,
#  '진짜': 12,
#  '살다': 5,
#  '소금': 25,
#  '허브': 1,
#  '어우러지다': 2,
#  '그냥': 11,
#  '설명': 2,
#  '필요': 3,
#  '미치다': 2,
#  '다소': 6,
#  '아쉽다': 7,
#  '비교': 2,
#  '거지': 1,
#  '엄청나다': 2,
#  '약간': 4,
#  '익다': 3,
#  '그치다': 1,
#  '특유': 2,
#  '그대로': 5,
#  '최근': 3,
#  '우동': 20,
#  '가격': 35,
#  '쓰이다': 1,
#  '무조건': 2,
#  '가야': 3,
#  '근데': 4,
#  '줄이다': 3,
#  '길다': 4,
#  '생기다': 2,
#  '인테리어': 8,
#  '킹왕짱': 1,
#  '돈까츠': 1,
#  '우열': 1,
#  '가리다': 1,
#  '힘들다': 4,
#  '모밀': 23,
#  '충격': 1,
#  '평소': 3,
#  '좋아하다': 13,
#  '아직': 1,
#  '촉촉하다': 8,
#  '빠삭': 1,
#  '탱탱하다': 1,
#  '젓가락': 1,
#  '누르다': 1,
#  '베다': 2,
#  '조각': 6,
#  '감동': 4,
#  '밀려오다': 1,
#  '전혀': 2,
#  '퍽퍽': 2,
#  '기르다': 4,
#  '부담스럽다': 3,
#  '깔끔하다': 25,
#  '정성': 3,
#  '트러플': 6,
#  '어느': 4,
#  '거슬리다': 1,
#  '같이': 15,
#  '내다': 10,
#  '직접': 5,
#  '유자': 3,
#  '드레싱': 4,
#  '츠케모노': 1,
#  '산뜻하다': 1,
#  '지다': 6,
#  '어울리다': 7,
#  '장국': 1,
#  '보상': 2,
#  '갈다': 7,
#  '식당': 16,
#  '다녀오다': 2,
#  '하루': 3,
#  '성공하다': 1,
#  'ㅠㅠ': 6,
#  '심다': 5,
#  '담백하다': 6,
#  '편이': 22,
#  '평타': 1,
#  '이상': 8,
#  '상향': 1,
#  '평준화': 1,
#  '30분': 6,
#  '토요일': 2,
#  '대기': 9,
#  '고요': 1,
#  '테이블': 17,
#  '어플': 2,
#  '원격': 1,
#  '예약': 7,
#  '드리다': 6,
#  '평일': 8,
#  '항상': 6,
#  '그래서': 4,
#  '희다': 1,
#  '히레가츠': 2,
#  '로만': 2,
#  '마디': 1,
#  '지나다': 3,
#  '얇다': 8,
#  '고소하다': 8,
#  '그리다': 5,
#  '즐기다': 5,
#  '김치': 4,
#  '피클': 2,
#  '날다': 2,
#  '카레': 13,
#  '인상': 6,
#  '이진': 1,
#  '짜지다': 1,
#  '적당하다': 6,
#  '감칠맛': 1,
#  '나다': 7,
#  '치킨': 3,
#  '카라': 1,
#  '튀기다': 12,
#  '특히': 7,
#  '가라아게': 1,
#  '레몬': 3,
#  '무엇': 2,
#  '찌다': 2,
#  '비치': 1,
#  '친절하다': 13,
#  '물다': 1,
#  '바로바로': 1,
#  '채우다': 1,
#  '구간': 1,
#  '담당': 1,
#  '서버': 1,
#  '요청': 1,
#  '사항': 1,
#  '피드백': 2,
#  '빨르다': 1,
#  '또한': 4,
#  '주방': 5,
#  '구경': 1,
#  '재미': 1,
#  '쏠쏠하다': 1,
#  '단지': 2,
#  '형태': 3,
#  '일본': 12,
#  '스타일': 6,
#  '둘러앉다': 1,
#  '사생활': 1,
#  '보호': 1,
#  '안되다': 3,
#  '코로나': 2,
#  '오붓하다': 1,
#  '단점': 3,
#  '중간': 4,
#  '음악': 1,
#  '시국': 1,
#  '골목': 2,
#  '주말': 4,
#  '동생': 1,
#  '인생': 4,
#  '기대하다': 3,
#  '만족': 6,
#  '저희': 2,
#  '다른': 11,
#  '들르다': 4,
#  '출발': 1,
#  '걸다': 2,
#  '바로': 8,
#  '내부': 8,
#  '모양': 2,
#  '한쪽': 2,
#  '키친': 2,
#  '스테이크': 2,
#  '적다': 11,
#  '보이다': 14,
#  '성인': 1,
#  '여자': 1,
#  '부들부들': 1,
#  '냄새': 5,
#  '일반': 8,
#  '참깨': 1,
#  '윤기': 2,
#  '흐르다': 2,
#  '친구': 2,
#  '흔하다': 3,
#  '돈지루': 2,
#  '돼지고기': 4,
#  '된장찌개': 1,
#  '간도': 1,
#  '잘맞다': 1,
#  '라인': 1,
#  '여서': 1,
#  '오시': 4,
#  '디저트': 1,
#  '끝내다': 1,
#  '요즘': 3,
#  '유행': 1,
#  '엄지': 1,
#  '체고': 1,
#  '고급': 4,
#  '레스토랑': 1,
#  '양배추': 4,
#  '담그다': 2,
#  '감탄': 1,
#  '도산': 2,
#  '만가': 1,
#  '자동': 1,
#  '생각나다': 4,
#  '끄다': 2,
#  '기름': 12,
#  '지지도': 1,
#  '싶다': 15,
#  '엄청': 10,
#  '만족스럽다': 4,
#  '국도': 2,
#  '추가': 5,
#  '비용': 1,
#  '서비스': 7,
#  '보고': 4,
#  '적지': 1,
#  '나니': 1,
#  '부르다': 3,
#  'ㅎㅎ': 5,
#  '이유': 3,
#  '치즈': 23,
#  '짜다': 4,
#  '마냥': 1,
#  '개운하다': 3,
#  '순삭': 1,
#  '해주다': 6,
#  '양도': 11,
#  '혜자': 1,
#  '점심시간': 6,
#  '12:30': 1,
#  '이후': 3,
#  '살살': 2,
#  '녹다': 3,
#  '끝내주다': 1,
#  '듣다': 2,
#  '비빔': 3,
#  '밀도': 2,
#  '깜놀': 1,
#  '관리': 1,
#  '오래': 4,
#  '광화문': 2,
#  '메이': 1,
#  '에르': 1,
#  '건물': 2,
#  '지하상가': 2,
#  '위치': 8,
#  '메밀': 2,
#  '전문점': 7,
#  '자체': 8,
#  '복잡하다': 1,
#  '안내': 1,
#  '미흡하다': 1,
#  '메다': 1,
#  '상가': 2,
#  '화장실': 2,
#  '파다': 1,
#  '따라가다': 1,
#  '쉬다': 5,
#  '찾다': 9,
#  '매장': 4,
#  '크다': 7,
#  '주변': 5,
#  '직장인': 3,
#  '정통': 1,
#  '사용': 9,
#  '새우다': 1,
#  '생선': 1,
#  '까스': 2,
#  '모습': 6,
#  '새우': 4,
#  '곁들이다': 5,
#  '미니': 2,
#  '국물': 8,
#  '얼큰하다': 1,
#  '잡다': 2,
#  '전반': 4,
#  '돈새까스': 1,
#  '7.5천원': 1,
#  '10.0천원': 1,
#  '7.0천원': 1,
#  '오피스': 1,
#  '중심': 1,
#  '상권': 1,
#  '음식점': 2,
#  '착하다': 3,
#  '종각': 2,
#  '넘다': 6,
#  '따뜻하다': 4,
#  '사이드': 5,
#  '버리다': 3,
#  '인원': 1,
#  '시키다': 10,
#  '기본': 9,
#  '부족하다': 3,
#  '거리': 4,
#  '복판': 1,
#  '어마어마하다': 1,
#  '숨다': 3,
#  '사랑': 1,
#  '늘어지다': 1,
#  '육질': 3,
#  '조화': 1,
#  '훌륭하다': 4,
#  '궁합': 6,
#  '시원하다': 4,
#  '다시': 9,
#  '시원': 2,
#  '반복': 1,
#  '번갈아': 1,
#  '새롭다': 2,
#  '사리다': 1,
#  '사장': 7,
#  '인심': 1,
#  '기적': 1,
#  '포장': 7,
#  '일행': 1,
#  '입장': 4,
#  '비다': 6,
#  '뛰어나다': 2,
#  '10,000': 1,
#  '7,000': 2,
#  '심하다': 1,
#  '오후': 1,
#  '4시': 1,
#  '기자': 1,
#  '순번': 1,
#  '3시': 1,
#  '55분': 1,
#  '무려': 1,
#  '다행하다': 2,
#  '5시': 2,
#  '자마자': 1,
#  '두툼': 5,
#  '외투': 1,
#  '입다': 1,
#  '겨울': 1,
#  '불편하다': 6,
#  '평이': 4,
#  '겨자': 5,
#  '작다': 7,
#  '반지하': 1,
#  '레모네이드': 1,
#  '구지': 2,
#  '천천히': 1,
#  '거나': 4,
#  '여유': 1,
#  '가면': 4,
#  '리스트': 1,
#  '이름': 3,
#  '올려놓다': 1,
#  '실제': 1,
#  '넓다': 2,
#  '크레이지': 4,
#  '4.0': 2,
#  '우리나라': 1,
#  '언급': 1,
#  '등장': 1,
#  '위해': 6,
#  '번째': 1,
#  '성공': 1,
#  '돈맥': 1,
#  '세트': 7,
#  '대표': 3,
#  '특로스가츠': 2,
#  '비롯': 2,
#  '가스': 6,
#  '고로케': 2,
#  '골고루': 2,
#  '생맥주': 1,
#  '조합': 3,
#  '유명': 4,
#  '대가': 1,
#  '문제': 1,
#  '미로': 2,
#  '주차': 9,
#  '대도': 1,
#  '성애자': 1,
#  '라면': 2,
#  '해보다': 7,
#  '정돈': 11,
#  '그렇게': 1,
#  '1시간': 3,
#  '오버': 2,
#  '듭니': 2,
#  '원래': 1,
#  '모르다': 7,
#  '다음': 8,
#  '히레카츠': 4,
#  '타이틀': 1,
#  '유지': 1,
#  '한다는': 3,
#  '세대': 1,
#  '선두': 1,
#  '주자': 2,
#  '강남': 1,
#  '지하': 4,
#  '주차장': 3,
#  '갖추다': 1,
#  '장점': 1,
#  '매니저': 1,
#  '무척': 4,
#  '프로': 1,
#  '페셔널': 1,
#  '응대': 2,
#  '하이': 1,
#  '늦다': 3,
#  '옮기다': 1,
#  '정중하다': 1,
#  '양해': 1,
#  '차다': 7,
#  '도씨': 1,
#  '보관': 2,
#  '400시간': 1,
#  '숙성': 3,
#  '경우': 4,
#  '2~3일': 1,
#  '의미': 1,
#  '보시': 2,
#  '이기': 3,
#  '쓴다': 2,
#  '저온': 2,
#  '단백질': 1,
#  '변형': 1,
#  '최소': 1,
#  '화하다': 1,
#  '지나치다': 2,
#  '먹음': 3,
#  '사진': 5,
#  '빵가루': 4,
#  '된장국': 2,
#  '미소시루': 2,
#  '밑반찬': 2,
#  '조금씩': 1,
#  '그릇': 3,
#  '초라하다': 1,
#  '컨디션': 1,
#  '경험': 3,
#  '동네': 2,
#  '불만': 1,
#  '지불': 2,
#  '보여주다': 2,
#  '대부분': 1,
#  '가로수길': 2,
#  '혜화점': 1,
#  '완성': 1,
#  '보아': 2,
#  '역시': 5,
#  '동의': 1,
#  '그야말로': 1,
#  '국내': 2,
#  '최초': 1,
#  '기법': 1,
#  '통해': 3,
#  '래서': 3,
#  '직장': 1,
#  '점심때': 1,
#  '가기': 2,
#  '무리': 1,
#  '20-30분': 1,
#  '필수': 2,
#  '반찬': 7,
#  '기존': 1,
#  '비싸다': 8,
#  '맛난': 1,
#  '커서': 1,
#  '자르다': 2,
#  '달라': 4,
#  '가위': 1,
#  '줍다': 1,
#  '분기': 1,
#  '뭉치다': 2,
#  '만큼': 1,
#  '깨끗하다': 3,
#  '대접받다': 1,
#  '요리': 3,
#  '다만': 5,
#  '부담': 1,
#  '자주': 5,
#  '다르다': 7,
#  '스탠다드': 3,
#  '아예': 1,
#  '단면': 1,
#  '보이': 1,
#  '동그랗다': 2,
#  '색다르다': 2,
#  '초창': 1,
#  '여러': 3,
#  '종류': 5,
#  '5천원': 1,
#  '차이': 3,
#  '차이다': 2,
#  '나진': 1,
#  '웬만하다': 1,
#  '신사': 1,
#  '부근': 1,
#  '땡기다': 1,
#  '맵다': 8,
#  '어묵': 5,
#  '양념장': 2,
#  '막연하다': 1,
#  '뭉근히': 1,
#  '오르다': 3,
#  '즉석': 1,
#  '배고프다': 1,
#  '가보다': 3,
#  '가세': 1,
#  '그러면': 1,
#  '조절': 3,
#  '호구': 1,
#  '보통': 3,
#  '선택': 4,
#  '어렵다': 5,
#  '주민': 1,
#  '벼르': 1,
#  '기회': 1,
#  '끊임없다': 2,
#  '들어오다': 3,
#  '나가다': 2,
#  '한국': 3,
#  '기계로': 1,
#  '뽑다': 1,
#  '쑥갓': 1,
#  '푸다': 6,
#  '비쥬': 2,
#  '칼칼하다': 3,
#  '매콤': 4,
#  '술안주': 1,
#  '해장': 1,
#  '달달': 2,
#  '흠뻑': 2,
#  '오히려': 2,
#  '입맛': 2,
#  '타이밍': 2,
#  '가락국수': 1,
#  '강하다': 2,
#  '분식': 1,
#  '국수': 2,
#  '면도': 1,
#  '타입': 1,
#  '뜨끈하다': 1,
#  '매다': 2,
#  '청양고추': 1,
#  '좀더': 1,
#  '면발': 2,
#  '서울': 2,
#  '집중': 1,
#  'TOP': 1,
#  '용산': 1,
#  '우체국': 1,
#  '뒷골목': 1,
#  '밥집': 1,
#  '12': 2,
#  '연어': 2,
#  '관련': 2,
#  '취향': 6,
#  '반영': 1,
#  '메뉴판': 1,
#  '따로': 2,
#  '계산서': 1,
#  '뭉치': 1,
#  '적히다': 2,
#  '익히다': 3,
#  '브라운': 4,
#  '로스까스': 2,
#  '생강': 1,
#  '절임': 3,
#  '단무지': 4,
#  '식사': 6,
#  '영향': 1,
#  '수준': 2,
#  '벗겨지다': 4,
#  '집다': 1,
#  '오랜': 1,
#  '부어': 1,
#  '그렇다고': 1,
#  '치다': 2,
#  '현상': 1,
#  '발견': 1,
#  '수분': 1,
#  '제거': 1,
#  '과정': 3,
#  '충분': 1,
#  '써다': 2,
#  '순간': 2,
#  '홀랑': 1,
#  '실력': 2,
#  '미달': 1,
#  '중앙': 4,
#  '부분': 9,
#  '두께': 8,
#  '발생': 1,
#  '상임': 1,
#  '확실하다': 1,
#  '조리': 4,
#  '구심': 1,
#  '자아내다': 1,
#  '개선': 1,
#  '필요하다': 1,
#  '동시': 2,
#  '평범하다': 1,
#  '시판': 1,
#  '제품': 1,
#  '쓰다': 2,
#  '일부러': 2,
#  '찾아가다': 9,
#  '일이': 2,
#  '고려': 1,
#  '가치': 2,
#  '만족하다': 4,
#  '상대': 1,
#  '저렴하다': 2,
#  '겁니다': 1,
#  '종업원': 1,
#  '딸리다': 1,
#  '파장': 1,
#  '노상': 1,
#  '대면': 1,
#  '소진': 3,
#  '합리': 1,
#  '인편': 1,
#  '남다름': 1,
#  '다섯': 2,
#  '양식': 3,
#  '화이트': 1,
#  '4.5': 1,
#  '기지': 1,
#  '자극': 1,
#  '분위기': 12,
#  '3.0': 2,
#  '바쁘다': 1,
#  '와중': 1,
#  '편재': 1,
#  '옛날': 3,
#  '추후': 1,
#  '왠지': 1,
#  '익숙하다': 1,
#  '수프': 1,
#  '덜하다': 1,
#  '부부': 2,
#  '미소': 2,
#  '작고': 2,
#  '조용하다': 4,
#  '돈카츠': 18,
#  '연신내': 2,
#  '남자': 2,
#  '오로지': 1,
#  '초등학교': 1,
#  '잠깐': 2,
#  '녹아내리다': 3,
#  'ㅋㅋ': 1,
#  '덥다': 2,
#  '숟가락': 1,
#  '이어서': 1,
#  '저렴': 1,
#  '한편': 1,
#  '표적': 1,
#  '지금': 2,
#  '바뀌다': 3,
#  '햇살': 2,
#  '머물다': 2,
#  '식탁': 3,
#  '상호': 3,
#  '변경': 2,
#  '변동': 1,
#  '여전하다': 2,
#  '돈까쓰': 3,
#  '비계': 4,
#  '끼우다': 1,
#  '아유': 1,
#  '가지': 5,
#  '따르다': 3,
#  '깍두기': 3,
#  '체인점': 1,
#  '점포': 1,
#  '바꾸다': 1,
#  '상위': 1,
#  '끊기다': 1,
#  '후퇴': 1,
#  '일쑤': 1,
#  '오늘': 4,
#  '드디어': 1,
#  '실내': 4,
#  '파티션': 1,
#  '구분': 1,
#  '놓다': 2,
#  '쾌적하다': 1,
#  '조명도': 1,
#  '딱딱하다': 1,
#  '채소': 1,
#  '대학로': 2,
#  '들다': 11,
#  '소문나다': 2,
#  '신선하다': 5,
#  '계단': 1,
#  '늘어서다': 1,
#  '전화': 1,
#  '너무나도': 1,
#  '언제나': 2,
#  '정신': 1,
#  '남녀': 1,
#  '공용': 1,
#  '삼성동': 1,
#  '백화점': 1,
#  '건너편': 1,
#  '휘문중': 1,
#  '학교': 1,
#  '빠르다': 5,
#  '타다': 4,
#  '마제': 7,
#  '소바': 13,
#  '가츠산': 1,
#  '맛보기': 1,
#  '붐비다': 2,
#  '시간대': 2,
#  '돈가츠': 4,
#  '두툼해': 1,
#  '넣기': 1,
#  '벅차다': 2,
#  '여러가지': 2,
#  '수도': 2,
#  '믿음': 1,
#  '퀄리티': 3,
#  '민숭맨숭': 1,
#  '달래다': 1,
#  '11:30': 1,
#  '11:40': 1,
#  '가츠산도': 2,
#  '씹다': 2,
#  '비우다': 1,
#  '아깝다': 3,
#  '장정': 1,
#  '남성': 1,
#  '이집': 1,
#  '만족도': 2,
#  '모두': 7,
#  '맥주': 1,
#  '9천원': 1,
#  '삼성': 1,
#  '검색': 2,
#  '곳웨이팅': 1,
#  '시반': 1,
#  '두시': 1,
#  '애매하다': 2,
#  '드라이': 1,
#  '쏘다': 2,
#  '뺏다': 1,
#  '단정하다': 1,
#  '깊다': 1,
#  '또는': 1,
#  '고프다': 2,
#  ...}

# %%
word_dic.items()
# Out:
# dict_items([('맛집', 23), ('기록', 3), ('카츠', 32), ('5.0', 1), ('만점', 3), ('유명하다', 15), ('프리미엄', 19), ('돈가스', 41), ('한정', 1), ('메뉴인', 3), ('로스', 23), ('정식', 15), ('인기', 7), ('메뉴', 24), ('히레', 6), ('두다', 4), ('월요일', 1), ('점심', 5), ('11시', 6), ('오픈', 19), ('맞추다', 7), ('도착', 7), ('이미', 3), ('거의', 5), ('만석', 2), ('시간', 25), ('조금', 14), ('이르다', 2), ('들어가다', 11), ('웨이팅', 29), ('싫다', 1), ('미리', 6), ('야하다', 3), ('16000원', 1), ('주문', 22), ('가다', 36), ('브리', 3), ('살이', 1), ('붙다', 1), ('등심', 12), ('부위', 2), ('만들다', 8), ('일단', 7), ('상당하다', 5), ('많다', 41), ('심지어', 3), ('리필', 6), ('가능하다', 9), ('양은', 2), ('걱정', 4), ('안해', 1), ('환상', 3), ('육즙', 11), ('가득하다', 1), ('부드럽다', 31), ('후추', 1), ('뿌리다', 3), ('특징', 3), ('괜찮다', 19), ('주인', 2), ('물어보다', 4), ('주다', 11), ('물론', 4), ('특성', 1), ('갈수록', 1), ('느끼하다', 23), ('로즈마리', 3), ('오일', 2), ('살짝', 14), ('찍다', 18), ('히말라야', 5), ('솔트', 3), ('먹다', 134), ('방식', 1), ('제일', 3), ('맛있다', 108), ('샐러드', 10), ('나름', 3), ('딱하다', 2), ('불만족', 1), ('없다', 37), ('일찍', 2), ('혼밥', 3), ('좋다', 78), ('구조', 2), ('매우', 16), ('돈까스', 123), ('대단하다', 3), ('우승하다', 1), ('가게', 23), ('화의', 1), ('일식', 3), ('웨이', 14), ('음식', 20), ('실망', 3), ('이만', 1), ('저만', 1), ('반면', 2), ('맛보다', 7), ('나서다', 3), ('기다리다', 22), ('같다', 36), ('생각', 30), ('함재', 2), ('방문', 37), ('의사', 8), ('500', 1), ('주변인', 1), ('망설이다', 1), ('없이', 10), ('추천', 18), ('브레이크', 2), ('타임', 3), ('끝나다', 2), ('20분', 2), ('서서', 5), ('우리', 4), ('계속', 3), ('서다', 7), ('기대', 7), ('되어다', 22), ('궁금하다', 3), ('품절', 1), ('하나', 25), ('결론', 1), ('모둠가츠', 1), ('많이', 11), ('남기다', 2), ('배부르다', 5), ('개인', 8), ('물리다', 3), ('느낌', 21), ('간다', 2), ('히레하', 1), ('우선', 4), ('별개', 1), ('안심', 15), ('식감', 10), ('질감', 1), ('처음', 9), ('느끼다', 12), ('보다', 41), ('부드러움', 4), ('걸리다', 5), ('풀어지다', 1), ('정도', 33), ('핑크', 2), ('올리브유', 1), ('키츠', 1), ('소스', 39), ('준비', 3), ('신경', 3), ('쓸다', 4), ('한번', 13), ('충분하다', 6), ('그리고', 5), ('건지다', 4), ('직원', 8), ('손님', 12), ('너무', 43), ('다그치다', 1), ('사람', 15), ('민망하다', 1), ('상황', 1), ('몇번', 1), ('자리', 10), ('앉다', 8), ('받다', 9), ('마치', 1), ('모든', 4), ('시스템', 1), ('알다', 11), ('언제', 2), ('일어나다', 2), ('고개', 1), ('밀고', 1), ('여기저기', 1), ('확인', 1), ('느껴지다', 6), ('별로', 7), ('근방', 2), ('가장', 8), ('인근', 4), ('가츠시', 1), ('가성', 6), ('압살', 1), ('여기다', 4), ('고기', 49), ('밀다', 1), ('붙이다', 1), ('사실', 4), ('여기', 14), ('절대', 1), ('떨어지다', 4), ('아주', 9), ('높다', 5), ('확률', 1), ('기다', 9), ('카톡', 1), ('활용', 2), ('차례', 1), ('알림', 1), ('자다', 27), ('근처', 8), ('카페', 2), ('요호', 1), ('오다', 21), ('협의', 1), ('음료', 2), ('할인', 1), ('대다', 5), ('편의', 1), ('제공', 4), ('정말', 19), ('즐거움', 1), ('와사비', 12), ('단맛', 2), ('돌다', 1), ('함께', 6), ('먹기', 6), ('나오다', 41), ('좌석', 4), ('좁다', 7), ('하지만', 10), ('데이트', 2), ('코스', 2), ('나쁘다', 1), ('키즈', 1), ('참고', 8), ('어딜', 1), ('가도', 3), ('만나다', 4), ('보기', 4), ('어리다', 1), ('재료', 9), ('영업', 4), ('때문', 10), ('빨리', 1), ('올리브', 1), ('오일이', 1), ('특이하다', 12), ('풍부하다', 2), ('밉다', 1), ('살리다', 3), ('먼저', 4), ('튀김', 33), ('거치다', 1), ('두껍다', 10), ('굉장하다', 4), ('바삭', 22), ('진짜', 12), ('살다', 5), ('소금', 25), ('허브', 1), ('어우러지다', 2), ('그냥', 11), ('설명', 2), ('필요', 3), ('미치다', 2), ('다소', 6), ('아쉽다', 7), ('비교', 2), ('거지', 1), ('엄청나다', 2), ('약간', 4), ('익다', 3), ('그치다', 1), ('특유', 2), ('그대로', 5), ('최근', 3), ('우동', 20), ('가격', 35), ('쓰이다', 1), ('무조건', 2), ('가야', 3), ('근데', 4), ('줄이다', 3), ('길다', 4), ('생기다', 2), ('인테리어', 8), ('킹왕짱', 1), ('돈까츠', 1), ('우열', 1), ('가리다', 1), ('힘들다', 4), ('모밀', 23), ('충격', 1), ('평소', 3), ('좋아하다', 13), ('아직', 1), ('촉촉하다', 8), ('빠삭', 1), ('탱탱하다', 1), ('젓가락', 1), ('누르다', 1), ('베다', 2), ('조각', 6), ('감동', 4), ('밀려오다', 1), ('전혀', 2), ('퍽퍽', 2), ('기르다', 4), ('부담스럽다', 3), ('깔끔하다', 25), ('정성', 3), ('트러플', 6), ('어느', 4), ('거슬리다', 1), ('같이', 15), ('내다', 10), ('직접', 5), ('유자', 3), ('드레싱', 4), ('츠케모노', 1), ('산뜻하다', 1), ('지다', 6), ('어울리다', 7), ('장국', 1), ('보상', 2), ('갈다', 7), ('식당', 16), ('다녀오다', 2), ('하루', 3), ('성공하다', 1), ('ㅠㅠ', 6), ('심다', 5), ('담백하다', 6), ('편이', 22), ('평타', 1), ('이상', 8), ('상향', 1), ('평준화', 1), ('30분', 6), ('토요일', 2), ('대기', 9), ('고요', 1), ('테이블', 17), ('어플', 2), ('원격', 1), ( ...

# %%
# lambda 함수를 활용하여,
# 앞서 만든 dict를 item 단위(tuple)로 꺼내어, tuple(x)의 value(x[1])를 기준으로 하여 내림차순(reverse=True) 정렬합니다.

sorted_word_dic = sorted(word_dic.items(), key=lambda x:x[1], reverse=True)
sorted_word_dic
# Out:
# [('먹다', 134),
#  ('돈까스', 123),
#  ('맛있다', 108),
#  ('좋다', 78),
#  ('고기', 49),
#  ('너무', 43),
#  ('돈가스', 41),
#  ('많다', 41),
#  ('보다', 41),
#  ('나오다', 41),
#  ('소스', 39),
#  ('없다', 37),
#  ('방문', 37),
#  ('가다', 36),
#  ('같다', 36),
#  ('가격', 35),
#  ('정도', 33),
#  ('튀김', 33),
#  ('카츠', 32),
#  ('부드럽다', 31),
#  ('생각', 30),
#  ('웨이팅', 29),
#  ('자다', 27),
#  ('시간', 25),
#  ('하나', 25),
#  ('소금', 25),
#  ('깔끔하다', 25),
#  ('메뉴', 24),
#  ('맛집', 23),
#  ('로스', 23),
#  ('느끼하다', 23),
#  ('가게', 23),
#  ('모밀', 23),
#  ('치즈', 23),
#  ('주문', 22),
#  ('기다리다', 22),
#  ('되어다', 22),
#  ('바삭', 22),
#  ('편이', 22),
#  ('느낌', 21),
#  ('오다', 21),
#  ('음식', 20),
#  ('우동', 20),
#  ('프리미엄', 19),
#  ('오픈', 19),
#  ('괜찮다', 19),
#  ('정말', 19),
#  ('찍다', 18),
#  ('추천', 18),
#  ('돈카츠', 18),
#  ('테이블', 17),
#  ('매우', 16),
#  ('식당', 16),
#  ('유명하다', 15),
#  ('정식', 15),
#  ('안심', 15),
#  ('사람', 15),
#  ('같이', 15),
#  ('싶다', 15),
#  ('조금', 14),
#  ('살짝', 14),
#  ('웨이', 14),
#  ('여기', 14),
#  ('보이다', 14),
#  ('한번', 13),
#  ('좋아하다', 13),
#  ('카레', 13),
#  ('친절하다', 13),
#  ('소바', 13),
#  ('등심', 12),
#  ('느끼다', 12),
#  ('손님', 12),
#  ('와사비', 12),
#  ('특이하다', 12),
#  ('진짜', 12),
#  ('튀기다', 12),
#  ('일본', 12),
#  ('기름', 12),
#  ('분위기', 12),
#  ('들어가다', 11),
#  ('육즙', 11),
#  ('주다', 11),
#  ('많이', 11),
#  ('알다', 11),
#  ('그냥', 11),
#  ('다른', 11),
#  ('적다', 11),
#  ('양도', 11),
#  ('정돈', 11),
#  ('들다', 11),
#  ('샐러드', 10),
#  ('없이', 10),
#  ('식감', 10),
#  ('자리', 10),
#  ('하지만', 10),
#  ('때문', 10),
#  ('두껍다', 10),
#  ('내다', 10),
#  ('엄청', 10),
#  ('시키다', 10),
#  ('설렁탕', 10),
#  ('가능하다', 9),
#  ('처음', 9),
#  ('받다', 9),
#  ('아주', 9),
#  ('기다', 9),
#  ('재료', 9),
#  ('대기', 9),
#  ('찾다', 9),
#  ('사용', 9),
#  ('기본', 9),
#  ('다시', 9),
#  ('주차', 9),
#  ('부분', 9),
#  ('찾아가다', 9),
#  ('만들다', 8),
#  ('의사', 8),
#  ('개인', 8),
#  ('직원', 8),
#  ('앉다', 8),
#  ('가장', 8),
#  ('근처', 8),
#  ('참고', 8),
#  ('인테리어', 8),
#  ('촉촉하다', 8),
#  ('이상', 8),
#  ('평일', 8),
#  ('얇다', 8),
#  ('고소하다', 8),
#  ('바로', 8),
#  ('내부', 8),
#  ('일반', 8),
#  ('위치', 8),
#  ('자체', 8),
#  ('국물', 8),
#  ('다음', 8),
#  ('비싸다', 8),
#  ('맵다', 8),
#  ('두께', 8),
#  ('인기', 7),
#  ('맞추다', 7),
#  ('도착', 7),
#  ('일단', 7),
#  ('맛보다', 7),
#  ('서다', 7),
#  ('기대', 7),
#  ('별로', 7),
#  ('좁다', 7),
#  ('아쉽다', 7),
#  ('어울리다', 7),
#  ('갈다', 7),
#  ('예약', 7),
#  ('나다', 7),
#  ('특히', 7),
#  ('서비스', 7),
#  ('전문점', 7),
#  ('크다', 7),
#  ('사장', 7),
#  ('포장', 7),
#  ('작다', 7),
#  ('세트', 7),
#  ('해보다', 7),
#  ('모르다', 7),
#  ('차다', 7),
#  ('반찬', 7),
#  ('다르다', 7),
#  ('마제', 7),
#  ('모두', 7),
#  ('히레', 6),
#  ('11시', 6),
#  ('미리', 6),
#  ('리필', 6),
#  ('충분하다', 6),
#  ('느껴지다', 6),
#  ('가성', 6),
#  ('함께', 6),
#  ('먹기', 6),
#  ('다소', 6),
#  ('조각', 6),
#  ('트러플', 6),
#  ('지다', 6),
#  ('ㅠㅠ', 6),
#  ('담백하다', 6),
#  ('30분', 6),
#  ('드리다', 6),
#  ('항상', 6),
#  ('인상', 6),
#  ('적당하다', 6),
#  ('스타일', 6),
#  ('만족', 6),
#  ('해주다', 6),
#  ('점심시간', 6),
#  ('모습', 6),
#  ('넘다', 6),
#  ('궁합', 6),
#  ('비다', 6),
#  ('불편하다', 6),
#  ('위해', 6),
#  ('가스', 6),
#  ('푸다', 6),
#  ('취향', 6),
#  ('식사', 6),
#  ('저녁', 6),
#  ('특등', 6),
#  ('최고', 6),
#  ('점심', 5),
#  ('거의', 5),
#  ('상당하다', 5),
#  ('히말라야', 5),
#  ('서서', 5),
#  ('배부르다', 5),
#  ('걸리다', 5),
#  ('그리고', 5),
#  ('높다', 5),
#  ('대다', 5),
#  ('살다', 5),
#  ('그대로', 5),
#  ('직접', 5),
#  ('심다', 5),
#  ('그리다', 5),
#  ('즐기다', 5),
#  ('주방', 5),
#  ('냄새', 5),
#  ('추가', 5),
#  ('ㅎㅎ', 5),
#  ('쉬다', 5),
#  ('주변', 5),
#  ('곁들이다', 5),
#  ('사이드', 5),
#  ('두툼', 5),
#  ('겨자', 5),
#  ('사진', 5),
#  ('역시', 5),
#  ('다만', 5),
#  ('자주', 5),
#  ('종류', 5),
#  ('어묵', 5),
#  ('어렵다', 5),
#  ('가지', 5),
#  ('신선하다', 5),
#  ('빠르다', 5),
#  ('최강', 5),
#  ('올리다', 5),
#  ('오징어', 5),
#  ('순대', 5),
#  ('두다', 4),
#  ('걱정', 4),
#  ('물어보다', 4),
#  ('물론', 4),
#  ('우리', 4),
#  ('우선', 4),
#  ('부드러움', 4),
#  ('쓸다', 4),
#  ('건지다', 4),
#  ('모든', 4),
#  ('인근', 4),
#  ('여기다', 4),
#  ('사실', 4),
#  ('떨어지다', 4),
#  ('제공', 4),
#  ('좌석', 4),
#  ('만나다', 4),
#  ('보기', 4),
#  ('영업', 4),
#  ('먼저', 4),
#  ('굉장하다', 4),
#  ('약간', 4),
#  ('근데', 4),
#  ('길다', 4),
#  ('힘들다', 4),
#  ('감동', 4),
#  ('기르다', 4),
#  ('어느', 4),
#  ('드레싱', 4),
#  ('그래서', 4),
#  ('김치', 4),
#  ('또한', 4),
#  ('중간', 4),
#  ('주말', 4),
#  ('인생', 4),
#  ('들르다', 4),
#  ('돼지고기', 4),
#  ('오시', 4),
#  ('고급', 4),
#  ('양배추', 4),
#  ('생각나다', 4),
#  ('만족스럽다', 4),
#  ('보고', 4),
#  ('짜다', 4),
#  ('오래', 4),
#  ('매장', 4),
#  ('새우', 4),
#  ('전반', 4),
#  ('따뜻하다', 4),
#  ('거리', 4),
#  ('훌륭하다', 4),
#  ('시원하다', 4),
#  ('입장', 4),
#  ('평이', 4),
#  ('거나', 4),
#  ('가면', 4),
#  ('크레이지', 4),
#  ('유명', 4),
#  ('히레카츠', 4),
#  ('지하', 4),
#  ('무척', 4),
#  ('경우', 4),
#  ('빵가루', 4),
#  ('달라', 4),
#  ('선택', 4),
#  ('매콤', 4),
#  ('브라운', 4),
#  ('단무지', 4),
#  ('벗겨지다', 4),
#  ('중앙', 4),
#  ('조리', 4),
#  ('만족하다', 4),
#  ('조용하다', 4),
#  ('비계', 4),
#  ('오늘', 4),
#  ('실내', 4),
#  ('타다', 4),
#  ('돈가츠', 4),
#  ('회전', 4),
#  ('불구', 4),
#  ('맞다', 4),
#  ('구성', 4),
#  ('오징어순대', 4),
#  ('기록', 3),
#  ('만점', 3),
#  ('메뉴인', 3),
#  ('이미', 3),
#  ('야하다', 3),
#  ('브리', 3),
#  ('심지어', 3),
#  ('환상', 3),
#  ('뿌리다', 3),
#  ('특징', 3),
#  ('로즈마리', 3),
#  ('솔트', 3),
#  ('제일', 3),
#  ('나름', 3),
#  ('혼밥', 3),
#  ('대단하다', 3),
#  ('일식', 3),
#  ('실망', 3),
#  ('나서다', 3),
#  ('타임', 3),
#  ('계속', 3),
#  ('궁금하다', 3),
#  ('물리다', 3),
#  ('준비', 3),
#  ('신경', 3),
#  ('가도', 3),
#  ('살리다', 3),
#  ('필요', 3),
#  ('익다', 3),
#  ('최근', 3),
#  ('가야', 3),
#  ('줄이다', 3),
#  ('평소', 3),
#  ('부담스럽다', 3),
#  ('정성', 3),
#  ('유자', 3),
#  ('하루', 3),
#  ('지나다', 3),
#  ('치킨', 3),
#  ('레몬', 3),
#  ('형태', 3),
#  ('안되다', 3),
#  ('단점', 3),
#  ('기대하다', 3),
#  ('흔하다', 3),
#  ('요즘', 3),
#  ('부르다', 3),
#  ('이유', 3),
#  ('개운하다', 3),
#  ('이후', 3),
#  ('녹다', 3),
#  ('비빔', 3),
#  ('직장인', 3),
#  ('착하다', 3),
#  ('버리다', 3),
#  ('부족하다', 3),
#  ('숨다', 3),
#  ('육질', 3),
#  ('이름', 3),
#  ('대표', 3),
#  ('조합', 3),
#  ('1시간', 3),
#  ('한다는', 3),
#  ('주차장', 3),
#  ('늦다', 3),
#  ('숙성', 3),
#  ('이기', 3),
#  ('먹음', 3),
#  ('그릇', 3),
#  ('경험', 3),
#  ('통해', 3),
#  ('래서', 3),
#  ('깨끗하다', 3),
#  ('요리', 3),
#  ('스탠다드', 3),
#  ('여러', 3),
#  ('차이', 3),
#  ('오르다', 3),
#  ('가보다', 3),
#  ('조절', 3),
#  ('보통', 3),
#  ('들어오다', 3),
#  ('한국', 3),
#  ('칼칼하다', 3),
#  ('익히다', 3),
#  ('절임', 3),
#  ('과정', 3),
#  ('소진', 3),
#  ('양식', 3),
#  ('옛날', 3),
#  ('녹아내리다', 3),
#  ('바뀌다', 3),
#  ('식탁', 3),
#  ('상호', 3),
#  ('돈까쓰', 3),
#  ('따르다', 3),
#  ('깍두기', 3),
#  ('퀄리티', 3),
#  ('아깝다', 3),
#  ('다양하다', 3),
#  ('재밌다', 3),
#  ('들기름', 3),
#  ('그것', 3),
#  ('빼다', 3),
#  ('가득', 3),
#  ('차분하다', 3),
#  ('잡아내다', 3),
#  ('분들', 3),
#  ('금방', 3),
#  ('가정', 3),
#  ('새우젓', 3),
#  ('무난', 3),
#  ('분식집', 3),
#  ('특별하다', 3),
#  ('썰리다', 3),
#  ('사먹다', 3),
#  ('진하다', 3),
#  ('다니다', 3),
#  ('10년', 3),
#  ('만석', 2),
#  ('이르다', 2),
#  ('부위', 2),
#  ('양은', 2),
#  ('주인', 2),
#  ('오일', 2),
#  ('딱하다', 2),
#  ('일찍', 2),
#  ('구조', 2),
#  ('반면', 2),
#  ('함재', 2),
#  ('브레이크', 2),
#  ('끝나다', 2),
#  ('20분', 2),
#  ('남기다', 2),
#  ('간다', 2),
#  ('핑크', 2),
#  ('언제', 2),
#  ('일어나다', 2),
#  ('근방', 2),
#  ('활용', 2),
#  ('카페', 2),
#  ('음료', 2),
#  ('단맛', 2),
#  ('데이트', 2),
#  ('코스', 2),
#  ('풍부하다', 2),
#  ('어우러지다', 2),
#  ('설명', 2),
#  ('미치다', 2),
#  ('비교', 2),
#  ('엄청나다', 2),
#  ('특유', 2),
#  ('무조건', 2),
#  ('생기다', 2),
#  ('베다', 2),
#  ('전혀', 2),
#  ('퍽퍽', 2),
#  ('보상', 2),
#  ('다녀오다', 2),
#  ('토요일', 2),
#  ('어플', 2),
#  ('히레가츠', 2),
#  ('로만', 2),
#  ('피클', 2),
#  ('날다', 2),
#  ('무엇', 2),
#  ('찌다', 2),
#  ('피드백', 2),
#  ('단지', 2),
#  ('코로나', 2),
#  ('골목', 2),
#  ('저희', 2),
#  ('걸다', 2),
#  ('모양', 2),
#  ('한쪽', 2),
#  ('키친', 2),
#  ('스테이크', 2),
#  ('윤기', 2),
#  ('흐르다', 2),
#  ('친구', 2),
#  ('돈지루', 2),
#  ('담그다', 2),
#  ('도산', 2),
#  ('끄다', 2),
#  ('국도', 2),
#  ('살살', 2),
#  ('듣다', 2),
#  ('밀도', 2),
#  ('광화문', 2),
#  ('건물', 2),
#  ('지하상가', 2),
#  ('메밀', 2),
#  ('상가', 2),
#  ('화장실', 2),
#  ('까스', 2),
#  ('미니', 2),
#  ('잡다', 2),
#  ('음식점', 2),
#  ('종각', 2),
#  ('시원', 2),
#  ('새롭다', 2),
#  ('뛰어나다', 2),
#  ('7,000', 2),
#  ('다행하다', 2),
#  ('5시', 2),
#  ('구지', 2),
#  ('넓다', 2),
#  ('4.0', 2),
#  ('특로스가츠', 2),
#  ('비롯', 2),
#  ('고로케', 2),
#  ('골고루', 2),
#  ('미로', 2),
#  ('라면', 2),
#  ('오버', 2),
#  ('듭니', 2),
#  ('주자', 2),
#  ('응대', 2),
#  ('보관', 2),
#  ('보시', 2),
#  ('쓴다', 2),
#  ('저온', 2),
#  ('지나치다', 2),
#  ('된장국', 2),
#  ('미소시루', 2),
#  ('밑반찬', 2),
#  ('동네', 2),
#  ('지불', 2),
#  ('보여주다', 2),
#  ('가로수길', 2),
#  ('보아', 2),
#  ('국내', 2),
#  ('가기', 2),
#  ('필수', 2),
#  ('자르다', 2),
#  ('뭉치다', 2),
#  ('동그랗다', 2),
#  ('색다르다', 2),
#  ('차이다', 2),
#  ('양념장', 2),
#  ('끊임없다', 2),
#  ('나가다', 2),
#  ('비쥬', 2),
#  ('달달', 2),
#  ('흠뻑', 2),
#  ('오히려', 2),
#  ('입맛', 2),
#  ('타이밍', 2),
#  ('강하다', 2),
#  ('국수', 2),
#  ('매다', 2),
#  ('면발', 2),
#  ('서울', 2),
#  ('12', 2),
#  ('연어', 2),
#  ('관련', 2),
#  ('따로', 2),
#  ('적히다', 2),
#  ('로스까스', 2),
#  ('수준', 2),
#  ('치다', 2),
#  ('써다', 2),
#  ('순간', 2),
#  ('실력', 2),
#  ('동시', 2),
#  ('쓰다', 2),
#  ('일부러', 2),
#  ('일이', 2),
#  ('가치', 2),
#  ('저렴하다', 2),
#  ('다섯', 2),
#  ('3.0', 2),
#  ('부부', 2),
#  ('미소', 2),
#  ('작고', 2),
#  ('연신내', 2),
#  ('남자', 2),
#  ('잠깐', 2),
#  ('덥다', 2),
#  ('지금', 2),
#  ('햇살', 2),
#  ('머물다', 2),
#  ('변경', 2),
#  ('여전하다', 2),
#  ('놓다', 2),
#  ('대학로', 2),
#  ('소문나다', 2),
#  ('언제나', 2),
#  ('붐비다', 2),
#  ('시간대', 2),
#  ('벅차다', 2),
#  ('여러가지', 2),
#  ('수도', 2),
#  ('가츠산도', 2),
#  ('씹다', 2),
#  ('만족도', 2),
#  ('검색', 2),
#  ('애매하다', 2),
#  ('쏘다', 2),
#  ('고프다', 2),
#  ('마음', 2),
#  ('입구', 2),
#  ('언뜻', 2),
#  ('독특하다', 2),
#  ('올리브오일', 2),
#  ('질도', 2),
#  ('수제', 2),
#  ('요거트', 2),
#  ('마련', 2),
#  ('지리산', 2),
#  ('끓이다', 2),
#  ('마지막', 2),
#  ('제격', 2),
#  ('따다', 2),
#  ('ㅠㅜ', 2),
#  ('굽다', 2),
#  ('덕분', 2),
#  ('편하다', 2),
#  ('더욱', 2),
#  ('이해', 2),
#  ('여름', 2),
#  ('제대로', 2),
#  ('굉장', 2),
#  ('신설동역', 2),
#  ('출구', 2),
#  ('닫다', 2),
#  ('공간', 2),
#  ('안다', 2),
#  ('신설', 2),
#  ('파가', 2),
#  ('장사', 2),
#  ('cm', 2),
#  ('입히다', 2),
#  ('필요없다', 2),
#  ('달다', 2),
#  ('엄마', 2),
#  ('양파', 2),
#  ('무슨', 2),
#  ('겉바', 2),
#  ('안보', 2),
#  ('여지', 2),
#  ('등심까스', 2),
#  ('감다', 2),
#  ('개취', 2),
#  ('아쉬움', 2),
#  ('김밥천국', 2),
#  ('이제', 2),
#  ('희생', 2),
#  ('불다', 2),
#  ('협소', 2),
#  ('혼자', 2),
#  ('몇개', 2),
#  ('스페셜', 2),
#  ('양념', 2),
#  ('정석', 2),
#  ('심플', 2),
#  ('만하', 2),
#  ('후기', 2),
#  ('3분', 2),
#  ('기분', 2),
#  ('규모', 2),
#  ('정갈하다', 2),
#  ('고급스럽다', 2),
#  ('오래되다', 2),
#  ('어회', 2),
#  ('강릉', 2),
#  ('중앙시장', 2),
#  ('공장', 2),
#  ('여느', 2),
#  ('대게', 2),
#  ('마리', 2),
#  ('단연', 2),
#  ('듬뿍', 2),
#  ('대접', 2),
#  ('은사', 2),
#  ('모시', 2),
#  ('머리', 2),
#  ('곰탕', 2),
#  ('믿다', 2),
#  ('프랜차이즈', 2),
#  ('후딱', 2),
#  ('승부', 2),
#  ('고민', 2),
#  ('널리', 2),
#  ('담기다', 2),
#  ('붙잡다', 2),
#  ('충실하다', 2),
#  ('5.0', 1),
#  ('한정', 1),
#  ('월요일', 1),
#  ('싫다', 1),
#  ('16000원', 1),
#  ('살이', 1),
#  ('붙다', 1),
#  ('안해', 1),
#  ('가득하다', 1),
#  ('후추', 1),
#  ('특성', 1),
#  ('갈수록', 1),
#  ('방식', 1),
#  ('불만족', 1),
#  ('우승하다', 1),
#  ('화의', 1),
#  ('이만', 1),
#  ('저만', 1),
#  ('500', 1),
#  ('주변인', 1),
#  ('망설이다', 1),
#  ('품절', 1),
#  ('결론', 1),
#  ('모둠가츠', 1),
#  ('히레하', 1),
#  ('별개', 1),
#  ('질감', 1),
#  ('풀어지다', 1),
#  ('올리브유', 1),
#  ('키츠', 1),
#  ('다그치다', 1),
#  ('민망하다', 1),
#  ('상황', 1),
#  ('몇번', 1),
#  ('마치', 1),
#  ('시스템', 1),
#  ('고개', 1),
#  ('밀고', 1),
#  ('여기저기', 1),
#  ('확인', 1),
#  ('가츠시', 1),
#  ('압살', 1),
#  ('밀다', 1),
#  ('붙이다', 1),
#  ('절대', 1),
#  ('확률', 1),
#  ('카톡', 1),
#  ('차례', 1),
#  ('알림', 1),
#  ('요호', 1),
#  ('협의', 1),
#  ('할인', 1),
#  ('편의', 1),
#  ('즐거움', 1),
#  ('돌다', 1),
#  ('나쁘다', 1),
#  ('키즈', 1),
#  ('어딜', 1),
#  ('어리다', 1),
#  ('빨리', 1),
#  ('올리브', 1),
#  ('오일이', 1),
#  ('밉다', 1),
#  ('거치다', 1),
#  ('허브', 1),
#  ('거지', 1),
#  ('그치다', 1),
#  ('쓰이다', 1),
#  ('킹왕짱', 1),
#  ('돈까츠', 1),
#  ('우열', 1),
#  ('가리다', 1),
#  ('충격', 1),
#  ('아직', 1),
#  ('빠삭', 1),
#  ('탱탱하다', 1),
#  ('젓가락', 1),
#  ('누르다', 1),
#  ('밀려오다', 1),
#  ('거슬리다', 1),
#  ('츠케모노', 1),
#  ('산뜻하다', 1),
#  ('장국', 1),
#  ('성공하다', 1),
#  ('평타', 1),
#  ('상향', 1),
#  ('평준화', 1),
#  ('고요', 1),
#  ('원격', 1),
#  ('희다', 1),
#  ('마디', 1),
#  ('이진', 1),
#  ('짜지다', 1),
#  ('감칠맛', 1),
#  ('카라', 1),
#  ('가라아게', 1),
#  ('비치', 1),
#  ('물다', 1),
#  ('바로바로', 1),
#  ('채우다', 1),
#  ('구간', 1),
#  ('담당', 1),
#  ('서버', 1),
#  ('요청', 1),
#  ('사항', 1),
#  ('빨르다', 1),
#  ('구경', 1),
#  ('재미', 1),
#  ('쏠쏠하다', 1),
#  ('둘러앉다', 1),
#  ('사생활', 1),
#  ('보호', 1),
#  ('오붓하다', 1),
#  ('음악', 1),
#  ('시국', 1),
#  ('동생', 1),
#  ('출발', 1),
#  ('성인', 1),
#  ('여자', 1),
#  ('부들부들', 1),
#  ('참깨', 1),
#  ('된장찌개', 1),
#  ('간도', 1),
#  ('잘맞다', 1),
#  ('라인', 1),
#  ('여서', 1),
#  ('디저트', 1),
#  ('끝내다', 1),
#  ('유행', 1),
#  ('엄지', 1),
#  ('체고', 1),
#  ('레스토랑', 1),
#  ('감탄', 1),
#  ('만가', 1),
#  ('자동', 1),
#  ('지지도', 1),
#  ('비용', 1),
#  ('적지', 1),
#  ('나니', 1),
#  ('마냥', 1),
#  ('순삭', 1),
#  ('혜자', 1),
#  ('12:30', 1),
#  ('끝내주다', 1),
#  ('깜놀', 1),
#  ('관리', 1),
#  ('메이', 1),
#  ('에르', 1),
#  ('복잡하다', 1),
#  ('안내', 1),
#  ('미흡하다', 1),
#  ('메다', 1),
#  ('파다', 1),
#  ('따라가다', 1),
#  ('정통', 1),
#  ('새우다', 1),
#  ('생선', 1),
#  ('얼큰하다', 1),
#  ('돈새까스', 1),
#  ('7.5천원', 1),
#  ('10.0천원', 1),
#  ('7.0천원', 1),
#  ('오피스', 1),
#  ('중심', 1),
#  ('상권', 1),
#  ('인원', 1),
#  ('복판', 1),
#  ('어마어마하다', 1),
#  ('사랑', 1),
#  ('늘어지다', 1),
#  ('조화', 1),
#  ('반복', 1),
#  ('번갈아', 1),
#  ('사리다', 1),
#  ('인심', 1),
#  ('기적', 1),
#  ('일행', 1),
#  ('10,000', 1),
#  ('심하다', 1),
#  ('오후', 1),
#  ('4시', 1),
#  ('기자', 1),
#  ('순번', 1),
#  ('3시', 1),
#  ('55분', 1),
#  ('무려', 1),
#  ('자마자', 1),
#  ('외투', 1),
#  ('입다', 1),
#  ('겨울', 1),
#  ('반지하', 1),
#  ('레모네이드', 1),
#  ('천천히', 1),
#  ('여유', 1),
#  ('리스트', 1),
#  ('올려놓다', 1),
#  ('실제', 1),
#  ('우리나라', 1),
#  ('언급', 1),
#  ('등장', 1),
#  ('번째', 1),
#  ('성공', 1),
#  ('돈맥', 1),
#  ('생맥주', 1),
#  ('대가', 1),
#  ('문제', 1),
#  ('대도', 1),
#  ('성애자', 1),
#  ('그렇게', 1),
#  ('원래', 1),
#  ('타이틀', 1),
#  ('유지', 1),
#  ('세대', 1),
#  ('선두', 1),
#  ('강남', 1),
#  ('갖추다', 1),
#  ('장점', 1),
#  ('매니저', 1),
#  ('프로', 1),
#  ('페셔널', 1),
#  ('하이', 1),
#  ('옮기다', 1),
#  ('정중하다', 1),
#  ('양해', 1),
#  ('도씨', 1),
#  ('400시간', 1),
#  ('2~3일', 1),
#  ('의미', 1),
#  ('단백질', 1),
#  ('변형', 1),
#  ('최소', 1),
#  ('화하다', 1),
#  ('조금씩', 1),
#  ('초라하다', 1),
#  ('컨디션', 1),
#  ('불만', 1),
#  ('대부분', 1),
#  ('혜화점', 1),
#  ('완성', 1),
#  ('동의', 1),
#  ('그야말로', 1),
#  ('최초', 1),
#  ('기법', 1),
#  ('직장', 1),
#  ('점심때', 1),
#  ('무리', 1),
#  ('20-30분', 1),
#  ('기존', 1),
#  ('맛난', 1),
#  ('커서', 1),
#  ('가위', 1),
#  ('줍다', 1),
#  ('분기', 1),
#  ('만큼', 1),
#  ('대접받다', 1),
#  ('부담', 1),
#  ('아예', 1),
#  ('단면', 1),
#  ('보이', 1),
#  ('초창', 1),
#  ('5천원', 1),
#  ('나진', 1),
#  ('웬만하다', 1),
#  ('신사', 1),
#  ('부근', 1),
#  ('땡기다', 1),
#  ('막연하다', 1),
#  ('뭉근히', 1),
#  ('즉석', 1),
#  ('배고프다', 1),
#  ('가세', 1),
#  ('그러면', 1),
#  ('호구', 1),
#  ('주민', 1),
#  ('벼르', 1),
#  ('기회', 1),
#  ('기계로', 1),
#  ('뽑다', 1),
#  ('쑥갓', 1),
#  ('술안주', 1),
#  ('해장', 1),
#  ('가락국수', 1),
#  ('분식', 1),
#  ('면도', 1),
#  ('타입', 1),
#  ...]

# %%
# 내림차순 정렬된 단어 중 상위 50개를 살펴보면 다음과 같습니다.


for word, count in sorted_word_dic[:50]:
    print("{0}({1})".format(word, count), end=" ")
# Out:
# 먹다(134) 돈까스(123) 맛있다(108) 좋다(78) 고기(49) 너무(43) 돈가스(41) 많다(41) 보다(41) 나오다(41) 소스(39) 없다(37) 방문(37) 가다(36) 같다(36) 가격(35) 정도(33) 튀김(33) 카츠(32) 부드럽다(31) 생각(30) 웨이팅(29) 자다(27) 시간(25) 하나(25) 소금(25) 깔끔하다(25) 메뉴(24) 맛집(23) 로스(23) 느끼하다(23) 가게(23) 모밀(23) 치즈(23) 주문(22) 기다리다(22) 되어다(22) 바삭(22) 편이(22) 느낌(21) 오다(21) 음식(20) 우동(20) 프리미엄(19) 오픈(19) 괜찮다(19) 정말(19) 찍다(18) 추천(18) 돈카츠(18)

# %%
# WordCloud 패키지 import
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
word_cloud.generate_from_frequencies(word_dic) # Generate wordcloud from word "frequency" data.

# %%
from PIL import Image

donkatsu_coloring = np.array(Image.open("돈까스4.png"))

youtube_coloring.shape
# Out:
# (1000, 1000, 4)

# %%
# 아래 코드에 사용 가능한 것들
#                        max_words=50, # max words
#                        prefer_horizontal= 1.0, # 이 부분의 주석을 해제하시면 단어들이 가로로만 그려지게 됩니다. (0~1)

# %%
from PIL import Image

donkatsu_coloring = np.array(Image.open("돈까스4.png"))

word_cloud = WordCloud(font_path="C:/Windows/Fonts/malgun.ttf", # font_path="C:/Windows/Fonts/NanumSquareB.ttf"
                       width=2000, height=1000, 
                       mask=donkatsu_coloring, # "마스크를 씌운다"라고 표현합니다. (masking)
                       background_color='white').generate_from_frequencies(word_dic)

plt.figure(figsize=(15,15))
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
